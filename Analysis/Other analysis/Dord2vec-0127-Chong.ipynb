# %% [markdown]
# ## Import doctor review dataset and gender dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
path = "/Users/chongchen/Desktop/19Fall RA/data/generated_data/Internal Medicine Review.csv"
review_im = pd.read_csv(path, index_col = 0)

# %%
review_im.head()
# Out:
#                                               Review  hp_id gender  hasorder  \
# 0  satisfactory but would not recommend coldness,...  19713      F         0
# 1   Although Dr. Merlo does not appear to have an...  19713      F         0
# 2   took my daughter for problems, never examined...  19713      F         0
# 3   Yes, Dr. Merlot can be rude and arrogant, but...  19713      F         0
# 4   I called to make and appointment and a woman ...  19713      F         0
#
#                                                lower  \
# 0  satisfactory but would not recommend coldness,...
# 1   although dr. merlo does not appear to have an...
# 2   took my daughter for problems, never examined...
# 3   yes, dr. merlot can be rude and arrogant, but...
# 4   i called to make and appointment and a woman ...
#
#                                            no_digits  \
# 0  satisfactory but would not recommend coldness,...
# 1   although dr. merlo does not appear to have an...
# 2   took my daughter for problems, never examined...
# 3   yes, dr. merlot can be rude and arrogant, but...
# 4   i called to make and appointment and a woman ...
#
#                                       no_punctuation  \
# 0  satisfactory but would not recommend coldness ...
# 1   although dr  merlo does not appear to have an...
# 2   took my daughter for problems  never examined...
# 3   yes  dr  merlot can be rude and arrogant  but...
# 4   i called to make and appointment and a woman ...
#
#                                                words
# 0  ['satisfactory', 'recommend', 'coldness', 'sol...
# 1  ['although', 'dr', 'merlo', 'appear', 'office'...
# 2  ['took', 'daughter', 'problems', 'never', 'exa...
# 3  ['yes', 'dr', 'merlot', 'rude', 'arrogant', 'o...
# 4  ['called', 'make', 'appointment', 'woman', 'ca...

# %%
# drop records without review
review_im.drop(review_im[review_im['Review'] == ' '].index, inplace = True)
review_im.reset_index(inplace = True, drop = True)

# %%
review_im['words'][0]
# Out:
# "['satisfactory', 'recommend', 'coldness', 'solo', 'helpfulness', 'limited', 'office', 'staff', 'isolation', 'diagnosis', 'solo']"

# %%
import ast
review_im['words'] = review_im['words'].map(lambda x: ast.literal_eval(x))

# %%
review_im['words'][0]
# Out:
# ['satisfactory',
#  'recommend',
#  'coldness',
#  'solo',
#  'helpfulness',
#  'limited',
#  'office',
#  'staff',
#  'isolation',
#  'diagnosis',
#  'solo']

# %%
review_im.head()
# Out:
#                                               Review  hp_id gender  hasorder  \
# 0  satisfactory but would not recommend coldness,...  19713      F         0
# 1   Although Dr. Merlo does not appear to have an...  19713      F         0
# 2   took my daughter for problems, never examined...  19713      F         0
# 3   Yes, Dr. Merlot can be rude and arrogant, but...  19713      F         0
# 4   I called to make and appointment and a woman ...  19713      F         0
#
#                                                lower  \
# 0  satisfactory but would not recommend coldness,...
# 1   although dr. merlo does not appear to have an...
# 2   took my daughter for problems, never examined...
# 3   yes, dr. merlot can be rude and arrogant, but...
# 4   i called to make and appointment and a woman ...
#
#                                            no_digits  \
# 0  satisfactory but would not recommend coldness,...
# 1   although dr. merlo does not appear to have an...
# 2   took my daughter for problems, never examined...
# 3   yes, dr. merlot can be rude and arrogant, but...
# 4   i called to make and appointment and a woman ...
#
#                                       no_punctuation  \
# 0  satisfactory but would not recommend coldness ...
# 1   although dr  merlo does not appear to have an...
# 2   took my daughter for problems  never examined...
# 3   yes  dr  merlot can be rude and arrogant  but...
# 4   i called to make and appointment and a woman ...
#
#                                                words
# 0  [satisfactory, recommend, coldness, solo, help...
# 1  [although, dr, merlo, appear, office, staff, m...
# 2  [took, daughter, problems, never, examined, un...
# 3  [yes, dr, merlot, rude, arrogant, one, gastroe...
# 4  [called, make, appointment, woman, calling, ma...

# %% [markdown]
# #### Add lable to the review based on gender & sanction

# %%
review_im['label']=0

# %%
review_im['label'][np.logical_and(review_im['gender']=='F',review_im['hasorder']==0)] = 'F0'
# Out:
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
review_im['label'][np.logical_and(review_im['gender']=='M',review_im['hasorder']==0)] = 'M0'
# Out:
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
review_im['label'][np.logical_and(review_im['gender']=='F',review_im['hasorder']==1)] = 'F1'
# Out:
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
review_im['label'][np.logical_and(review_im['gender']=='M',review_im['hasorder']==1)] = 'M1'
# Out:
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
review_im
# Out:
#                                                   Review    hp_id gender  \
# 0      satisfactory but would not recommend coldness,...    19713      F
# 1       Although Dr. Merlo does not appear to have an...    19713      F
# 2       took my daughter for problems, never examined...    19713      F
# 3       Yes, Dr. Merlot can be rude and arrogant, but...    19713      F
# 4       I called to make and appointment and a woman ...    19713      F
# 5       I, unfortunately,treated with Dr.Merlo severa...    19713      F
# 6       I can't tell you if she's a good or bad docto...    19713      F
# 7       Yesterday my partner had an upper endoscopy d...    19713      F
# 8       Very arrogant and rude. Went in with a previo...    19713      F
# 9       She files insurance for me even though I have...    19713      F
# 10      After scheduling 2 appts. (for a husband and ...    19713      F
# 11     I have been going to Dr. Mittleman for the pas...   587845      M
# 12      Dr. Mittleman is friendly, non-threatening, n...   587845      M
# 13      Dr. Mittleman has been my primary physician f...   587845      M
# 14      I've been Dr. Mittleman for years. He's very ...   587845      M
# 15      This man had the patience of a saint when he ...   587845      M
# 16      Very poor. I took my uncle to him and he was ...   587845      M
# 17      Very caring and helpful! I had a BMI of 41 an...   587845      M
# 18      Dr. Mittleman never makes you feel rushed and...   587845      M
# 19      Dr Mittleman is an excellent MD. He is caring...   587845      M
# 20     What I like most about Dr. Brandies is that sh...  1026482      F
# 21      I've used Dr. Brandies as my doctor for over ...  1026482      F
# 22      I did not find her compassionate at all; in f...  1026482      F
# 23      Excellent doctor with a great 'bedside manner...  1026482      F
# 24      I love Dr. Brandies! She truly is a great doc...  1026482      F
# 25      I can't say enough good things about Dr. Bran...  1026482      F
# 26      Dr. Brandies always takes the time to listen ...  1026482      F
# 27      Dr Brandies is very thoughtful. She listens t...  1026482      F
# 28      Dr. Brandies is a dedicated physician who lis...  1026482      F
# 29      It is ocassionally hard to get an appointment...  1026482      F
# ...                                                  ...      ...    ...
# 87845  My first experience with this doctor was when ...   188148      M
# 87846   This doctor is perpetually in a languid mood....   188148      M
# 87847                                    Very Attentive   1239152      M
# 87848  An excellent physician. A good diagnostician. ...   879980      M
# 87849   always booked and very hard to get an appoint...   879980      M
# 87850   I found him to be very thorough and smart and...   879980      M
# 87851   I found him thorough and caring and he is gre...   879980      M
# 87852  Excellent doctor, in terms of skill, knowledge...  1336864      M
# 87853  This doctor was unable to complete the colonos...   868723      M
# 87854                                                      868723      M
# 87855  best all time Dr. She takes care of my mother ...   711194      F
# 87856   I have been going to her for over 12 years. s...   711194      F
# 87857   My whole family had been going to see her for...   711194      F
# 87858  Exquisite diagnostician! Dr. Myaing was the li...   211646      M
# 87859   I have always found Dr. Myaing to be extremel...   211646      M
# 87860  Dr. Rickles is helpful, informative and consid...     9685      M
# 87861   Dr. Rickles is very caring and knowledgeable....     9685      M
# 87862   Very knowledgeable; warm and sympathetic. I u...     9685      M
# 87863   A kind and caring doctor. Extremely knowledge...     9685      M
# 87864   blamed me (the patient) for the dambing diffi...     9685      M
# 87865  I was very disappointed with this doctor. He s...  1036394      M
# 87866         Above average. Some room for improvement.    425150      M
# 87867  Saw him several times for liver disease -- he'...   818326      M
# 87868   Thoughtful and understanding. He is intereste...   818326      M
# 87869  dr. Foster has been excellent, she has hapled ...  1049044      F
# 87870   This doctor is just flaky. Dr. Foster, just s...  1049044      F
# 87871   DO NOT GO TO DR. ERNIA FOSTER. She perforated...  1049044      F
# 87872  Dr. Davis is a very caring physician. She is n...  1132315      F
# 87873   I found it sad that Dr. Charlyce Davis will n...  1132315      F
# 87874   The times she is running behind you are promp...  1132315      F
#
#        hasorder                                              lower  \
# 0             0  satisfactory but would not recommend coldness,...
# 1             0   although dr. merlo does not appear to have an...
# 2             0   took my daughter for problems, never examined...
# 3             0   yes, dr. merlot can be rude and arrogant, but...
# 4             0   i called to make and appointment and a woman ...
# 5             0   i, unfortunately,treated with dr.merlo severa...
# 6             0   i can't tell you if she's a good or bad docto...
# 7             0   yesterday my partner had an upper endoscopy d...
# 8             0   very arrogant and rude. went in with a previo...
# 9             0   she files insurance for me even though i have...
# 10            0   after scheduling 2 appts. (for a husband and ...
# 11            0  i have been going to dr. mittleman for the pas...
# 12            0   dr. mittleman is friendly, non-threatening, n...
# 13            0   dr. mittleman has been my primary physician f...
# 14            0   i've been dr. mittleman for years. he's very ...
# 15            0   this man had the patience of a saint when he ...
# 16            0   very poor. i took my uncle to him and he was ...
# 17            0   very caring and helpful! i had a bmi of 41 an...
# 18            0   dr. mittleman never makes you feel rushed and...
# 19            0   dr mittleman is an excellent md. he is caring...
# 20            0  what i like most about dr. brandies is that sh...
# 21            0   i've used dr. brandies as my doctor for over ...
# 22            0   i did not find her compassionate at all; in f...
# 23            0   excellent doctor with a great 'bedside manner...
# 24            0   i love dr. brandies! she truly is a great doc...
# 25            0   i can't say enough good things about dr. bran...
# 26            0   dr. brandies always takes the time to listen ...
# 27            0   dr brandies is very thoughtful. she listens t...
# 28            0   dr. brandies is a dedicated physician who lis...
# 29            0   it is ocassionally hard to get an appointment...
# ...         ...                                                ...
# 87845         0  my first experience with this doctor was when ...
# 87846         0   this doctor is perpetually in a languid mood....
# 87847         0                                    very attentive
# 87848         0  an excellent physician. a good diagnostician. ...
# 87849         0   always booked and very hard to get an appoint...
# 87850         0   i found him to be very thorough and smart and...
# 87851         0   i found him thorough and caring and he is gre...
# 87852         0  excellent doctor, in terms of skill, knowledge...
# 87853         0  this doctor was unable to complete the colonos...
# 87854         0
# 87855         0  best all time dr. she takes care of my mother ...
# 87856         0   i have been going to her for over 12 years. s...
# 87857         0   my whole family had been going to see her for...
# 87858         0  exquisite diagnostician! dr. myaing was the li...
# 87859         0   i have always found dr. myaing to be extremel...
# 87860         0  dr. rickles is helpful, informative and consid...
# 87861         0   dr. rickles is very caring and knowledgeable....
# 87862         0   very knowledgeable; warm and sympathetic. i u...
# 87863         0   a kind and caring doctor. extremely knowledge...
# 87864         0   blamed me (the patient) for the dambing diffi...
# 87865         0  i was very disappointed with this doctor. he s...
# 87866         0         above average. some room for improvement.
# 87867         0  saw him several times for liver disease -- he'...
# 87868         0   thoughtful and understanding. he is intereste...
# 87869         0  dr. foster has been excellent, she has hapled ...
# 87870         0   this doctor is just flaky. dr. foster, just s...
# 87871         0   do not go to dr. ernia foster. she perforated...
# 87872         0  dr. davis is a very caring physician. she is n...
# 87873         0   i found it sad that dr. charlyce davis will n...
# 87874         0   the times she is running behind you are promp...
#
#                                                no_digits  \
# 0      satisfactory but would not recommend coldness,...
# 1       although dr. merlo does not appear to have an...
# 2       took my daughter for problems, never examined...
# 3       yes, dr. merlot can be rude and arrogant, but...
# 4       i called to make and appointment and a woman ...
# 5       i, unfortunately,treated with dr.merlo severa...
# 6       i can't tell you if she's a good or bad docto...
# 7       yesterday my partner had an upper endoscopy d...
# 8       very arrogant and rude. went in with a previo...
# 9       she files insurance for me even though i have...
# 10      after scheduling  appts. (for a husband and w...
# 11     i have been going to dr. mittleman for the pas...
# 12      dr. mittleman is friendly, non-threatening, n...
# 13      dr. mittleman has been my primary physician f...
# 14      i've been dr. mittleman for years. he's very ...
# 15      this man had the patience of a saint when he ...
# 16      very poor. i took my uncle to him and he was ...
# 17      very caring and helpful! i had a bmi of  and ...
# 18      dr. mittleman never makes you feel rushed and...
# 19      dr mittleman is an excellent md. he is caring...
# 20     what i like most about dr. brandies is that sh...
# 21      i've used dr. brandies as my doctor for over ...
# 22      i did not find her compassionate at all; in f...
# 23      excellent doctor with a great 'bedside manner...
# 24      i love dr. brandies! she truly is a great doc...
# 25      i can't say enough good things about dr. bran...
# 26      dr. brandies always takes the time to listen ...
# 27      dr brandies is very thoughtful. she listens t...
# 28      dr. brandies is a dedicated physician who lis...
# 29      it is ocassionally hard to get an appointment...
# ...                                                  ...
# 87845  my first experience with this doctor was when ...
# 87846   this doctor is perpetually in a languid mood....
# 87847                                    very attentive
# 87848  an excellent physician. a good diagnostician. ...
# 87849   always booked and very hard to get an appoint...
# 87850   i found him to be very thorough and smart and...
# 87851   i found him thorough and caring and he is gre...
# 87852  excellent doctor, in terms of skill, knowledge...
# 87853  this doctor was unable to complete the colonos...
# 87854
# 87855  best all time dr. she takes care of my mother ...
# 87856   i have been going to her for over  years. she...
# 87857   my whole family had been going to see her for...
# 87858  exquisite diagnostician! dr. myaing was the li...
# 87859   i have always found dr. myaing to be extremel...
# 87860  dr. rickles is helpful, informative and consid...
# 87861   dr. rickles is very caring and knowledgeable....
# 87862   very knowledgeable; warm and sympathetic. i u...
# 87863   a kind and caring doctor. extremely knowledge...
# 87864   blamed me (the patient) for the dambing diffi...
# 87865  i was very disappointed with this doctor. he s...
# 87866         above average. some room for improvement.
# 87867  saw him several times for liver disease -- he'...
# 87868   thoughtful and understanding. he is intereste...
# 87869  dr. foster has been excellent, she has hapled ...
# 87870   this doctor is just flaky. dr. foster, just s...
# 87871   do not go to dr. ernia foster. she perforated...
# 87872  dr. davis is a very caring physician. she is n...
# 87873   i found it sad that dr. charlyce davis will n...
# 87874   the times she is running behind you are promp...
#
#                                           no_punctuation  \
# 0      satisfactory but would not recommend coldness ...
# 1       although dr  merlo does not appear to have an...
# 2       took my daughter for problems  never examined...
# 3       yes  dr  merlot can be rude and arrogant  but...
# 4       i called to make and appointment and a woman ...
# 5       i  unfortunately treated with dr merlo severa...
# 6       i can t tell you if she s a good or bad docto...
# 7       yesterday my partner had an upper endoscopy d...
# 8       very arrogant and rude  went in with a previo...
# 9       she files insurance for me even though i have...
# 10      after scheduling  appts   for a husband and w...
# 11     i have been going to dr  mittleman for the pas...
# 12      dr  mittleman is friendly  non threatening  n...
# 13      dr  mittleman has been my primary physician f...
# 14      i ve been dr  mittleman for years  he s very ...
# 15      this man had the patience of a saint when he ...
# 16      very poor  i took my uncle to him and he was ...
# 17      very caring and helpful  i had a bmi of  and ...
# 18      dr  mittleman never makes you feel rushed and...
# 19      dr mittleman is an excellent md  he is caring...
# 20     what i like most about dr  brandies is that sh...
# 21      i ve used dr  brandies as my doctor for over ...
# 22      i did not find her compassionate at all  in f...
# 23      excellent doctor with a great  bedside manner...
# 24      i love dr  brandies  she truly is a great doc...
# 25      i can t say enough good things about dr  bran...
# 26      dr  brandies always takes the time to listen ...
# 27      dr brandies is very thoughtful  she listens t...
# 28      dr  brandies is a dedicated physician who lis...
# 29      it is ocassionally hard to get an appointment...
# ...                                                  ...
# 87845  my first experience with this doctor was when ...
# 87846   this doctor is perpetually in a languid mood ...
# 87847                                    very attentive
# 87848  an excellent physician  a good diagnostician  ...
# 87849   always booked and very hard to get an appoint...
# 87850   i found him to be very thorough and smart and...
# 87851   i found him thorough and caring and he is gre...
# 87852  excellent doctor  in terms of skill  knowledge...
# 87853  this doctor was unable to complete the colonos...
# 87854
# 87855  best all time dr  she takes care of my mother ...
# 87856   i have been going to her for over  years  she...
# 87857   my whole family had been going to see her for...
# 87858  exquisite diagnostician  dr  myaing was the li...
# 87859   i have always found dr  myaing to be extremel...
# 87860  dr  rickles is helpful  informative and consid...
# 87861   dr  rickles is very caring and knowledgeable ...
# 87862   very knowledgeable  warm and sympathetic  i u...
# 87863   a kind and caring doctor  extremely knowledge...
# 87864   blamed me  the patient  for the dambing diffi...
# 87865  i was very disappointed with this doctor  he s...
# 87866         above average  some room for improvement
# 87867  saw him several times for liver disease    he ...
# 87868   thoughtful and understanding  he is intereste...
# 87869  dr  foster has been excellent  she has hapled ...
# 87870   this doctor is just flaky  dr  foster  just s...
# 87871   do not go to dr  ernia foster  she perforated...
# 87872  dr  davis is a very caring physician  she is n...
# 87873   i found it sad that dr  charlyce davis will n...
# 87874   the times she is running behind you are promp...
#
#                                                    words label
# 0      [satisfactory, recommend, coldness, solo, help...    F0
# 1      [although, dr, merlo, appear, office, staff, m...    F0
# 2      [took, daughter, problems, never, examined, un...    F0
# 3      [yes, dr, merlot, rude, arrogant, one, gastroe...    F0
# 4      [called, make, appointment, woman, calling, ma...    F0
# 5      [unfortunately, treated, dr, merlo, several, y...    F0
# 6      [tell, good, bad, doctor, anything, prove, one...    F0
# 7      [yesterday, partner, upper, endoscopy, done, d...    F0
# 8      [arrogant, rude, went, previously, diagnosed, ...    F0
# 9      [files, insurance, even, though, traditional, ...    F0
# 10     [scheduling, appts, husband, wife, immediate, ...    F0
# 11     [going, dr, mittleman, past, years, caring, at...    M0
# 12     [dr, mittleman, friendly, non, threatening, ne...    M0
# 13     [dr, mittleman, primary, physician, many, year...    M0
# 14     [dr, mittleman, years, attentive, patients, al...    M0
# 15     [man, patience, saint, took, care, wife, amp, ...    M0
# 16     [poor, took, uncle, rude, short, completely, u...    M0
# 17     [caring, helpful, bmi, jump, throat, weight, a...    M0
# 18     [dr, mittleman, never, makes, feel, rushed, tr...    M0
# 19     [dr, mittleman, excellent, md, caring, compass...    M0
# 20     [dr, brandies, jump, treating, every, ache, am...    F0
# 21     [used, dr, brandies, doctor, years, knowledgea...    F0
# 22     [find, compassionate, fact, judgmental, rude, ...    F0
# 23     [excellent, doctor, great, bedside, manner, pa...    F0
# 24     [love, dr, brandies, truly, great, doctor, lis...    F0
# 25     [say, enough, good, things, dr, brandies, comp...    F0
# 26     [dr, brandies, always, takes, time, listen, pr...    F0
# 27     [dr, brandies, thoughtful, listens, everything...    F0
# 28     [dr, brandies, dedicated, physician, listens, ...    F0
# 29     [ocassionally, hard, appointment, doctor, prac...    F0
# ...                                                  ...   ...
# 87845  [first, experience, doctor, arrived, urgent, c...    M0
# 87846  [doctor, perpetually, languid, mood, treats, p...    M0
# 87847                                        [attentive]    M0
# 87848  [excellent, physician, good, diagnostician, ca...    M0
# 87849                [always, booked, hard, appointment]    M0
# 87850  [found, thorough, smart, responsive, diagnosed...    M0
# 87851  [found, thorough, caring, great, following, pa...    M0
# 87852  [excellent, doctor, terms, skill, knowledge, b...    M0
# 87853  [doctor, unable, complete, colonoscopy, amount...    M0
# 87854                                                 []    M0
# 87855  [best, time, dr, takes, care, mother, law, dau...    F0
# 87856  [going, years, one, professional, caring, doct...    F0
# 87857  [whole, family, going, see, years, gotten, bad...    F0
# 87858  [exquisite, diagnostician, dr, myaing, lirst, ...    M0
# 87859  [always, found, dr, myaing, extremely, thoroug...    M0
# 87860  [dr, rickles, helpful, informative, considerat...    M0
# 87861  [dr, rickles, caring, knowledgeable, conversan...    M0
# 87862  [knowledgeable, warm, sympathetic, used, go, a...    M0
# 87863   [kind, caring, doctor, extremely, knowledgeable]    M0
# 87864  [blamed, patient, dambing, difficulty, getting...    M0
# 87865  [disappointed, doctor, seemed, aloof, conversa...    M0
# 87866                       [average, room, improvement]    M0
# 87867  [saw, several, times, liver, disease, affable,...    M0
# 87868  [thoughtful, understanding, interested, proble...    M0
# 87869  [dr, foster, excellent, hapled, diagnosed, alo...    F0
# 87870  [doctor, flaky, dr, foster, seems, care, work,...    F0
# 87871         [go, dr, ernia, foster, perforated, colon]    F0
# 87872  [dr, davis, caring, physician, quick, write, s...    F0
# 87873  [found, sad, dr, charlyce, davis, accept, new,...    F0
# 87874  [times, running, behind, promptly, notified, a...    F0
#
# [87875 rows x 9 columns]

# %% [markdown]
# ### Run Doc2vec, using window size of 5, hold other parameters constant.

# %%
from gensim.models import Word2Vec

# %%
# preparing corpus
documents = list(review_im['words'])

# %%
documents[0][0]
# Out:
# 'satisfactory'

# %%
gender = list(review_im['gender'])
hasorder = list(review_im['hasorder'])
label = list(review_im['label']) # conbine gender & sanction in one label

# %%
len(documents),len(gender),len(hasorder),len(label)
# Out:
# (87875, 87875, 87875, 87875)

# %% [markdown]
# ### Write a Doc2vec function

# %%
def run_dov2vec(documents,label1,sampling=None,label2=None):
    # tag document
    import gensim
    docs = [] # each review/row is a tagged document.
    if label2==None:
        for i in range(len(documents)):
            docs.append(gensim.models.doc2vec.TaggedDocument(documents[i], [label1[i]]))
    else:
        for i in range(len(documents)):
            docs.append(gensim.models.doc2vec.TaggedDocument(documents[i], [label1[i],label2[i]]))
    
    # build vocab
    docs_for_vocab = [] 
    for i in docs:
        docs_for_vocab.append(i)
        
    from gensim.models.doc2vec import Doc2Vec, TaggedDocument
    model = Doc2Vec(dm=0, window=5,vector_size=300,min_count=30,epochs=100,workers=4,
               hs=0,negative=7,dbow_words=1,dm_concat=1)
    model.build_vocab(docs_for_vocab)
    if sampling != None:
        docs = sampling
    model.train(documents = docs,total_examples=model.corpus_count,epochs=100)
    return model

# %%
def run_dov2vec_sampling(documents,label1,gs = False,sampling=False,label2=None):
    # tag document
    import gensim
    import random
    import numpy as np
    docs = [] # each review/row is a tagged document.
    if label2==None:
        for i in range(len(documents)):
            docs.append(gensim.models.doc2vec.TaggedDocument(documents[i], [label1[i]]))
    else:
        for i in range(len(documents)):
            docs.append(gensim.models.doc2vec.TaggedDocument(documents[i], [label1[i],label2[i]]))
    
    # build vocab
    docs_for_vocab = [] 
    for i in docs:
        docs_for_vocab.append(i)
    
    if sampling != False & gs == False:
        repeat = {}
        indices = []
        batch = []
        s_candidates = list(review_im[review_im['hasorder']==1].index)
        ns_candidates = list(review_im[review_im['hasorder']==0].index)
        
        ns = np.random.choice(ns_candidates, sampling, replace = True)
        
        # this is upsampling
        if sampling >207:
            s = np.random.choice(s_candidates, sampling, replace = True)
        else:
            s = s_candidates
        indices = list(ns)+list(s)

        for i in indices:
            try:
                repeat[i]+=1
            except:
                repeat[i]=1
            batch.append(docs[i])
            
    if sampling != False & gs != False:
        repeat = {}
        indices = []
        batch = []
        sf_candidates = list(review_im[np.logical_and(review_im['hasorder']==1, review_im['gender']=='F')].index)
        sm_candidates = list(review_im[np.logical_and(review_im['hasorder']==1, review_im['gender']=='M')].index)
        nsf_candidates = list(review_im[np.logical_and(review_im['hasorder']==0, review_im['gender']=='F')].index)
        nsm_candidates = list(review_im[np.logical_and(review_im['hasorder']==0, review_im['gender']=='M')].index)
        
        nsf = np.random.choice(nsf_candidates, sampling, replace = True)
        nsm = np.random.choice(nsm_candidates, sampling, replace = True)

        # this is upsampling
        if sampling >207:
            sf = np.random.choice(sf_candidates, sampling, replace = True)
            sm = np.random.choice(sm_candidates, sampling, replace = True)
        else:
            # In this case, we are not sampling, we just use all the saction reviews
            sf = sf_candidates
            sm = sm_candidates
            
        indices = list(nsf)+list(nsm)+list(sf)+list(sm)
        
        for i in indices:
            try:
                repeat[i]+=1
            except:
                repeat[i]=1
            batch.append(docs[i])
        
 
    from gensim.models.doc2vec import Doc2Vec, TaggedDocument
    model = Doc2Vec(dm=0, window=5,vector_size=300,min_count=30,epochs=100,workers=4,
               hs=0,negative=7,dbow_words=1,dm_concat=1)
    model.build_vocab(docs_for_vocab)
    if sampling != False:
        docs = batch
    model.train(documents = docs,total_examples=model.corpus_count,epochs=100)
    return model

# %% [markdown]
# ### Doc2vec - gender (window size = 5)

# %%
d2v_gender_w5 = run_dov2vec(documents = documents, label1=gender)
d2v_gender_w5.save('d2v_gender_w5.model')

# %%
from gensim.models.doc2vec import Doc2Vec
d2v_gender_w5= Doc2Vec.load('d2v_gender_w5.model')

# %%
d2v_gender_w5.wv.most_similar(positive = [d2v_gender_w5.docvecs['F']],topn=15)
# Out:
# [('dr', 0.5182182192802429),
#  ('doctor', 0.43451419472694397),
#  ('office', 0.40141963958740234),
#  ('staff', 0.370434433221817),
#  ('patient', 0.3658064007759094),
#  ('caring', 0.3610556125640869),
#  ('extremely', 0.35695192217826843),
#  ('knowledgeable', 0.35561496019363403),
#  ('never', 0.350536048412323),
#  ('kind', 0.3500881791114807),
#  ('time', 0.34429776668548584),
#  ('helpful', 0.3397917151451111),
#  ('one', 0.33969056606292725),
#  ('amp', 0.3386547267436981),
#  ('thorough', 0.33682572841644287)]

# %%
d2v_gender_w5.wv.most_similar(positive = [d2v_gender_w5.docvecs['M']],topn=15)
# Out:
# [('dr', 0.5896364450454712),
#  ('doctor', 0.5331661105155945),
#  ('caring', 0.47638845443725586),
#  ('great', 0.46560367941856384),
#  ('kind', 0.460755318403244),
#  ('patient', 0.4508189857006073),
#  ('excellent', 0.4296659231185913),
#  ('knowledgeable', 0.421493798494339),
#  ('physician', 0.41862595081329346),
#  ('extremely', 0.40773874521255493),
#  ('wonderful', 0.403767466545105),
#  ('well', 0.39761823415756226),
#  ('professional', 0.3952086269855499),
#  ('helpful', 0.39506465196609497),
#  ('good', 0.3938184380531311)]

# %% [markdown]
# ### Write a function to output the comparison results

# %%
# for consistency, we assign female words to list1 and male words to list2
def compare(list1,list2):
    ### list1 & list2 are the results from doc2vec.wv.most_similar() ###
    # convert similar words to dataframe
    list1={x:y for (x,y) in list1}
    list1=pd.DataFrame.from_dict(list1,orient='index')
    list1.reset_index(inplace= True)
    list1.rename(columns= {'index':'words',0:'similarity_score_f'},inplace= True)
    
    # convert similar words in list2 to dataframe
    list2={x:y for (x,y) in list2}
    list2=pd.DataFrame.from_dict(list2,orient='index')
    list2.reset_index(inplace= True)
    list2.rename(columns= {'index':'words',0:'similarity_score_m'},inplace= True)
    
    # left join list1 with list2, find words didn't appear in list2 but in list1
    l1 = pd.merge(list1,list2,on = 'words', how = 'left')
    l1_result = l1[['words','similarity_score_f']][l1['similarity_score_m'].isnull()].sort_values(by = 'similarity_score_f', ascending= False)
    print('In F not in M: Words related with female doctors but didn\'t appear in male doctor\'s reviews','\n')
    print(l1_result,'\n')

    # left join male words with female words, find words didn't appear in female but in male
    l2 = pd.merge(list1,list2,on = 'words', how = 'right')
    l2_result = l2[['words','similarity_score_m']][l2['similarity_score_f'].isnull()].sort_values(by = 'similarity_score_m', ascending= False)
    print('In M not in F: Words related with male doctors but didn\'t appear in female doctor\'s reviews','\n')
    print(l2_result,'\n')
    
    
    # related with both
    similar_words = pd.merge(list1,list2,on = 'words', how = 'inner')
    similar_words['diff']=similar_words['similarity_score_m']-similar_words['similarity_score_f']
    similar_words['label'] = similar_words['diff'].map(lambda x: 'F' if x < 0 else 'M')
    similar_words['abs_diff'] = similar_words['diff'].map(lambda x: abs(x))

    # M>F
    m = similar_words[['words','abs_diff']][similar_words['label']=='M'].sort_values(by ='abs_diff', ascending = False)
    # F>M
    f = similar_words[['words','abs_diff']][similar_words['label']=='F'].sort_values(by ='abs_diff', ascending = False)
    
    print('M>F: Similarity score of male doctors higher then that of female doctors','\n')
    print(m,'\n')
    print('F>M: Similarity score of female doctors higher then that of male doctors','\n')
    print(f,'\n')

# %%
f = d2v_gender_w5.wv.most_similar(positive = [d2v_gender_w5.docvecs['F']],topn=500)
m = d2v_gender_w5.wv.most_similar(positive = [d2v_gender_w5.docvecs['M']],topn=500)
compare(list1=f,list2=m)
# Out:
# In F not in M: Words related with female doctors but didn't appear in male doctor's reviews
#
#               words  similarity_score_f
# 36      appointment            0.289986
# 52            woman            0.277924
# 66         physical            0.273189
# 68          current            0.272838
# 69     receptionist            0.272391
# 72        listening            0.270839
# 77          usually            0.269435
# 79             past            0.269114
# 91          focused            0.262964
# 92             cold            0.262912
# 93            often            0.262165
# 99      examination            0.260653
# 100           front            0.260347
# 109           order            0.257630
# 110  unprofessional            0.257585
# 113         thyroid            0.256826
# 116       assistant            0.255420
# 118            hour            0.254724
# 122            appt            0.253775
# 124         someone            0.253388
# 128            desk            0.249622
# 135        previous            0.246030
# 136    appointments            0.245911
# 145          breast            0.244484
# 155   condescending            0.242165
# 156    prescription            0.242082
# 157        holistic            0.242059
# 166        comments            0.238477
# 171         finally            0.236958
# 174            week            0.236523
# ..              ...                 ...
# 451        schedule            0.196685
# 452       proactive            0.196635
# 453          topics            0.196552
# 454        ailments            0.196509
# 456              gp            0.196026
# 457       bloodwork            0.195893
# 458           moved            0.195870
# 459         nodules            0.195814
# 462             end            0.195534
# 464         dealing            0.195133
# 466              ac            0.195034
# 468            away            0.194887
# 469           linda            0.194385
# 470            labs            0.194081
# 471             run            0.194004
# 472    inconsistent            0.193942
# 473        adequate            0.193902
# 476       hashimoto            0.193485
# 477            tone            0.193400
# 478            must            0.193381
# 480       sensitive            0.193283
# 481         whether            0.193180
# 482       conducted            0.193146
# 487            lots            0.192700
# 492         follows            0.192454
# 494        multiple            0.192330
# 495            late            0.192308
# 496           hurry            0.192294
# 497         related            0.192179
# 499           weeks            0.191829
#
# [182 rows x 2 columns]
#
# In M not in F: Words related with male doctors but didn't appear in female doctor's reviews
#
#                words  similarity_score_m
# 318           family            0.335569
# 319          skilled            0.330197
# 320      informative            0.326895
# 321              guy            0.325112
# 322        performed            0.315484
# 323            heart            0.313466
# 324           mother            0.311941
# 325              ago            0.310217
# 326         hospital            0.307102
# 327            saved            0.305101
# 328          treated            0.304108
# 329     cardiologist            0.297576
# 330        brilliant            0.291533
# 331            sense            0.290330
# 332         treating            0.286329
# 333              put            0.280267
# 334           enough            0.279082
# 335               us            0.278133
# 336             knew            0.276423
# 337         possible            0.275684
# 338      exceptional            0.275296
# 339           father            0.274783
# 340          surgery            0.274228
# 341            earth            0.273778
# 342              old            0.269075
# 343            stuff            0.269064
# 344       procedures            0.267964
# 345              bed            0.267710
# 346          respect            0.267578
# 347            young            0.266998
# ..               ...                 ...
# 470           couple            0.219635
# 471            clean            0.219528
# 472           talked            0.219337
# 473            speak            0.219298
# 474         internal            0.219282
# 475             busy            0.219188
# 476       comforting            0.219064
# 477         exellent            0.218970
# 478       wonderfull            0.218949
# 479          control            0.218575
# 480          country            0.218542
# 481       phenomenal            0.218103
# 482            works            0.218083
# 483             uses            0.218025
# 484            money            0.217936
# 485            cared            0.217730
# 486            notch            0.217518
# 487        suffering            0.217260
# 488             kept            0.217203
# 489       technology            0.217134
# 490  professionalism            0.216926
# 491      prescribing            0.216818
# 492                c            0.216818
# 493          chronic            0.216675
# 494            refer            0.216502
# 495          respond            0.216486
# 496             mind            0.216459
# 497          ability            0.216390
# 498            night            0.216091
# 499        diagnoses            0.215774
#
# [182 rows x 2 columns]
#
# M>F: Similarity score of male doctors higher then that of female doctors
#
#            words  abs_diff
# 34         great  0.170266
# 314      husband  0.168632
# 213          man  0.161584
# 30     excellent  0.131552
# 59     wonderful  0.128576
# 293       gentle  0.122383
# 237          met  0.117938
# 277    condition  0.116516
# 5         caring  0.115333
# 276      disease  0.111828
# 266  outstanding  0.111447
# 9           kind  0.110667
# 302      awesome  0.108540
# 306   thoughtful  0.105249
# 51       bedside  0.104191
# 193  recommended  0.102506
# 97   intelligent  0.102485
# 118         best  0.101642
# 205         life  0.100914
# 1         doctor  0.098652
# 292         used  0.097987
# 62        manner  0.094809
# 73        highly  0.094706
# 27          well  0.092928
# 63     recommend  0.092879
# 166     pleasant  0.091325
# 250       needed  0.089750
# 113        smart  0.089408
# 131         nice  0.089048
# 299   respectful  0.088415
# ..           ...       ...
# 244        wrong  0.010297
# 142       people  0.010259
# 28          seen  0.010020
# 233     demeanor  0.009608
# 180        check  0.008052
# 175     personal  0.007843
# 127   interested  0.007649
# 16      friendly  0.007563
# 135          ask  0.007261
# 194     probably  0.006440
# 78         makes  0.006198
# 31      actually  0.006172
# 195     informed  0.005633
# 174       called  0.005401
# 3          staff  0.005135
# 236      service  0.005061
# 141         felt  0.004506
# 111          yet  0.003991
# 124        tests  0.003588
# 152       waited  0.003309
# 130       things  0.002897
# 158         tell  0.002818
# 108         want  0.002216
# 44          take  0.001889
# 136      totally  0.001850
# 46      listener  0.001737
# 150     terrible  0.001669
# 192         rare  0.001637
# 169         call  0.001632
# 191      overall  0.000050
#
# [267 rows x 2 columns]
#
# F>M: Similarity score of female doctors higher then that of male doctors
#
#            words  abs_diff
# 2         office  0.052565
# 83          wait  0.046033
# 64          exam  0.045573
# 53      attitude  0.044935
# 91          left  0.036726
# 95       minutes  0.036626
# 29        seeing  0.032764
# 48          long  0.031296
# 92        return  0.031267
# 98        taking  0.030820
# 47          rude  0.028203
# 114       seemed  0.024428
# 50        issues  0.024253
# 36         nurse  0.023329
# 40         times  0.022943
# 35         seems  0.020683
# 112   supportive  0.020206
# 107          etc  0.020065
# 137    sometimes  0.015062
# 81    empathetic  0.014355
# 139         rush  0.013673
# 66       answers  0.013011
# 88         asked  0.012990
# 37        listen  0.012135
# 159         come  0.011562
# 165      primary  0.011293
# 19           see  0.011265
# 87          back  0.011183
# 106     symptoms  0.010281
# 89      practice  0.010231
# 109         make  0.009723
# 77     efficient  0.008979
# 117        calls  0.008190
# 96    incredibly  0.008068
# 72         visit  0.007571
# 68    responsive  0.006145
# 200         less  0.006068
# 146      waiting  0.004897
# 138        gives  0.004861
# 196     approach  0.004691
# 125        blood  0.004568
# 210   incredible  0.004543
# 74          last  0.004470
# 148        phone  0.004209
# 133         told  0.004199
# 8          never  0.004017
# 217  appropriate  0.002901
# 84        follow  0.002055
# 105        needs  0.001906
# 164          due  0.000748
# 25     attentive  0.000389

# %% [markdown]
# ### Run Doc2vec - sanction

# %%
d2v_sanction_w5 = run_dov2vec(documents = documents, label1=hasorder)
d2v_sanction_w5.save('d2v_sanction_w5.model')

# %%
from gensim.models.doc2vec import Doc2Vec
d2v_sanction_w5= Doc2Vec.load('d2v_sanction_w5.model')

# %%
s = d2v_sanction_w5.wv.most_similar(positive = [d2v_sanction_w5.docvecs[1]],topn=500)
ns = d2v_sanction_w5.wv.most_similar(positive = [d2v_sanction_w5.docvecs[0]],topn=500)
compare(list1=s,list2=ns)
# Out:
# In F not in M: Words related with female doctors but didn't appear in male doctor's reviews
#
#              words  similarity_score_f
# 0             dube            0.291882
# 1         campbell            0.265031
# 2          respond            0.257605
# 3            bruce            0.230014
# 4              hrs            0.224968
# 5             sign            0.218561
# 6       contracted            0.213497
# 9         pressure            0.211623
# 11          forced            0.211058
# 12         injured            0.208180
# 13        mistakes            0.206732
# 16          sunday            0.204581
# 17            dont            0.202554
# 18            temp            0.202455
# 19        vacation            0.202004
# 20          seldom            0.201464
# 21           hears            0.199992
# 22             via            0.199275
# 23    unbelievable            0.198335
# 25            soft            0.197833
# 26          longer            0.197735
# 27         english            0.195773
# 28   appropriately            0.195745
# 31       including            0.195107
# 32       primarily            0.194593
# 33           badly            0.194169
# 34            pill            0.193848
# 36           sites            0.193575
# 37           ahmed            0.193449
# 38           sweet            0.193112
# ..             ...                 ...
# 462       attorney            0.129839
# 463            ill            0.129788
# 464          death            0.129777
# 465         levels            0.129738
# 466        studied            0.129673
# 467      downright            0.129562
# 468        actions            0.129415
# 470          aside            0.129341
# 471     contacting            0.129305
# 472    knowlegable            0.129300
# 473     practicing            0.129201
# 474          depth            0.129038
# 475            kim            0.129005
# 476          shown            0.128818
# 478   hospitalized            0.128741
# 480           fake            0.128390
# 481      injection            0.128351
# 482         heaven            0.128307
# 483             sp            0.128281
# 485          super            0.128267
# 486          large            0.128185
# 487        careing            0.128160
# 488          kelly            0.128139
# 489          aware            0.128136
# 490          sadly            0.128081
# 491       machines            0.128072
# 492           keep            0.127956
# 495       distress            0.127860
# 497        reviews            0.127789
# 499      completly            0.127722
#
# [393 rows x 2 columns]
#
# In M not in F: Words related with male doctors but didn't appear in female doctor's reviews
#
#              words  similarity_score_m
# 107           kind            0.468537
# 108  knowledgeable            0.441983
# 109          great            0.427428
# 110      extremely            0.420948
# 111      excellent            0.416486
# 112           good            0.406362
# 113            one            0.402884
# 114        helpful            0.398026
# 115   professional            0.393361
# 116       thorough            0.390501
# 117  compassionate            0.387059
# 118   knowledgable            0.379616
# 119      recommend            0.376331
# 120     personable            0.372647
# 121           even            0.365988
# 122         really            0.365340
# 123          found            0.365267
# 124       friendly            0.365239
# 125         manner            0.357929
# 126        bedside            0.356621
# 127    intelligent            0.354689
# 128         highly            0.347190
# 129             go            0.346872
# 130      concerned            0.344232
# 131      treatment            0.343185
# 132         person            0.338475
# 133        doctors            0.338063
# 134       problems            0.335230
# 135          think            0.333608
# 136           best            0.331513
# ..             ...                 ...
# 470          helps            0.227195
# 471       returned            0.227025
# 472         period            0.227012
# 473           away            0.226987
# 474        surgeon            0.226941
# 475      difficult            0.226707
# 476           stay            0.226609
# 477     specialist            0.226537
# 478        someone            0.226526
# 479            bit            0.226506
# 480        working            0.226122
# 481           hand            0.226065
# 482      scheduled            0.225729
# 483        provide            0.225728
# 484         giving            0.225649
# 485           five            0.225634
# 486         caused            0.225585
# 487            ran            0.225313
# 488  unfortunately            0.225257
# 489       uncaring            0.224806
# 490       question            0.224677
# 491      something            0.224666
# 492        instead            0.224313
# 493          works            0.224194
# 494          issue            0.224051
# 495      procedure            0.224009
# 496          state            0.223948
# 497         rather            0.223937
# 498          words            0.223552
# 499        perfect            0.223238
#
# [393 rows x 2 columns]
#
# M>F: Similarity score of male doctors higher then that of female doctors
#
#            words  abs_diff
# 3             dr  0.402745
# 4         doctor  0.335917
# 74       patient  0.323847
# 83     physician  0.294595
# 8         caring  0.264324
# 75     wonderful  0.260152
# 95      patients  0.253834
# 29         staff  0.242945
# 28           amp  0.239102
# 25          well  0.237719
# 80          care  0.231244
# 15          time  0.224696
# 69           man  0.218433
# 5         office  0.212738
# 19        always  0.211268
# 47         years  0.206872
# 59           see  0.201336
# 65         truly  0.195264
# 52         takes  0.193297
# 62        polite  0.192723
# 97          many  0.184644
# 61       husband  0.181730
# 1          never  0.177051
# 78          much  0.174569
# 50       medical  0.174149
# 55        family  0.171286
# 79       answers  0.168780
# 63        health  0.168292
# 90          rude  0.164866
# 73        needed  0.160539
# ..           ...       ...
# 36          past  0.104864
# 104         busy  0.104510
# 24          true  0.104054
# 82          lost  0.103261
# 10        mother  0.102710
# 6           love  0.102002
# 20       without  0.101199
# 85          read  0.097725
# 16          room  0.096044
# 0         almost  0.095967
# 100  grandmother  0.094964
# 91         wants  0.094531
# 40          goes  0.091289
# 77       follows  0.089364
# 66     impressed  0.089035
# 67        nurses  0.088204
# 12        waited  0.086857
# 30       despite  0.085567
# 49     assistant  0.082756
# 57         front  0.082096
# 11        people  0.081994
# 27        clinic  0.080412
# 38     sometimes  0.079304
# 14         taken  0.075766
# 39    absolutely  0.075013
# 13        father  0.073019
# 23    incredible  0.071927
# 2    considerate  0.059636
# 9      available  0.058805
# 18    diagnostic  0.054469
#
# [107 rows x 2 columns]
#
# F>M: Similarity score of female doctors higher then that of male doctors
#
# Empty DataFrame
# Columns: [words, abs_diff]
# Index: []

# %% [markdown]
# ### Run Doc2vec - sanction (downsampling)

# %%
d2v_sanction_ds_w5 = run_dov2vec_sampling(documents=documents, sampling=207,label1=hasorder)
d2v_sanction_ds_w5.save('d2v_sanction_ds_w5.model')

# %%
from gensim.models.doc2vec import Doc2Vec
d2v_sanction_ds_w5= Doc2Vec.load('d2v_sanction_ds_w5.model')

# %%
s1 = d2v_sanction_ds_w5.wv.most_similar(positive = [d2v_sanction_ds_w5.docvecs[1]],topn=500)
ns1 = d2v_sanction_ds_w5.wv.most_similar(positive = [d2v_sanction_ds_w5.docvecs[0]],topn=500)
compare(list1=s1,list2=ns1)
# Out:
# In F not in M: Words related with female doctors but didn't appear in male doctor's reviews
#
#                words  similarity_score_f
# 0               mark            0.404605
# 1      inexperienced            0.402954
# 2         judgmental            0.402018
# 3          responded            0.393790
# 4            remains            0.392931
# 6         statements            0.389924
# 7             warmth            0.388798
# 8              kelly            0.386059
# 9               tend            0.385524
# 10         wednesday            0.384341
# 12              lord            0.382974
# 13              spot            0.382772
# 14           fatigue            0.382140
# 15             pushy            0.381242
# 17          compared            0.379734
# 18            headed            0.379245
# 19            heaven            0.378844
# 21             flare            0.376710
# 22           display            0.376636
# 23      consistently            0.376132
# 24            pusher            0.376018
# 25             input            0.375897
# 27            billed            0.374696
# 28   unknowledgeable            0.374529
# 29         irritated            0.374516
# 30        thankfully            0.373621
# 32      communicates            0.372493
# 33          deserves            0.372347
# 34              shot            0.371747
# 35           elderly            0.371632
# ..               ...                 ...
# 468           gloves            0.317548
# 469      inattentive            0.317506
# 470           choose            0.317403
# 471             wear            0.317387
# 472           winter            0.317319
# 473       scheduling            0.317118
# 474            trash            0.317059
# 475     debilitating            0.317016
# 476           weekly            0.317001
# 477          quality            0.316943
# 478           miller            0.316934
# 479           middle            0.316869
# 480         brooklyn            0.316527
# 481       tremendous            0.316505
# 482         hesitate            0.316495
# 483          morning            0.316489
# 484         solution            0.316404
# 486    disappointing            0.316113
# 487             sits            0.316069
# 488          attempt            0.316056
# 489           united            0.315661
# 490        infection            0.315537
# 491           worthy            0.315513
# 492           sunday            0.315392
# 493          scolded            0.315296
# 494             duty            0.315186
# 495             curt            0.315101
# 496       injections            0.315086
# 497           higher            0.315055
# 499    inconvenience            0.314585
#
# [431 rows x 2 columns]
#
# In M not in F: Words related with male doctors but didn't appear in female doctor's reviews
#
#                words  similarity_score_m
# 69         proactive            0.426592
# 70         everytime            0.423957
# 71   straightforward            0.414077
# 72           trained            0.413339
# 73               phd            0.412721
# 74            breath            0.410522
# 75           outside            0.409830
# 76             manor            0.408198
# 77             fresh            0.408147
# 78        phenomenal            0.406984
# 79          whenever            0.406888
# 80        recomended            0.406420
# 81            proved            0.403574
# 82       credentials            0.400954
# 83               air            0.398352
# 84          absolute            0.396964
# 85           dignity            0.396535
# 86          outright            0.395717
# 87        thoroughly            0.395681
# 88           calming            0.395459
# 89           fathers            0.395445
# 90              endo            0.392977
# 91        regardless            0.392972
# 92         consulted            0.392695
# 93           benefit            0.392007
# 94              wall            0.390376
# 95          military            0.390374
# 96         addressed            0.390255
# 97        empathetic            0.389219
# 98          deciding            0.387714
# ..               ...                 ...
# 470           dosage            0.302043
# 471         pharmacy            0.301721
# 472            terms            0.301615
# 473            offer            0.301590
# 474        welcoming            0.301529
# 475         vacation            0.301398
# 476               md            0.301260
# 477       ridiculous            0.300779
# 478          aspects            0.300668
# 479       hesitation            0.300504
# 480        affecting            0.300350
# 481         physcian            0.300274
# 482         pregnant            0.299716
# 483             sees            0.299644
# 484           habits            0.299516
# 485        explained            0.299331
# 486       reassuring            0.299018
# 487     unbelievably            0.298860
# 488           appear            0.298550
# 489        intensive            0.298376
# 490              car            0.298328
# 491         accurate            0.298247
# 492         turnover            0.298124
# 493        confident            0.297854
# 494      intelligent            0.297504
# 495          affects            0.297419
# 496           series            0.297262
# 497          prevent            0.297207
# 498          returns            0.297069
# 499               ra            0.296907
#
# [431 rows x 2 columns]
#
# M>F: Similarity score of male doctors higher then that of female doctors
#
#            words  abs_diff
# 64  communicator  0.080757
# 68         nancy  0.038150
# 65       walking  0.030316
# 66     heartbeat  0.024284
# 15       workers  0.022315
# 52         fears  0.020598
# 59        martin  0.020550
# 29        keeper  0.019545
# 20     doctoring  0.018731
# 38         rocks  0.017267
# 37        admire  0.013486
# 53         drawn  0.011365
# 63          note  0.009676
# 46         bonus  0.009004
# 61    insightful  0.008070
# 49        benign  0.006264
# 58       kidneys  0.005918
# 18     motivated  0.004562
# 40        stupid  0.002618
# 25          wise  0.000702
#
# F>M: Similarity score of female doctors higher then that of male doctors
#
#                words  abs_diff
# 7            upfront  0.065177
# 11            wisdom  0.063919
# 4           regarded  0.063299
# 14          talented  0.061894
# 3             ailing  0.060997
# 9         definitely  0.060634
# 19            vitals  0.057186
# 0              aetna  0.054500
# 10           alright  0.054022
# 2             gifted  0.048634
# 17          jennifer  0.046307
# 30      consultation  0.045522
# 16        definately  0.045191
# 5             public  0.043866
# 22          diseases  0.043079
# 27         injection  0.039949
# 32        accessible  0.038834
# 43              sold  0.036513
# 35  gastroenterology  0.034837
# 6           reminded  0.034797
# 12           mystery  0.029493
# 26          detached  0.029467
# 31           survive  0.029319
# 24          overbook  0.028173
# 45          sleeping  0.027962
# 21            ethics  0.025330
# 57         beginning  0.024857
# 34    unknowledgable  0.024320
# 23         happening  0.024055
# 55       knowledable  0.023237
# 33            torres  0.022841
# 51            insure  0.021759
# 56             seven  0.021678
# 8              harsh  0.019356
# 54            enjoys  0.018958
# 48            loudly  0.018786
# 1             crisis  0.017839
# 67         patiently  0.017454
# 41                 v  0.017107
# 39           brushed  0.016114
# 62            school  0.014317
# 47          extended  0.013012
# 60        recovering  0.010673
# 50          extremly  0.010275
# 28              rule  0.009987
# 44             hears  0.008548
# 42          medicate  0.008137
# 13           methods  0.007404
# 36      investigated  0.005786

# %% [markdown]
# ### Run Doc2vec - sanction (upsampling)

# %%
d2v_sanction_up_w5 = run_dov2vec_sampling(documents=documents, sampling=1000,label1=hasorder)
d2v_sanction_up_w5.save('d2v_sanction_up_w5.model')

# %%
from gensim.models.doc2vec import Doc2Vec
d2v_sanction_up_w5= Doc2Vec.load('d2v_sanction_up_w5.model')

# %%
s2 = d2v_sanction_up_w5.wv.most_similar(positive = [d2v_sanction_up_w5.docvecs[1]],topn=500)
ns2 = d2v_sanction_up_w5.wv.most_similar(positive = [d2v_sanction_up_w5.docvecs[0]],topn=500)
compare(list1=s2,list2=ns2)
# Out:
# In F not in M: Words related with female doctors but didn't appear in male doctor's reviews
#
#               words  similarity_score_f
# 1             aches            0.397968
# 2         attitudes            0.397157
# 3          finished            0.395545
# 4               hey            0.393624
# 5            blamed            0.390295
# 6      conversation            0.390294
# 7             kelly            0.388925
# 8            idiots            0.387601
# 9           neglect            0.385609
# 10           gloves            0.383715
# 11   professionally            0.379365
# 12          fatigue            0.379213
# 13            moody            0.378778
# 14            lobby            0.378116
# 15               ca            0.376391
# 16            hubby            0.375918
# 17             hole            0.375827
# 18            arise            0.374509
# 19        alternate            0.373566
# 21          longest            0.368548
# 22            false            0.366974
# 23     examinations            0.366605
# 24            panic            0.366294
# 27           guided            0.364472
# 28            score            0.363173
# 30     friendliness            0.362778
# 32             fool            0.361685
# 33            fresh            0.361066
# 34             jerk            0.360514
# 35            weigh            0.360226
# ..              ...                 ...
# 461           aging            0.279183
# 464          caused            0.278673
# 465         factory            0.278647
# 467          shares            0.278475
# 470     questioning            0.278415
# 471          intend            0.278400
# 472         allowed            0.278320
# 473         selling            0.278304
# 475        handling            0.277992
# 476            page            0.277790
# 478          addict            0.277457
# 480     discussions            0.277303
# 481          genius            0.277293
# 482          endure            0.277197
# 484           heavy            0.276998
# 485         welcome            0.276895
# 486         machine            0.276821
# 487           backs            0.276688
# 488       inability            0.276670
# 489          heaven            0.276608
# 490         perfect            0.276410
# 491            thin            0.276290
# 492         clinics            0.276265
# 493        occurred            0.275812
# 494            shop            0.275666
# 495            rely            0.275607
# 496    improvements            0.275498
# 497     willingness            0.275455
# 498            butt            0.275411
# 499           rules            0.275162
#
# [399 rows x 2 columns]
#
# In M not in F: Words related with male doctors but didn't appear in female doctor's reviews
#
#             words  similarity_score_m
# 101        mailed            0.386839
# 102    approaches            0.386624
# 103          flat            0.385346
# 104         nancy            0.383282
# 105       driving            0.382553
# 106          blow            0.382031
# 107             f            0.381714
# 108          boot            0.377272
# 109           mds            0.375665
# 110     equipment            0.374506
# 111        remove            0.373086
# 112        losing            0.370508
# 113      welcomed            0.369698
# 114      recovery            0.369513
# 115          lied            0.368122
# 116        benign            0.367119
# 117        gifted            0.366730
# 118       laughed            0.366497
# 119     reassured            0.366082
# 120  knowledgeble            0.365468
# 121         rocks            0.365133
# 122         views            0.365095
# 123     cancerous            0.365043
# 124       density            0.364635
# 125       episode            0.364325
# 126   radiologist            0.362803
# 127   participate            0.362549
# 128        closer            0.361064
# 129         reply            0.359682
# 130            dr            0.359414
# ..            ...                 ...
# 470    bronchitis            0.301914
# 471           hiv            0.301881
# 472         space            0.301726
# 473      reminded            0.301689
# 474   combination            0.301620
# 475       vitamin            0.301490
# 476         fears            0.301241
# 477       generic            0.301204
# 478      intently            0.300886
# 479         brief            0.300798
# 480       teacher            0.300776
# 481           pat            0.300506
# 482        nights            0.300485
# 483    dedication            0.300472
# 484        repair            0.300417
# 485    unreliable            0.300362
# 486      screamed            0.300351
# 487      painless            0.300301
# 488       factors            0.300055
# 489      prostate            0.299971
# 490         hills            0.299953
# 491   sympathetic            0.299852
# 492       kindest            0.299818
# 493        peters            0.299715
# 494      sometime            0.299633
# 495           btw            0.299491
# 496      expected            0.299407
# 497         exams            0.299089
# 498         santa            0.298988
# 499       handles            0.298977
#
# [399 rows x 2 columns]
#
# M>F: Similarity score of male doctors higher then that of female doctors
#
#             words  abs_diff
# 87           sood  0.081023
# 34         awsome  0.080190
# 54         ethics  0.074183
# 60       contacts  0.073843
# 61        dismiss  0.072877
# 78      injection  0.071521
# 80        kidding  0.070949
# 77      apologize  0.068294
# 84            til  0.067877
# 100    uneducated  0.063298
# 99        classic  0.059834
# 96           gold  0.055990
# 40      perfectly  0.055975
# 39      dishonest  0.053549
# 46         chatty  0.053167
# 71         adding  0.046781
# 94        display  0.046576
# 85       recomend  0.043796
# 92       extended  0.041126
# 69           join  0.040004
# 33      elizabeth  0.039467
# 62             nc  0.039319
# 47       curteous  0.038514
# 93        decades  0.038173
# 64     passionate  0.038046
# 88         decade  0.037778
# 14         joined  0.032979
# 51       sleeping  0.032403
# 58         street  0.032033
# 65         regret  0.031466
# ..            ...       ...
# 76        genetic  0.024632
# 31        alright  0.023039
# 66   excruciating  0.022494
# 83          scans  0.022198
# 82           vist  0.021766
# 67          marks  0.021462
# 86     reflection  0.020963
# 68         shared  0.020818
# 20    opinionated  0.020443
# 56            ive  0.019421
# 70        godsend  0.017258
# 29       reflects  0.016032
# 41        fortune  0.015655
# 37     intestinal  0.015579
# 59       pleasent  0.015560
# 30      delivered  0.014684
# 79     retirement  0.014463
# 75        bladder  0.013022
# 72    wonderfully  0.013004
# 73           hero  0.011517
# 38       impolite  0.010583
# 42           oral  0.009370
# 50           bush  0.007530
# 23   investigated  0.007216
# 63        fifteen  0.004703
# 55           gall  0.003826
# 49        upfront  0.002862
# 57     pleasantly  0.002665
# 27      magazines  0.001594
# 52          blame  0.000408
#
# [70 rows x 2 columns]
#
# F>M: Similarity score of female doctors higher then that of male doctors
#
#             words  abs_diff
# 1            mark  0.062737
# 3        priority  0.058170
# 5        downside  0.050022
# 8        regarded  0.045576
# 11     reccommend  0.044911
# 13       retiring  0.044906
# 0           delay  0.040970
# 10           sold  0.035377
# 15      considers  0.035157
# 16            pas  0.033529
# 18          north  0.032854
# 12             gt  0.030122
# 6       wednesday  0.029650
# 19        methods  0.025934
# 7              il  0.025177
# 4       monitored  0.022442
# 36          final  0.016745
# 22    grandmother  0.016732
# 24          doors  0.016643
# 17    functioning  0.013041
# 28          vague  0.012502
# 26   personalized  0.011703
# 9   inexperienced  0.011209
# 45    description  0.007800
# 43          straw  0.003429
# 2         pulling  0.003414
# 44          sales  0.003211
# 21  extraordinary  0.002769
# 53        explore  0.001790
# 25    maintaining  0.000874
# 35         fisher  0.000217

# %% [markdown]
# ### Run Doc2vec - gender & sanction

# %%
dv2_gs_w5 = run_dov2vec_sampling(documents=documents,label1=gender,label2=hasorder)
dv2_gs_w5.save('dv2_gs_w5.model')

# %%
from gensim.models.doc2vec import Doc2Vec
dv2_gs_w5= Doc2Vec.load('dv2_gs_w5.model')

# %% [markdown]
# ### Similar words comparison results -gender & not sanctioned

# %%
nsf = dv2_gs_w5.wv.most_similar(positive = [dv2_gs_w5.docvecs[0],dv2_gs_w5.docvecs['F']],topn=500)
nsm = dv2_gs_w5.wv.most_similar(positive = [dv2_gs_w5.docvecs[0],dv2_gs_w5.docvecs['M']],topn=500)
compare(list1=nsf,list2=nsm)
# Out:
# In F not in M: Words related with female doctors but didn't appear in male doctor's reviews
#
#               words  similarity_score_f
# 106        physical            0.288713
# 112    receptionist            0.284726
# 164         already            0.271491
# 169         thyroid            0.270010
# 181         usually            0.268503
# 219     examination            0.258559
# 233       listening            0.255653
# 234            hour            0.255313
# 236           front            0.254937
# 238      dismissive            0.254729
# 253            desk            0.251822
# 255             pcp            0.251494
# 270            seem            0.248322
# 271    disappointed            0.247977
# 279    prescription            0.247646
# 286      unfriendly            0.245871
# 289            hear            0.245332
# 292          looked            0.244632
# 293    appointments            0.244631
# 300         mention            0.243534
# 302   condescending            0.243448
# 308         willing            0.242851
# 309           point            0.242135
# 310            hard            0.242089
# 314        previous            0.241409
# 318       generally            0.240682
# 319         ordered            0.240619
# 320              pa            0.240406
# 327        provider            0.239290
# 330           worth            0.239033
# ..              ...                 ...
# 428        daughter            0.226275
# 430         appears            0.226246
# 433               x            0.226158
# 437            wish            0.225464
# 439       attention            0.225230
# 440  hypothyroidism            0.224884
# 444   prescriptions            0.224571
# 449      specialist            0.223735
# 451          weight            0.223403
# 452           twice            0.223368
# 453         focused            0.223352
# 455   comprehensive            0.223243
# 459      healthcare            0.222971
# 461       proactive            0.222602
# 468           quick            0.221482
# 470             try            0.221439
# 474             run            0.221260
# 476           worst            0.221107
# 479         records            0.220562
# 480        promptly            0.220253
# 483          anyway            0.219940
# 484       scheduled            0.219867
# 488        disorder            0.219355
# 489          rushes            0.219314
# 491         leaving            0.219264
# 492       necessary            0.219264
# 493            lack            0.219220
# 495            says            0.219102
# 496          normal            0.218882
# 498            girl            0.218860
#
# [98 rows x 2 columns]
#
# In M not in F: Words related with male doctors but didn't appear in female doctor's reviews
#
#             words  similarity_score_m
# 402         heart            0.300984
# 403      hospital            0.299545
# 404         saved            0.290644
# 405       skilled            0.275099
# 406  cardiologist            0.274160
# 407        father            0.272714
# 408      treating            0.270628
# 409     brilliant            0.269785
# 410         thank            0.266157
# 411        gentle            0.260361
# 412        treats            0.257514
# 413         human            0.257481
# 414         sense            0.257117
# 415          case            0.255415
# 416    procedures            0.255013
# 417        center            0.253825
# 418     procedure            0.251372
# 419            st            0.250370
# 420       clearly            0.249238
# 421        superb            0.248807
# 422       respect            0.248467
# 423           mom            0.247484
# 424     correctly            0.247072
# 425           god            0.247010
# 426        attack            0.243774
# 427      research            0.242371
# 428           job            0.242036
# 429        worked            0.241175
# 430         along            0.239840
# 431          body            0.239090
# ..            ...                 ...
# 470          five            0.223864
# 471         level            0.223677
# 472      husbands            0.223348
# 473       concern            0.223199
# 474  knowlegeable            0.222860
# 475           low            0.222575
# 476        showed            0.222517
# 477     effective            0.222426
# 478       quickly            0.222370
# 479     obviously            0.222205
# 480      admitted            0.222197
# 481           dad            0.222010
# 482         dealt            0.221823
# 483         sweet            0.221103
# 484          ease            0.220931
# 485         lucky            0.220835
# 486        proper            0.220822
# 487         cause            0.220805
# 488         clear            0.220698
# 489     expertise            0.220664
# 490           son            0.220559
# 491           set            0.220425
# 492        period            0.220024
# 493          kept            0.219740
# 494          glad            0.219710
# 495    profession            0.219706
# 496    diagnostic            0.219551
# 497         lived            0.219209
# 498         agree            0.218862
# 499      services            0.218656
#
# [98 rows x 2 columns]
#
# M>F: Similarity score of male doctors higher then that of female doctors
#
#            words  abs_diff
# 371    performed  0.082179
# 151      husband  0.081292
# 393  informative  0.074791
# 126          man  0.074453
# 378          guy  0.070463
# 28         great  0.065855
# 298         knew  0.064572
# 264          met  0.061033
# 32     excellent  0.060519
# 338      surgery  0.057605
# 273  outstanding  0.057319
# 257       family  0.055958
# 276          put  0.054837
# 224      disease  0.054674
# 365   thoughtful  0.053369
# 216       mother  0.050646
# 155         used  0.047924
# 122         life  0.046523
# 85       bedside  0.046264
# 196    condition  0.045120
# 340      treated  0.041385
# 47     recommend  0.040003
# 40   intelligent  0.038606
# 38     wonderful  0.038461
# 154     medicine  0.038078
# 290           us  0.037567
# 362  immediately  0.037184
# 145        smart  0.037082
# 357    explained  0.035901
# 313      awesome  0.035264
# ..           ...       ...
# 140       answer  0.004707
# 401         open  0.004673
# 263        three  0.004559
# 67           say  0.004530
# 25            go  0.004359
# 277       little  0.004342
# 333    genuinely  0.004117
# 99          help  0.004089
# 332    following  0.003802
# 305      talking  0.003433
# 114   everything  0.003212
# 286       clinic  0.002909
# 337       spends  0.002880
# 77          much  0.002745
# 198     anything  0.002513
# 354      despite  0.002504
# 330   complaints  0.002496
# 92        almost  0.002424
# 89           saw  0.002375
# 331          bit  0.002368
# 210        happy  0.001582
# 274        hours  0.001560
# 162    internist  0.000938
# 358          let  0.000823
# 110           md  0.000761
# 390   absolutely  0.000617
# 261     recently  0.000605
# 249        given  0.000537
# 183    diagnosis  0.000456
# 359     diagnose  0.000067
#
# [200 rows x 2 columns]
#
# F>M: Similarity score of female doctors higher then that of male doctors
#
#               words  abs_diff
# 83             appt  0.075459
# 52      appointment  0.075016
# 71            woman  0.068452
# 3            office  0.061504
# 96             exam  0.059074
# 139            cold  0.055551
# 156       assistant  0.054148
# 149           order  0.049241
# 130            wait  0.048978
# 119            past  0.048761
# 24           seeing  0.048568
# 158         someone  0.044798
# 117         minutes  0.044345
# 113             lab  0.044248
# 170            week  0.042942
# 45            nurse  0.042703
# 106        attitude  0.042263
# 213         instead  0.040476
# 118          taking  0.040188
# 111  unprofessional  0.039825
# 44             last  0.039467
# 9             never  0.038724
# 222      supportive  0.037787
# 65          answers  0.037702
# 128         current  0.037170
# 108          return  0.035845
# 14              see  0.035363
# 169           often  0.035343
# 146       something  0.035177
# 220          visits  0.034962
# ..              ...       ...
# 0                dr  0.003824
# 112            want  0.003700
# 82           health  0.003663
# 372            idea  0.003444
# 54            going  0.003397
# 204            warm  0.003350
# 59              may  0.003045
# 327           weeks  0.002914
# 13        extremely  0.002896
# 240       carefully  0.002441
# 133            love  0.002413
# 268            room  0.002307
# 68             said  0.002226
# 347           thing  0.002133
# 171         listens  0.002120
# 355            rare  0.002042
# 215        probably  0.001753
# 232       regarding  0.001696
# 379        question  0.001411
# 285      understand  0.001330
# 384            sick  0.001303
# 377            deal  0.001244
# 181           every  0.001172
# 239            true  0.001172
# 70             find  0.000992
# 30          doctors  0.000888
# 367          couple  0.000828
# 132             day  0.000469
# 86            still  0.000328
# 349         chronic  0.000249
#
# [202 rows x 2 columns]

# %% [markdown]
# ### Similar words comparison results -gender & sanctioned

# %%
sf = dv2_gs_w5.wv.most_similar(positive = [dv2_gs_w5.docvecs[1],dv2_gs_w5.docvecs['F']],topn=500)
sm = dv2_gs_w5.wv.most_similar(positive = [dv2_gs_w5.docvecs[1],dv2_gs_w5.docvecs['M']],topn=500)
compare(list1=sf,list2=sm)
# Out:
# In F not in M: Words related with female doctors but didn't appear in male doctor's reviews
#
#                words  similarity_score_f
# 118            lanna            0.206649
# 124     receptionist            0.205721
# 157          usually            0.199381
# 164            woman            0.198191
# 184     nutritionist            0.195768
# 200                ’            0.192536
# 213        paperwork            0.191271
# 216        headaches            0.191063
# 229       unfriendly            0.189317
# 238      examination            0.188523
# 246         physical            0.187940
# 249             temp            0.187619
# 257          posters            0.186580
# 259        migraines            0.186575
# 277         provider            0.184743
# 278           filled            0.184637
# 281         negative            0.184528
# 282              etc            0.184369
# 291          clinics            0.183674
# 297              sit            0.183152
# 298           return            0.182844
# 299             desk            0.182808
# 304              pcp            0.182375
# 305             last            0.182260
# 308              yes            0.181620
# 309          unheard            0.181537
# 310           prices            0.181425
# 317            fault            0.181009
# 320          finally            0.180539
# 327            clerk            0.179634
# ..               ...                 ...
# 432             appt            0.172146
# 433         friendly            0.171949
# 434        untreated            0.171836
# 442       responsive            0.171202
# 444           called            0.171008
# 446        narcotics            0.170877
# 447             says            0.170789
# 452          genuine            0.170044
# 455            shown            0.169933
# 460            trade            0.169709
# 462           anyway            0.169612
# 465          vitamin            0.169479
# 466            means            0.169455
# 472              sad            0.169067
# 473          someone            0.169016
# 476         violated            0.168629
# 477          changed            0.168485
# 478     prescription            0.168413
# 480              kim            0.168284
# 481          samples            0.168263
# 482          records            0.168249
# 485          reviews            0.167948
# 487             test            0.167536
# 488             look            0.167518
# 489            catch            0.167459
# 490             long            0.167412
# 492               ac            0.167354
# 493          pompous            0.167170
# 494  uncompassionate            0.167143
# 495      appointment            0.167075
#
# [106 rows x 2 columns]
#
# In M not in F: Words related with male doctors but didn't appear in female doctor's reviews
#
#                words  similarity_score_m
# 394         hospital            0.214873
# 395            saved            0.213212
# 396            night            0.209115
# 397              met            0.198785
# 398             quit            0.195452
# 399            heart            0.193710
# 400          disease            0.193496
# 401            death            0.192905
# 402           gentle            0.192100
# 403       practicing            0.188496
# 404              ama            0.185993
# 405           forced            0.185129
# 406              use            0.184509
# 407         treating            0.183671
# 408            sharp            0.183109
# 409        therapies            0.182893
# 410     approachable            0.182050
# 411         distress            0.180742
# 412  hospitalization            0.180668
# 413         attorney            0.180287
# 414             save            0.179843
# 415        courteous            0.179305
# 416           parent            0.179112
# 417             cell            0.177804
# 418            aside            0.177602
# 419              hes            0.177493
# 420         medicaid            0.177235
# 421      prescribing            0.176982
# 422        technical            0.176885
# 423              ago            0.176820
# ..               ...                 ...
# 470            alive            0.167887
# 471          nursing            0.167713
# 472             pull            0.167648
# 473          reminds            0.167620
# 474          several            0.167570
# 475          blocked            0.167276
# 476          consult            0.166978
# 477             case            0.166820
# 478            lower            0.166459
# 479       occassions            0.166409
# 480         admitted            0.166371
# 481       recognized            0.166091
# 482           states            0.166083
# 483             stay            0.166040
# 484        dangerous            0.166009
# 485           solved            0.165982
# 486           enough            0.165950
# 487        emergency            0.165862
# 488         greatful            0.165777
# 489           jersey            0.165767
# 490          nothing            0.165678
# 491           little            0.165647
# 492             open            0.165596
# 493           claims            0.165578
# 494        immediate            0.165015
# 495             kept            0.164960
# 496               gt            0.164951
# 497         charging            0.164854
# 498             busy            0.164744
# 499           george            0.164712
#
# [106 rows x 2 columns]
#
# M>F: Similarity score of male doctors higher then that of female doctors
#
#               words  abs_diff
# 45           father  0.053527
# 89          husband  0.049776
# 291             man  0.044953
# 135          pusher  0.044596
# 349      contracted  0.043952
# 288           great  0.038916
# 101           legal  0.037544
# 338            soft  0.035778
# 371       excellent  0.035540
# 293          family  0.034089
# 208             put  0.033650
# 102          mother  0.031268
# 378       gentleman  0.029959
# 352           thank  0.029252
# 191            used  0.029113
# 376            life  0.027721
# 294         bedside  0.027568
# 264          pulled  0.026838
# 373            legs  0.026785
# 369           human  0.026312
# 189         treated  0.025680
# 185        believes  0.025612
# 321          rating  0.025012
# 238            pill  0.024980
# 235        injuries  0.024812
# 387        required  0.023920
# 204            wise  0.023432
# 382       recommend  0.023282
# 314        medicine  0.022804
# 164       wonderful  0.022703
# ..              ...       ...
# 141            pain  0.003567
# 79                b  0.003283
# 345  administrative  0.003023
# 128       following  0.002970
# 31             help  0.002943
# 296   knowledgeable  0.002646
# 123             say  0.002496
# 14           almost  0.002235
# 388              fl  0.002011
# 93               go  0.001973
# 214         happens  0.001903
# 243           smile  0.001817
# 302          clinic  0.001815
# 72    consideration  0.001796
# 224          google  0.001664
# 104            much  0.001553
# 328        cheerful  0.001430
# 98         recently  0.000927
# 39               md  0.000890
# 356           hours  0.000846
# 75    inappropriate  0.000751
# 289      absolutely  0.000744
# 134         unknown  0.000669
# 364           happy  0.000647
# 154         chronic  0.000432
# 228         trouble  0.000379
# 81             four  0.000172
# 20            idiot  0.000154
# 370       illnesses  0.000124
# 318          beware  0.000064
#
# [199 rows x 2 columns]
#
# F>M: Similarity score of female doctors higher then that of male doctors
#
#               words  abs_diff
# 44           rarely  0.038411
# 1            office  0.037269
# 37             exam  0.035636
# 138        messages  0.034653
# 42            ahmed  0.034227
# 41               np  0.033552
# 124         earlier  0.032682
# 32            front  0.032522
# 46        assistant  0.032443
# 5              dube  0.032341
# 43            karen  0.032248
# 95             gray  0.032202
# 66          running  0.031913
# 57           seeing  0.030067
# 113          booked  0.029751
# 110            wait  0.029735
# 62            order  0.029600
# 121            hour  0.029417
# 144           susan  0.029336
# 36             past  0.029227
# 16             half  0.029104
# 38          mention  0.028254
# 176          worker  0.028080
# 22         comments  0.027822
# 169         minutes  0.027160
# 35            nurse  0.026008
# 160         hearing  0.025817
# 212           shots  0.024566
# 206    thoroughness  0.024308
# 133  unprofessional  0.024298
# ..              ...       ...
# 281      disrespect  0.002931
# 68            takes  0.002912
# 178             law  0.002877
# 25          quality  0.002766
# 240        diabetes  0.002730
# 76        extremely  0.002724
# 279             may  0.002605
# 265         benefit  0.002602
# 336           rehab  0.002348
# 74           health  0.002204
# 347            said  0.002202
# 196          school  0.002067
# 390           weeks  0.001822
# 346           loyal  0.001482
# 94            keeps  0.001437
# 143         doctors  0.001311
# 177            find  0.001026
# 305           style  0.000735
# 250           still  0.000712
# 18             love  0.000707
# 67             room  0.000689
# 184           alone  0.000550
# 192            true  0.000537
# 236             day  0.000533
# 226          charge  0.000375
# 77              via  0.000354
# 53          request  0.000199
# 172            sick  0.000151
# 350           holds  0.000093
# 343           finds  0.000059
#
# [195 rows x 2 columns]

# %% [markdown]
# ### Run Doc2vec - gender & sanction (downsampling)

# %%
d2v_gs_d_w5 = run_dov2vec_sampling(documents = documents, sampling = 207,label1=gender, label2=hasorder, gs=True)
d2v_gs_d_w5.save('d2v_gs_d_w5.model')

# %%
from gensim.models.doc2vec import Doc2Vec
d2v_gs_d_w5= Doc2Vec.load('d2v_gs_d_w5.model')

# %% [markdown]
# ### Similar words comparison results - gender & not sanctioned (downsampling)

# %%
nf1 = d2v_gs_d_w5.wv.most_similar(positive = [d2v_gs_d_w5.docvecs[0],d2v_gs_d_w5.docvecs['F']],topn=500)
nm1 = d2v_gs_d_w5.wv.most_similar(positive = [d2v_gs_d_w5.docvecs[0],d2v_gs_d_w5.docvecs['M']],topn=500)
compare(list1=nf1,list2=nm1)
# Out:
# In F not in M: Words related with female doctors but didn't appear in male doctor's reviews
#
#               words  similarity_score_f
# 14          leading            0.436143
# 17           intend            0.431944
# 20             hall            0.429882
# 24             isnt            0.427628
# 28          johnson            0.424631
# 42       deficiency            0.416994
# 43     pediatrician            0.416787
# 50          bizarre            0.413103
# 54       judgmental            0.411116
# 61             card            0.407950
# 62     communicator            0.407126
# 64           obtain            0.406389
# 70    communicating            0.403970
# 74              hey            0.403596
# 76        unrelated            0.402675
# 80          decades            0.402256
# 87            cigna            0.401301
# 89      responsible            0.401178
# 95   understandable            0.400275
# 105            hurt            0.398010
# 108         sounded            0.397712
# 112      threatened            0.397084
# 120           goals            0.393940
# 121            liar            0.393600
# 123         explore            0.393493
# 124       overheard            0.393447
# 125          shield            0.393396
# 128           grasp            0.393256
# 132         covered            0.390801
# 134             lay            0.390281
# ..              ...                 ...
# 445           straw            0.344540
# 446        tempered            0.344523
# 448           susan            0.344503
# 455   complications            0.343289
# 456          utmost            0.343055
# 459       performed            0.342656
# 464            rely            0.341931
# 465  administrative            0.341899
# 466         becomes            0.341897
# 469          states            0.341288
# 470          sample            0.341277
# 471           clear            0.341272
# 472           pills            0.341241
# 473    satisfactory            0.341058
# 477       remembers            0.340928
# 478            mild            0.340733
# 480            sort            0.340541
# 481   extraordinary            0.340471
# 482      internists            0.340461
# 483          warmth            0.340279
# 484     examination            0.340216
# 485         persons            0.340156
# 486           words            0.340056
# 487    subsequently            0.339874
# 488      hesitation            0.339808
# 492           feels            0.339679
# 493        finished            0.339590
# 495         central            0.339369
# 496        specific            0.339344
# 497           older            0.339099
#
# [211 rows x 2 columns]
#
# In M not in F: Words related with male doctors but didn't appear in female doctor's reviews
#
#              words  similarity_score_m
# 289       greatful            0.427847
# 290      elizabeth            0.425493
# 291    intimidated            0.424771
# 292       surgeons            0.413884
# 293         keeper            0.412766
# 294        glucose            0.409907
# 295  colonoscopies            0.408208
# 296            boy            0.406753
# 297        godsend            0.404992
# 298        abusive            0.404556
# 299      therapist            0.402166
# 300   consultation            0.400994
# 301      completed            0.398787
# 302       pregnant            0.397076
# 303       absolute            0.396299
# 304       american            0.395248
# 305    exceptional            0.394775
# 306          began            0.392777
# 307            hep            0.392003
# 308         former            0.390778
# 309   specifically            0.390277
# 310        survive            0.389318
# 311        upfront            0.389187
# 312             ya            0.388514
# 313     depression            0.387549
# 314        whoever            0.384216
# 315        hearted            0.383962
# 316      healthier            0.383851
# 317      pacemaker            0.383411
# 318          loves            0.382815
# ..             ...                 ...
# 470            bar            0.344533
# 471           clue            0.344231
# 472       language            0.344161
# 473          ready            0.343653
# 474      apologies            0.342887
# 475         genius            0.342553
# 476     remarkable            0.342065
# 477        amongst            0.341881
# 478       brooklyn            0.341341
# 479          silly            0.341340
# 480       grateful            0.340831
# 481   cardiologist            0.340675
# 482      unethical            0.340452
# 483        picture            0.340445
# 484          spine            0.340445
# 485        mention            0.340091
# 486    experienced            0.339826
# 487       severely            0.339611
# 488    individuals            0.339496
# 489        operate            0.339258
# 490        perfect            0.339146
# 491         gastro            0.338944
# 492       followed            0.338409
# 493              f            0.338133
# 494           plus            0.338131
# 495    practically            0.338060
# 496        passion            0.338041
# 497   complication            0.337939
# 498          value            0.337835
# 499           tend            0.337569
#
# [211 rows x 2 columns]
#
# M>F: Similarity score of male doctors higher then that of female doctors
#
#              words  abs_diff
# 270       reminded  0.081886
# 280          stiff  0.077555
# 283         target  0.073206
# 220    helpfulness  0.069749
# 261        require  0.066687
# 273           foot  0.065677
# 287       strongly  0.065342
# 204         crisis  0.062258
# 266        program  0.060188
# 197         public  0.055809
# 258       addition  0.055194
# 271          inept  0.053844
# 237           acts  0.051884
# 67        provider  0.048978
# 227          shame  0.046800
# 219          truth  0.044211
# 267       oriented  0.043447
# 96            lord  0.042476
# 286       thankful  0.040761
# 272        happier  0.040456
# 275        choices  0.040115
# 121         stupid  0.037903
# 186            aid  0.037844
# 128        setting  0.037066
# 251     whatsoever  0.036597
# 288        highest  0.036548
# 268     explaining  0.036217
# 252          rough  0.035302
# 233        atleast  0.034876
# 171       retiring  0.034204
# ..             ...       ...
# 269           sees  0.010116
# 229        intense  0.008824
# 232       approved  0.008341
# 264        benefit  0.008328
# 191        killers  0.008255
# 177      internist  0.008201
# 282       surgical  0.007734
# 146  conscientious  0.007298
# 211          cried  0.007041
# 141         values  0.005853
# 203             tv  0.005683
# 89             ive  0.005586
# 242          foods  0.005398
# 247          sales  0.005202
# 205          colon  0.005023
# 145  inexperienced  0.004725
# 209           iron  0.003996
# 63          staffs  0.003538
# 127    neurologist  0.003343
# 154     transplant  0.002947
# 262     frustrated  0.002595
# 192          plain  0.002528
# 260        chaotic  0.001578
# 263     suggesting  0.001513
# 216     empathetic  0.001335
# 173         length  0.001292
# 57        vacation  0.001154
# 110      incorrect  0.000897
# 119    desperately  0.000805
# 134        selling  0.000720
#
# [124 rows x 2 columns]
#
# F>M: Similarity score of female doctors higher then that of male doctors
#
#              words  abs_diff
# 3          walking  0.093153
# 1           smiley  0.093095
# 14      washington  0.091375
# 12       practiced  0.087135
# 23   exceptionally  0.085107
# 22         pushing  0.083146
# 27        relative  0.079090
# 24             key  0.077798
# 11            vist  0.074369
# 6        arrogance  0.073522
# 44      apologized  0.070921
# 47            safe  0.070757
# 28          minded  0.070712
# 17           hears  0.069912
# 51           posts  0.069344
# 26       pneumonia  0.068760
# 30      introduced  0.066771
# 0            lacks  0.063743
# 34      researched  0.063409
# 25      deductible  0.062434
# 70           share  0.061070
# 2         skillful  0.060834
# 4        effective  0.058671
# 20          online  0.054759
# 97         morning  0.054361
# 65         trained  0.054151
# 82           stone  0.051420
# 19         whether  0.051061
# 7       eventually  0.050545
# 48              gi  0.049761
# ..             ...       ...
# 156     beneficial  0.006531
# 246           till  0.006440
# 101              q  0.006286
# 257       abnormal  0.006172
# 174       curtious  0.006025
# 235     associated  0.005523
# 250      motivated  0.005386
# 139         vitals  0.005026
# 249       pleasent  0.004876
# 187    appreciated  0.004679
# 112     delightful  0.004429
# 256         pierce  0.004157
# 255         moving  0.004030
# 253      paperwork  0.003986
# 241        longest  0.003858
# 124            ice  0.003669
# 131     originally  0.003493
# 150      realistic  0.003209
# 281              b  0.003208
# 46      meticulous  0.002744
# 32       doctoring  0.002592
# 234           term  0.001917
# 64       attempted  0.001636
# 254         recent  0.001428
# 265        managed  0.001297
# 168       shoulder  0.001278
# 118        periods  0.001142
# 181          fears  0.000426
# 206          notch  0.000352
# 217      hopefully  0.000307
#
# [165 rows x 2 columns]

# %% [markdown]
# ### Similar words comparison results - gender & sanctioned (downsampling)

# %%
sf1 = d2v_gs_d_w5.wv.most_similar(positive = [d2v_gs_d_w5.docvecs[1],d2v_gs_d_w5.docvecs['F']],topn=500)
sm1 = d2v_gs_d_w5.wv.most_similar(positive = [d2v_gs_d_w5.docvecs[1],d2v_gs_d_w5.docvecs['M']],topn=500)
compare(list1=sf1,list2=sm1)
# Out:
# In F not in M: Words related with female doctors but didn't appear in male doctor's reviews
#
#               words  similarity_score_f
# 3        tremendous            0.459889
# 8             trash            0.448854
# 12           wasted            0.445547
# 14          decades            0.443940
# 17           annual            0.435510
# 20             hurt            0.434415
# 22          judging            0.433095
# 23            rater            0.432920
# 25          science            0.432663
# 27          johnson            0.432056
# 28        unrelated            0.431723
# 31      interaction            0.429384
# 32        excellant            0.428766
# 34            terms            0.428347
# 35             sort            0.428239
# 36        practiced            0.427732
# 38       introduced            0.426723
# 40        defensive            0.426034
# 42            goals            0.425150
# 44           mental            0.424477
# 45              mad            0.423368
# 46          becomes            0.423250
# 47            heads            0.422111
# 49          bizarre            0.421734
# 52            vital            0.420927
# 54           aspect            0.420556
# 56         disagree            0.419998
# 57       considered            0.419619
# 58             tone            0.419465
# 60        receptive            0.418733
# ..              ...                 ...
# 446             til            0.357107
# 448       bothering            0.357000
# 449         workers            0.356956
# 450         towards            0.356872
# 452      inaccurate            0.356663
# 453           watch            0.356473
# 454       referring            0.356440
# 456         whether            0.356033
# 457         imagine            0.355971
# 458          regret            0.355651
# 459       medically            0.355506
# 460            hate            0.355294
# 462         returns            0.355048
# 463      deficiency            0.354847
# 465        squeezed            0.354764
# 466  responsibility            0.354717
# 468       intuitive            0.354695
# 469          opened            0.354669
# 471         dignity            0.354425
# 472     forthcoming            0.354382
# 473       abandoned            0.354373
# 477          served            0.353958
# 478      university            0.353900
# 484           fraud            0.353335
# 485            hall            0.353266
# 489      sufficient            0.352872
# 490         referal            0.352693
# 492       reccomend            0.352311
# 493        vacation            0.352266
# 498     appreciated            0.351752
#
# [296 rows x 2 columns]
#
# In M not in F: Words related with male doctors but didn't appear in female doctor's reviews
#
#                 words  similarity_score_m
# 204               hep            0.455682
# 205             valve            0.443498
# 206            counts            0.439600
# 207              spot            0.438836
# 208  gastroenterology            0.435871
# 209            keeper            0.435629
# 210      consistently            0.430957
# 211             saver            0.429727
# 212        competence            0.429541
# 213              hole            0.425295
# 214            robert            0.425183
# 215            heaven            0.424938
# 216            miller            0.422642
# 217             kelly            0.421291
# 218              clue            0.420909
# 219               sat            0.420435
# 220               bar            0.419793
# 221           upfront            0.419458
# 222          performs            0.419398
# 223               lbs            0.418177
# 224            island            0.417917
# 225        statements            0.417820
# 226          terrific            0.417394
# 227      improvements            0.415861
# 228           stepped            0.415361
# 229         elizabeth            0.414613
# 230          greatful            0.412676
# 231         irritated            0.412545
# 232              kill            0.411649
# 233       complaining            0.410700
# ..                ...                 ...
# 470         witnessed            0.363275
# 471               cry            0.363271
# 472            doctor            0.363174
# 473        remarkable            0.362935
# 474            causes            0.362933
# 475            approx            0.362809
# 476         apologies            0.362799
# 477         listening            0.362676
# 478            market            0.362663
# 479           changes            0.362588
# 480          lawrence            0.362198
# 481           greeted            0.362040
# 482           arrival            0.361966
# 483             candy            0.361743
# 484             backs            0.361527
# 485            solved            0.361522
# 486            friday            0.361430
# 487         irritable            0.361112
# 488           keeping            0.360743
# 489           happier            0.360737
# 490            coming            0.360667
# 491              anti            0.360513
# 492             draws            0.360436
# 493          discover            0.360061
# 494             shots            0.359937
# 495          managing            0.359774
# 496           mistake            0.359358
# 497              hung            0.359189
# 498           whoever            0.359142
# 499        convenient            0.358870
#
# [296 rows x 2 columns]
#
# M>F: Similarity score of male doctors higher then that of female doctors
#
#              words  abs_diff
# 148     negligence  0.084423
# 128          spoke  0.080211
# 187         artery  0.078151
# 192             ca  0.073875
# 199       whenever  0.073748
# 183        remains  0.073159
# 101        staying  0.070347
# 200        ignored  0.069714
# 179        methods  0.068876
# 131       provider  0.067427
# 175    rescheduled  0.065466
# 195          arise  0.064574
# 196       thankful  0.062520
# 138   complication  0.060696
# 46            mark  0.060154
# 119     whatsoever  0.059997
# 162           lord  0.058535
# 142          rough  0.057070
# 55          direct  0.054473
# 178        operate  0.053149
# 129         headed  0.052500
# 49       wednesday  0.051570
# 147          hopes  0.051565
# 74            wise  0.048163
# 158     affiliated  0.047819
# 188       cautious  0.046585
# 170  disappointing  0.046248
# 139          leads  0.045825
# 109          beach  0.043942
# 53        critical  0.042369
# ..             ...       ...
# 51       realistic  0.009833
# 155         recent  0.009702
# 97          decade  0.009457
# 132         staffs  0.009437
# 149           draw  0.008951
# 194           scam  0.008864
# 203      hopefully  0.007462
# 32       doctoring  0.006959
# 110        periods  0.006905
# 141        longest  0.006725
# 130       pleasent  0.006398
# 184      screaming  0.005191
# 95     proceedures  0.005190
# 43            rule  0.005009
# 181       shoulder  0.004912
# 3            aetna  0.004689
# 157         insure  0.004650
# 186         pierce  0.004533
# 86      delightful  0.004347
# 85          vitals  0.004298
# 151       horribly  0.004249
# 79      beneficial  0.003651
# 161     associated  0.003514
# 65               q  0.002808
# 163           jack  0.001412
# 91      internists  0.001361
# 59        sleeping  0.001354
# 62         perform  0.000865
# 31           pushy  0.000393
# 84         closely  0.000046
#
# [120 rows x 2 columns]
#
# F>M: Similarity score of female doctors higher then that of male doctors
#
#               words  abs_diff
# 0               hey  0.094627
# 9    unknowledgable  0.084678
# 6              vist  0.081648
# 1             lobby  0.077327
# 4        judgmental  0.077080
# 2             enemy  0.076774
# 8               box  0.075896
# 15      discussions  0.074166
# 18         skillful  0.070634
# 22      unsatisfied  0.065651
# 5         responded  0.060917
# 33        personnel  0.050835
# 36         finished  0.050679
# 13            eight  0.050082
# 38            reply  0.046835
# 34          dressed  0.046723
# 28           travel  0.046553
# 12         reflects  0.046109
# 14           remind  0.045251
# 7            unique  0.042774
# 50             free  0.041020
# 11     investigated  0.040875
# 44           loudly  0.037288
# 58            pills  0.035774
# 10           billed  0.035465
# 70          retires  0.034579
# 41       hesitation  0.034245
# 40      unorganized  0.033513
# 30       intestinal  0.032401
# 83         reliable  0.032230
# ..              ...       ...
# 66            threw  0.014850
# 107        physcian  0.013338
# 54           factor  0.012968
# 106         private  0.012848
# 37         feedback  0.011608
# 45            model  0.011589
# 75            fired  0.010761
# 87            final  0.010729
# 94             duty  0.010024
# 93      credentials  0.009973
# 112           clerk  0.008695
# 133             ekg  0.008051
# 76      importantly  0.006362
# 92           warmth  0.006168
# 19        proactive  0.005974
# 137         laughed  0.005935
# 99           member  0.005852
# 57                v  0.005428
# 100           pages  0.003987
# 127     trustworthy  0.003830
# 153        charging  0.003113
# 24         regarded  0.002759
# 80           awhile  0.002577
# 25       recomended  0.001717
# 61             ages  0.001692
# 96       technology  0.001547
# 140          pounds  0.001254
# 144         collect  0.001040
# 63            enjoy  0.000936
# 116        realized  0.000080
#
# [84 rows x 2 columns]

# %% [markdown]
# ### Run Doc2vec - gender & sanction (upsampling)

# %%
d2v_gs_up_w5 = run_dov2vec_sampling(documents = documents, sampling = 1000,label1=gender, label2=hasorder, gs=True)
d2v_gs_up_w5.save('d2v_gs_up_w5.model')

# %%
from gensim.models.doc2vec import Doc2Vec
d2v_gs_up_w5= Doc2Vec.load('d2v_gs_up_w5.model')

# %% [markdown]
# ### Similar words comparison results - gender & not sanctioned (upsampling)

# %%
nf2 = d2v_gs_up_w5.wv.most_similar(positive = [d2v_gs_up_w5.docvecs[0],d2v_gs_up_w5.docvecs['F']],topn=500)
nm2 = d2v_gs_up_w5.wv.most_similar(positive = [d2v_gs_up_w5.docvecs[0],d2v_gs_up_w5.docvecs['M']],topn=500)
compare(list1=nf2,list2=nm2)
# Out:
# In F not in M: Words related with female doctors but didn't appear in male doctor's reviews
#
#               words  similarity_score_f
# 0          majority            0.445555
# 8        confronted            0.416596
# 9            social            0.414981
# 13              men            0.412349
# 20           aspect            0.406052
# 27          explore            0.400062
# 28       situations            0.399918
# 30      depressants            0.399382
# 32           effort            0.398453
# 33    uncooperative            0.398089
# 35       accurately            0.395829
# 36             sold            0.395200
# 39        insisting            0.393358
# 41          watched            0.392004
# 43       overlooked            0.391099
# 44              mad            0.390607
# 45        completed            0.390544
# 46       documented            0.390456
# 48           relies            0.389407
# 50       judgmental            0.388552
# 51         mannered            0.388477
# 52            ankle            0.388449
# 53        introduce            0.388287
# 55        sarcastic            0.386734
# 56             cuts            0.386491
# 58            polyp            0.386226
# 60        cancerous            0.385930
# 61          delayed            0.385554
# 62     specifically            0.385363
# 65           beings            0.384454
# ..              ...                 ...
# 457      accomodate            0.324481
# 458             esp            0.324470
# 460           track            0.324202
# 461           virus            0.324166
# 467             kim            0.323619
# 468           catch            0.323529
# 470        relative            0.323257
# 472          google            0.323225
# 473          arrive            0.323211
# 474         nowhere            0.323191
# 475            page            0.323151
# 477          plenty            0.322895
# 478             tom            0.322713
# 479      originally            0.322586
# 480            butt            0.322423
# 481  administrative            0.322411
# 482            shes            0.322317
# 484            onto            0.322269
# 485           santa            0.322248
# 486       discharge            0.322208
# 487           ahmad            0.322001
# 489         walking            0.321990
# 490       intuitive            0.321903
# 491         journey            0.321893
# 492           threw            0.321887
# 493      internists            0.321868
# 494        episodes            0.321853
# 495        relevant            0.321711
# 496            fell            0.321690
# 497         mothers            0.321616
#
# [292 rows x 2 columns]
#
# In M not in F: Words related with male doctors but didn't appear in female doctor's reviews
#
#              words  similarity_score_m
# 208        rapport            0.457205
# 209        survive            0.452545
# 210            hes            0.447838
# 211     washington            0.446084
# 212           gift            0.439920
# 213       charming            0.437714
# 214          equal            0.435932
# 215   tremendously            0.434967
# 216            cfs            0.429150
# 217         career            0.428873
# 218           tune            0.424996
# 219       articles            0.424817
# 220        miracle            0.423105
# 221          guide            0.420709
# 222          vital            0.420446
# 223            til            0.417292
# 224       national            0.416497
# 225        caution            0.416265
# 226         verify            0.416265
# 227   instrumental            0.414445
# 228          added            0.414436
# 229          hated            0.412299
# 230        counter            0.410210
# 231      wednesday            0.410174
# 232     bronchitis            0.409823
# 233           mood            0.409761
# 234         bigger            0.409612
# 235          craft            0.408872
# 236      preferred            0.408787
# 237   conventional            0.407113
# ..             ...                 ...
# 470         chatty            0.356896
# 471         idiots            0.356772
# 472         judged            0.356484
# 473     recovering            0.356432
# 474      skeptical            0.355971
# 475        hanging            0.355956
# 476    potentially            0.355936
# 477           aged            0.355903
# 478        prepare            0.355886
# 479        choices            0.355803
# 480          renal            0.355309
# 481      referring            0.355174
# 482  unsympathetic            0.355092
# 483      extensive            0.355048
# 484           warn            0.354873
# 485      employees            0.354585
# 486     dismissing            0.354572
# 487       addicted            0.354546
# 488    responsible            0.354468
# 489       nowadays            0.354409
# 490       guessing            0.354068
# 491    knowledable            0.353723
# 492            std            0.353638
# 493     remarkable            0.353478
# 494      advantage            0.353180
# 495       lifetime            0.353134
# 496   friendliness            0.353063
# 497         option            0.353017
# 498         cattle            0.352985
# 499         starts            0.352850
#
# [292 rows x 2 columns]
#
# M>F: Similarity score of male doctors higher then that of female doctors
#
#               words  abs_diff
# 142     resourceful  0.125439
# 158         chicago  0.119403
# 173    consequences  0.113080
# 159           picky  0.112455
# 51              pat  0.107149
# 171           relax  0.106542
# 127          shared  0.106308
# 153   accommodating  0.103850
# 166      pleasantly  0.098045
# 143       doctoring  0.094441
# 125           leads  0.093502
# 104            laid  0.093285
# 21          screwed  0.090546
# 194            beat  0.089448
# 102         equally  0.088811
# 204          ailing  0.087835
# 191          proved  0.084569
# 113       according  0.080486
# 176    northwestern  0.078729
# 121      affiliated  0.077883
# 133          keeper  0.076972
# 138       willingly  0.076298
# 144       apologies  0.075631
# 87     consultation  0.075151
# 117         cordial  0.074714
# 4              mark  0.074474
# 149     possibility  0.071630
# 197             shy  0.071102
# 86          william  0.070174
# 199           abuse  0.069830
# ..              ...       ...
# 147           mails  0.020502
# 101               j  0.020253
# 105         advises  0.018935
# 82         discount  0.018863
# 25   disappointment  0.018745
# 136           straw  0.018655
# 7     inexperienced  0.017926
# 141   disappointing  0.017859
# 17             tops  0.017836
# 34           workup  0.017578
# 122      identified  0.016679
# 140            lazy  0.016432
# 14           gifted  0.016427
# 11     investigated  0.013644
# 61       associated  0.012933
# 115             red  0.012825
# 116           lived  0.012029
# 103    accomodating  0.011964
# 111    hypertension  0.011209
# 120       reporting  0.009513
# 69           hungry  0.009450
# 107           mayer  0.008959
# 44         released  0.008015
# 98        intensive  0.005270
# 18             blew  0.002934
# 29          success  0.002472
# 83          dressed  0.002156
# 62            trade  0.002127
# 38            rough  0.002043
# 80         compared  0.000424
#
# [170 rows x 2 columns]
#
# F>M: Similarity score of female doctors higher then that of male doctors
#
#            words  abs_diff
# 1       strictly  0.079258
# 12      intently  0.054754
# 8       includes  0.051996
# 6         becker  0.051332
# 5          gruff  0.048500
# 9           mass  0.044441
# 20        denied  0.042610
# 2      graduated  0.041678
# 26   unsatisfied  0.039022
# 10        closer  0.035901
# 13       jumping  0.034013
# 22      abrasive  0.033236
# 33          mild  0.033203
# 24         whats  0.032170
# 30          liar  0.031684
# 28          join  0.026100
# 41      disaster  0.023989
# 39   judgemental  0.020210
# 3      confirmed  0.019971
# 53           beg  0.017697
# 27   established  0.017188
# 15       manages  0.015585
# 35       america  0.014950
# 63       decades  0.014846
# 57     irritated  0.013417
# 59         deals  0.011878
# 70     desperate  0.011725
# 65       gaining  0.011069
# 32            az  0.008719
# 37      thoughts  0.008004
# 54   progressive  0.005384
# 50      vacation  0.003684
# 76         ideas  0.003359
# 31        beware  0.001420
# 19   angioplasty  0.001050
# 94           huh  0.000881
# 91        profit  0.000847
# 49  pancreatitis  0.000011

# %% [markdown]
# ### Similar words comparison results - gender & sanctioned (upsampling)

# %%
sf2 = d2v_gs_up_w5.wv.most_similar(positive = [d2v_gs_up_w5.docvecs[1],d2v_gs_up_w5.docvecs['F']],topn=500)
sm2 = d2v_gs_up_w5.wv.most_similar(positive = [d2v_gs_up_w5.docvecs[1],d2v_gs_up_w5.docvecs['M']],topn=500)
compare(list1=sf2,list2=sm2)
# Out:
# In F not in M: Words related with female doctors but didn't appear in male doctor's reviews
#
#              words  similarity_score_f
# 14            tone            0.410024
# 15        bringing            0.408603
# 18         central            0.406278
# 19            curt            0.405905
# 21       introduce            0.403195
# 23          parent            0.401513
# 26             esp            0.399527
# 27        hundreds            0.399150
# 45           tears            0.387048
# 46           pulse            0.386373
# 48    expectations            0.383971
# 49         explore            0.383591
# 51         hateful            0.382987
# 52            cuts            0.382366
# 58          aspect            0.378763
# 61       responses            0.378533
# 63     unconcerned            0.378117
# 65    pediatrician            0.377963
# 66         removal            0.376951
# 67         stating            0.376631
# 72          energy            0.375224
# 75             pas            0.372348
# 78         unhappy            0.371222
# 79         watched            0.370430
# 80           rater            0.369864
# 85           paper            0.368355
# 90              ms            0.366272
# 91      confronted            0.365496
# 93       discharge            0.365197
# 94        stronger            0.364626
# ..             ...                 ...
# 448      angiogram            0.310863
# 450  uncooperative            0.310551
# 452         excess            0.310016
# 453       relevant            0.309809
# 457         dumped            0.309051
# 458         temper            0.308941
# 460        manages            0.308670
# 461          block            0.308529
# 462        salvato            0.308406
# 466     inaccurate            0.307968
# 468    essentially            0.307946
# 469     unbearable            0.307933
# 470    interrupted            0.307772
# 471      bothering            0.307754
# 472            tom            0.307644
# 474     controlled            0.307507
# 477          viral            0.307373
# 478          chair            0.307285
# 479          urine            0.307228
# 481     insurances            0.307049
# 482         endure            0.306929
# 485        educate            0.306839
# 487      insulting            0.306506
# 490     internists            0.306098
# 494            wit            0.305364
# 495   perscription            0.305361
# 496   preventative            0.305222
# 497         decent            0.305121
# 498  communicating            0.305121
# 499   debilitating            0.304816
#
# [204 rows x 2 columns]
#
# In M not in F: Words related with male doctors but didn't appear in female doctor's reviews
#
#             words  similarity_score_m
# 296      articles            0.441024
# 297      charming            0.435527
# 298        afford            0.430279
# 299       rapport            0.424961
# 300        judged            0.424166
# 301      downside            0.412749
# 302        healer            0.411791
# 303          hole            0.401241
# 304    supporting            0.401066
# 305       letting            0.399439
# 306         solid            0.399101
# 307         shock            0.395498
# 308        counts            0.394378
# 309       clothes            0.393234
# 310      injuries            0.389691
# 311        bigger            0.387648
# 312  tremendously            0.387271
# 313       survive            0.386961
# 314           hes            0.386311
# 315       planned            0.385504
# 316  instrumental            0.383496
# 317      machines            0.383044
# 318         loses            0.381569
# 319     improving            0.381452
# 320        robert            0.381233
# 321         equal            0.379751
# 322        chatty            0.379129
# 323        heaven            0.379082
# 324    remarkable            0.378960
# 325  consequences            0.378602
# ..            ...                 ...
# 470      shopping            0.329213
# 471      biopsies            0.329096
# 472        ailing            0.328936
# 473          tend            0.328594
# 474       obesity            0.328568
# 475           dog            0.328500
# 476   possibility            0.328451
# 477  complication            0.328305
# 478       ongoing            0.328249
# 479        cattle            0.328245
# 480         stops            0.328242
# 481         dozen            0.327942
# 482          jack            0.327788
# 483         vital            0.327705
# 484    assistants            0.327674
# 485        prefer            0.327556
# 486         faith            0.326996
# 487        miller            0.326899
# 488          hang            0.326542
# 489  consultation            0.326492
# 490         means            0.326461
# 491       scripts            0.326398
# 492   researching            0.326304
# 493        excuse            0.326304
# 494         pages            0.326028
# 495        single            0.326016
# 496        messed            0.325990
# 497          shot            0.325940
# 498           std            0.325447
# 499     qualities            0.325297
#
# [204 rows x 2 columns]
#
# M>F: Similarity score of male doctors higher then that of female doctors
#
#               words  abs_diff
# 220           candy  0.130233
# 271        incident  0.130124
# 223     embarrassed  0.126119
# 171            fool  0.103748
# 46            beach  0.101757
# 143    friendliness  0.101574
# 275        physcian  0.100799
# 273          passes  0.099544
# 263            oral  0.097076
# 230              gt  0.096906
# 248            xray  0.096704
# 117            gift  0.095600
# 96        bloodwork  0.091657
# 279         million  0.090465
# 138     resourceful  0.089662
# 179          israel  0.088422
# 169        retiring  0.086021
# 232           kudos  0.084889
# 130       considers  0.084383
# 39           verify  0.082962
# 170             hep  0.081838
# 239             tho  0.081518
# 214     emergencies  0.080807
# 215            vein  0.079145
# 294          austin  0.078600
# 236    condesending  0.077756
# 160       healthier  0.077555
# 240           picky  0.076087
# 221            step  0.076002
# 27        wednesday  0.075512
# ..              ...       ...
# 210           rates  0.011317
# 89         pleasent  0.010832
# 183              ga  0.010218
# 195        cheerful  0.009645
# 101         connect  0.008861
# 234       daughters  0.008676
# 114     unfortunate  0.008555
# 42         familiar  0.008381
# 147             sub  0.007540
# 159      implicitly  0.006936
# 77           vitals  0.006610
# 206     challenging  0.006497
# 153           adult  0.006429
# 58            sadly  0.006393
# 184          rudely  0.005950
# 211          handed  0.005506
# 194        language  0.005459
# 56         training  0.005391
# 139       dismisses  0.004944
# 185         closing  0.004926
# 216        overbook  0.004579
# 144         engaged  0.004144
# 86         engaging  0.003564
# 63         valuable  0.003454
# 100               j  0.002517
# 97        breathing  0.001909
# 82            gross  0.001897
# 165           threw  0.001291
# 190  administrative  0.000845
# 212              mi  0.000753
#
# [222 rows x 2 columns]
#
# F>M: Similarity score of female doctors higher then that of male doctors
#
#               words  abs_diff
# 2          majority  0.105060
# 6               men  0.087664
# 0        judgmental  0.082347
# 9          disagree  0.081889
# 14           method  0.073985
# 15    perscriptions  0.069441
# 17          shocked  0.067754
# 8            becker  0.059505
# 36               ya  0.056914
# 11             lump  0.056102
# 3             gruff  0.054685
# 49          jumping  0.050480
# 21        overnight  0.048225
# 20      unsatisfied  0.047716
# 28         position  0.047316
# 26            susan  0.044991
# 4               mad  0.042770
# 10             mild  0.038402
# 22             join  0.037069
# 29            brand  0.035562
# 38           pusher  0.034638
# 59            favor  0.034544
# 32         tomorrow  0.030119
# 83          decades  0.029568
# 78           lovely  0.029379
# 18      judgemental  0.029339
# 64            pushy  0.028673
# 53       antibiotic  0.026640
# 54               az  0.025510
# 61        desperate  0.025329
# ..              ...       ...
# 158          billed  0.012335
# 136            butt  0.011771
# 47              huh  0.011680
# 107          vision  0.010555
# 135          joints  0.010482
# 95        intensive  0.010210
# 125       traveling  0.009827
# 34     investigated  0.009618
# 68             tops  0.008826
# 84             temp  0.008386
# 41           gifted  0.008354
# 105           track  0.007600
# 33         released  0.007443
# 168    hypertension  0.007279
# 123       obnoxious  0.006516
# 70   disappointment  0.006176
# 74           winter  0.005442
# 112         alcohol  0.004564
# 120           lived  0.004514
# 187        discount  0.004025
# 75        overheard  0.003993
# 12    inexperienced  0.002633
# 192           noted  0.002561
# 25        medically  0.002050
# 126       receptive  0.001995
# 30       associated  0.001865
# 151      identified  0.001359
# 122             dar  0.000897
# 154            lazy  0.000763
# 50     accomodating  0.000428
#
# [74 rows x 2 columns]

# %% [markdown]
# ### Run Doc2vec for gender & sanction using one label

# %%
d2v_gs_l_w5 = run_dov2vec_sampling(documents = documents,label1=label)
d2v_gs_l_w5.save('d2v_gs_l_w5.model')

# %%
from gensim.models.doc2vec import Doc2Vec
d2v_gs_l_w5= Doc2Vec.load('d2v_gs_l_w5.model')

# %% [markdown]
# ### Similar words comparison results - gender & not sanction (using one label)

# %%
f0 = d2v_gs_l_w5.wv.most_similar(positive = [d2v_gs_l_w5.docvecs['F0']],topn=500)
m0 = d2v_gs_l_w5.wv.most_similar(positive = [d2v_gs_l_w5.docvecs['M0']],topn=500)
compare(list1=f0,list2=m0)
# Out:
# In F not in M: Words related with female doctors but didn't appear in male doctor's reviews
#
#               words  similarity_score_f
# 34      appointment            0.294882
# 45            woman            0.282115
# 65     receptionist            0.272076
# 67        assistant            0.271823
# 72        listening            0.266960
# 74          usually            0.265037
# 80         physical            0.262531
# 82          thyroid            0.262146
# 83   unprofessional            0.262057
# 85             cold            0.260616
# 87             appt            0.260135
# 89          someone            0.259809
# 91            often            0.259738
# 93           return            0.259388
# 96            front            0.258879
# 99      examination            0.258362
# 111           order            0.255164
# 114         focused            0.254047
# 122        previous            0.252077
# 127            hour            0.250675
# 129            desk            0.249595
# 131          taking            0.249107
# 137      dismissive            0.247245
# 145    appointments            0.244798
# 155            past            0.241571
# 168    prescription            0.238772
# 178         already            0.236541
# 180        holistic            0.236172
# 187           spend            0.234387
# 188               ’            0.234272
# ..              ...                 ...
# 456            endo            0.195704
# 460           bring            0.195153
# 461     experiences            0.195125
# 464           weeks            0.194819
# 465          turned            0.194646
# 467           chang            0.194399
# 468        multiple            0.194379
# 469       mentioned            0.194374
# 473            gets            0.194151
# 474            lady            0.194136
# 475    inconsistent            0.193996
# 476         private            0.193993
# 477         finding            0.193985
# 478             pap            0.193905
# 479             sit            0.193895
# 480            jump            0.193800
# 482             run            0.193377
# 484       surprised            0.193085
# 485        response            0.193066
# 486         reviews            0.192958
# 488          became            0.192831
# 489       medically            0.192822
# 491             pay            0.192671
# 492         average            0.192593
# 494            mary            0.192350
# 495         melamed            0.192222
# 496            lots            0.192169
# 497       addressed            0.192120
# 498        provider            0.191927
# 499          couple            0.191799
#
# [186 rows x 2 columns]
#
# In M not in F: Words related with male doctors but didn't appear in female doctor's reviews
#
#             words  similarity_score_m
# 314   informative            0.339103
# 315    thoughtful            0.326988
# 316        mother            0.322919
# 317       skilled            0.322816
# 318           guy            0.317396
# 319         heart            0.312687
# 320     performed            0.309638
# 321         saved            0.301872
# 322       treated            0.300587
# 323           ago            0.300232
# 324           put            0.300166
# 325     brilliant            0.299396
# 326      treating            0.298560
# 327  cardiologist            0.296702
# 328       awesome            0.292249
# 329         sense            0.290154
# 330          knew            0.283796
# 331        father            0.283445
# 332      hospital            0.283100
# 333    procedures            0.282911
# 334            us            0.282445
# 335           old            0.280102
# 336       surgery            0.279190
# 337          side            0.278532
# 338     procedure            0.276442
# 339        nurses            0.276048
# 340         treat            0.275644
# 341     dedicated            0.273868
# 342           dad            0.271077
# 343          plus            0.268510
# ..            ...                 ...
# 470           low            0.222246
# 471          keep            0.222226
# 472     suffering            0.222060
# 473         level            0.222008
# 474   specialists            0.221897
# 475    reassuring            0.221797
# 476     literally            0.221790
# 477         using            0.221787
# 478     diagnoses            0.221674
# 479        member            0.221626
# 480     confident            0.221551
# 481        thanks            0.221182
# 482       brought            0.220612
# 483         hurry            0.220189
# 484         world            0.220166
# 485   generations            0.219751
# 486       quality            0.219623
# 487       effects            0.219369
# 488       provide            0.219137
# 489         liver            0.218608
# 490         state            0.218397
# 491    profession            0.217987
# 492        nearly            0.217820
# 493      positive            0.217736
# 494     specialty            0.217660
# 495             w            0.217630
# 496     fortunate            0.217570
# 497       working            0.217281
# 498         thing            0.217044
# 499         clear            0.216986
#
# [186 rows x 2 columns]
#
# M>F: Similarity score of male doctors higher then that of female doctors
#
#            words  abs_diff
# 310      husband  0.169159
# 34         great  0.158506
# 196          man  0.157402
# 293       family  0.135046
# 29     excellent  0.133433
# 246          met  0.126711
# 270  outstanding  0.122346
# 1         doctor  0.115765
# 10          kind  0.115171
# 118        smart  0.113116
# 35     wonderful  0.112295
# 264      disease  0.112223
# 73        highly  0.110226
# 71       bedside  0.109226
# 201         life  0.108083
# 6         caring  0.106621
# 283    condition  0.106006
# 66     recommend  0.104718
# 60        manner  0.103824
# 142         nice  0.103332
# 272        known  0.102585
# 85   intelligent  0.098920
# 217  recommended  0.098059
# 240          doc  0.097301
# 211        knows  0.096862
# 191    courteous  0.095960
# 19     physician  0.095387
# 37    personable  0.094765
# 151       polite  0.094510
# 254         used  0.093504
# ..           ...       ...
# 235   personally  0.007893
# 194     punctual  0.007530
# 123      totally  0.007455
# 52          work  0.007301
# 119        blood  0.005991
# 172         felt  0.005979
# 32     attentive  0.005931
# 108     practice  0.005610
# 165      looking  0.005343
# 103        needs  0.005260
# 121         tell  0.005031
# 144        gives  0.004705
# 94    empathetic  0.004615
# 114         told  0.003907
# 208        least  0.003801
# 222       latest  0.003247
# 109          ask  0.003058
# 195       months  0.003032
# 163     approach  0.002936
# 107   incredibly  0.002496
# 202      genuine  0.002427
# 187      finally  0.002055
# 80    responsive  0.001951
# 132       things  0.001909
# 178     probably  0.001457
# 189      waiting  0.001434
# 174        short  0.001401
# 95         asked  0.001138
# 188      getting  0.000657
# 147        comes  0.000211
#
# [265 rows x 2 columns]
#
# F>M: Similarity score of female doctors higher then that of male doctors
#
#              words  abs_diff
# 42            exam  0.055930
# 40        attitude  0.054164
# 2           office  0.054123
# 43         current  0.047189
# 76            wait  0.039577
# 23          seeing  0.031585
# 86         minutes  0.031031
# 51            rude  0.029043
# 59            long  0.028858
# 104            lab  0.027815
# 106     supportive  0.027237
# 129           come  0.024381
# 117           rush  0.023324
# 45          issues  0.022478
# 41           nurse  0.022363
# 141  condescending  0.021470
# 58           visit  0.020629
# 28           seems  0.018537
# 82             etc  0.016918
# 49         answers  0.016580
# 68          follow  0.016143
# 148        primary  0.014633
# 100          calls  0.013309
# 18             see  0.013003
# 38          listen  0.011684
# 145        willing  0.010157
# 110           left  0.010108
# 93        symptoms  0.010011
# 128         seemed  0.009793
# 126          phone  0.009081
# 154          point  0.008966
# 102          tests  0.007948
# 160         waited  0.007874
# 90            last  0.006447
# 96             new  0.006375
# 192           less  0.005620
# 131            yes  0.005251
# 146           make  0.005002
# 30        actually  0.004992
# 116        results  0.004759
# 158            due  0.004477
# 197        illness  0.002411
# 57           times  0.002374
# 205         visits  0.002254
# 185       informed  0.002242
# 36            take  0.001559
# 136     interested  0.001148
# 135          check  0.000889
# 84            back  0.000843

# %% [markdown]
# ### Similar words comparison results - gender & sanction (using one label)

# %%
f1 = d2v_gs_l_w5.wv.most_similar(positive = [d2v_gs_l_w5.docvecs['F1']],topn=500)
m1 = d2v_gs_l_w5.wv.most_similar(positive = [d2v_gs_l_w5.docvecs['M1']],topn=500)
compare(list1=f1,list2=m1)
# Out:
# In F not in M: Words related with female doctors but didn't appear in male doctor's reviews
#
#              words  similarity_score_f
# 0             dube            0.429604
# 1         campbell            0.328663
# 2        indicated            0.220437
# 3            costs            0.211093
# 4       threatened            0.210364
# 5         engaging            0.207528
# 6            karen            0.206459
# 7             grew            0.198441
# 8         declined            0.196600
# 9           sooner            0.193269
# 10         payment            0.192906
# 11       impatient            0.191722
# 12    osteoporosis            0.191426
# 13    organization            0.190849
# 14           files            0.190330
# 15           bully            0.190244
# 16          market            0.188147
# 17     respiratory            0.186053
# 18          solved            0.185056
# 19           onset            0.185034
# 20          freely            0.184546
# 21         educate            0.184538
# 22        superior            0.181719
# 23          longer            0.181221
# 24          degree            0.180913
# 25            dont            0.180417
# 26           hears            0.179955
# 27         scripts            0.179453
# 28          booked            0.179015
# 29       including            0.178232
# ..             ...                 ...
# 464            dog            0.114622
# 465           felt            0.114514
# 466     frustrated            0.114437
# 468          lupus            0.114367
# 469       obtained            0.114329
# 470        smoking            0.114295
# 471          fault            0.114234
# 472         kicked            0.114211
# 473        instead            0.114117
# 474          allow            0.114011
# 475         backed            0.113994
# 476         result            0.113833
# 477      pertinent            0.113811
# 478       welcomed            0.113550
# 479  inexperienced            0.113527
# 480           tech            0.113360
# 481         nights            0.113332
# 483           many            0.113068
# 484      disregard            0.113025
# 485        stories            0.112895
# 487    exceptional            0.112763
# 488        fashion            0.112752
# 490             na            0.112653
# 492            bad            0.112539
# 493            pts            0.112519
# 495       strongly            0.112383
# 496         agency            0.112374
# 497      pneumonia            0.112364
# 498      inquiries            0.112294
# 499      physicals            0.112135
#
# [443 rows x 2 columns]
#
# In M not in F: Words related with male doctors but didn't appear in female doctor's reviews
#
#              words  similarity_score_m
# 57           mdvip            0.263296
# 58        injuries            0.249322
# 59      outrageous            0.244101
# 60          deadly            0.233893
# 61    unbelievable            0.233618
# 62   appropriately            0.229957
# 63       typically            0.225419
# 64            heal            0.222641
# 65        believes            0.220458
# 66       continues            0.219950
# 67         injured            0.218735
# 68           trade            0.218476
# 69           legal            0.217120
# 70             via            0.216655
# 71       complaint            0.210595
# 72            true            0.208613
# 73            sign            0.206219
# 74           adore            0.203406
# 75          foster            0.202781
# 76      contracted            0.201074
# 77           aside            0.198884
# 78       attending            0.196596
# 79          trauma            0.195712
# 80            beth            0.195235
# 81         killers            0.192358
# 82           paged            0.192226
# 83         license            0.191698
# 84       attentive            0.190533
# 85            born            0.190036
# 86             bet            0.189453
# ..             ...                 ...
# 470     geriatrics            0.128193
# 471       returned            0.128160
# 472           yell            0.128159
# 473          tough            0.128130
# 474            cat            0.128020
# 475       blockage            0.127996
# 476        doctors            0.127995
# 477         nurses            0.127969
# 478         upmost            0.127596
# 479         prompt            0.127554
# 480      medicines            0.127543
# 481           pray            0.127513
# 482    specializes            0.127421
# 483           hole            0.127407
# 484          acute            0.127402
# 485    potentially            0.127305
# 486        younger            0.127255
# 487  investigation            0.126969
# 488            fix            0.126949
# 489          wound            0.126889
# 490           kind            0.126814
# 491           goes            0.126718
# 492        dentist            0.126661
# 493     congestive            0.126579
# 494    grandfather            0.126564
# 495           alot            0.126483
# 496        happens            0.126352
# 497         second            0.126040
# 498          ahmed            0.125983
# 499         normal            0.125971
#
# [443 rows x 2 columns]
#
# M>F: Similarity score of male doctors higher then that of female doctors
#
#             words  abs_diff
# 37        respond  0.095442
# 54        english  0.086248
# 51     antibiotic  0.085289
# 42        running  0.058707
# 40            law  0.058376
# 10  consideration  0.053348
# 52          quite  0.049671
# 48          awful  0.049446
# 36        salvato  0.047838
# 4             hrs  0.047752
# 9           never  0.045777
# 56       industry  0.043888
# 53         israel  0.043204
# 24             dr  0.041045
# 13    helpfulness  0.037474
# 17         office  0.034295
# 41          books  0.033154
# 6           bruce  0.032936
# 26         almost  0.032633
# 43           love  0.030379
# 34       turnover  0.027418
# 44         prices  0.027402
# 22         worker  0.027002
# 35       machines  0.026033
# 33           past  0.025901
# 49           half  0.024232
# 46        quality  0.023709
# 55          quick  0.022328
# 31         signed  0.021942
# 2          pusher  0.021396
# 47           room  0.020834
# 20          idiot  0.020499
# 45      illnesses  0.017195
# 21     apparently  0.015108
# 50     disability  0.015031
# 38         father  0.013596
# 19          avoid  0.010440
# 32    grandmother  0.009674
# 39          noted  0.006700
# 30        brought  0.004623
# 27         waited  0.004123
# 12          asset  0.003230
# 29      wednesday  0.002468
# 25          catch  0.002325
#
# F>M: Similarity score of female doctors higher then that of male doctors
#
#              words  abs_diff
# 0            broke  0.040960
# 1          example  0.035959
# 8          partner  0.023213
# 7   administrative  0.017878
# 11        vacation  0.015978
# 5        available  0.014471
# 15         reasons  0.014070
# 14          chatty  0.013480
# 18     appreciates  0.011792
# 3           always  0.004692
# 16         mention  0.002775
# 28           email  0.001761
# 23           shots  0.000906

# %% [markdown]
# ### Run Doc2vec for gender & sanction using one label - downsampling

# %%
d2v_gs_ld_w5 = run_dov2vec_sampling(documents = documents,label1=label,sampling=207,gs=True)
d2v_gs_ld_w5.save('d2v_gs_ld_w5.model')

# %%
from gensim.models.doc2vec import Doc2Vec
d2v_gs_ld_w5= Doc2Vec.load('d2v_gs_ld_w5.model')

# %% [markdown]
# ### Not sanction

# %%
f0 = d2v_gs_ld_w5.wv.most_similar(positive = [d2v_gs_ld_w5.docvecs['F0']],topn=500)
m0 = d2v_gs_ld_w5.wv.most_similar(positive = [d2v_gs_ld_w5.docvecs['M0']],topn=500)
compare(list1=f0,list2=m0)
# Out:
# In F not in M: Words related with female doctors but didn't appear in male doctor's reviews
#
#                words  similarity_score_f
# 0           expected            0.467540
# 1       questionable            0.462629
# 2           knowlege            0.462604
# 3            readily            0.459064
# 4       relationship            0.458717
# 5             missed            0.457652
# 8           dialysis            0.446763
# 9            setting            0.445190
# 10           private            0.440388
# 11            basics            0.440053
# 12             shore            0.439956
# 13              blue            0.439348
# 14             words            0.439230
# 15          declined            0.437756
# 16      knowledgeble            0.437445
# 17       ineffective            0.436679
# 18             seven            0.436414
# 19              wall            0.436386
# 20             grace            0.435288
# 21       maintaining            0.432179
# 22           expects            0.432071
# 23           outside            0.430283
# 24            covers            0.430215
# 25            enters            0.430120
# 26         recovered            0.429578
# 27         specialty            0.428563
# 28             xrays            0.428062
# 29         consulted            0.428033
# 30             blame            0.427682
# 31   confidentiality            0.426577
# ..               ...                 ...
# 458             four            0.306361
# 459      embarrassed            0.305823
# 460            guess            0.305815
# 461          message            0.305708
# 462            dirty            0.305641
# 463             runs            0.305595
# 464   unknowledgable            0.305574
# 466         speaking            0.305150
# 467             past            0.304829
# 468           endure            0.304807
# 469            threw            0.304776
# 470            leave            0.304447
# 472           agency            0.304247
# 473      proceedures            0.304199
# 474           rather            0.304104
# 475    authorization            0.303879
# 476             post            0.303559
# 477          discuss            0.303503
# 479           thinks            0.303318
# 483              try            0.302716
# 485             plus            0.302239
# 486       addressing            0.302185
# 487             sits            0.301355
# 488          charges            0.301345
# 490           obtain            0.301119
# 492      efficiently            0.300855
# 494       particular            0.300650
# 496     debilitating            0.300037
# 497             area            0.299917
# 498           costly            0.299915
#
# [398 rows x 2 columns]
#
# In M not in F: Words related with male doctors but didn't appear in female doctor's reviews
#
#             words  similarity_score_m
# 102         skill            0.439574
# 103     sincerely            0.429230
# 104      guidance            0.423559
# 105       nodules            0.419925
# 106         began            0.417310
# 107       growing            0.415740
# 108       rapidly            0.414786
# 109   technically            0.414455
# 110    eventually            0.410186
# 111      disaster            0.409038
# 112      followed            0.408871
# 113       journey            0.406240
# 114      suddenly            0.405753
# 115     insulting            0.405403
# 116    management            0.404739
# 117      replaced            0.404314
# 118       closing            0.403528
# 119       anxiety            0.403434
# 120      identify            0.403131
# 121       skilled            0.402309
# 122     reassured            0.402238
# 123        breath            0.401738
# 124      punctual            0.400730
# 125      elevated            0.399720
# 126           lay            0.399518
# 127        minded            0.398304
# 128        larger            0.398254
# 129    challenged            0.397938
# 130        prompt            0.396079
# 131        excuse            0.395381
# ..            ...                 ...
# 470   prescribing            0.297747
# 471       mystery            0.297725
# 472     undivided            0.297703
# 473  unbelievably            0.297586
# 474   possibility            0.297558
# 475     pulmonary            0.297462
# 476       cutting            0.297326
# 477      facility            0.296899
# 478          town            0.296818
# 479            gt            0.296714
# 480       popular            0.296708
# 481          shah            0.296427
# 482           ego            0.296370
# 483            th            0.296319
# 484         smile            0.295863
# 485   considering            0.295845
# 486         reads            0.295767
# 487       sending            0.295721
# 488         stuff            0.295516
# 489         sadly            0.295443
# 490    hesitation            0.295398
# 491   individuals            0.295381
# 492       managed            0.295189
# 493        habits            0.295188
# 494          cell            0.295130
# 495      recently            0.295068
# 496           fix            0.295023
# 497   specialized            0.294937
# 498    researches            0.294783
# 499       consult            0.294608
#
# [398 rows x 2 columns]
#
# M>F: Similarity score of male doctors higher then that of female doctors
#
#             words  abs_diff
# 94        imagine  0.076694
# 86         stress  0.076327
# 85         stupid  0.074262
# 80             ny  0.072844
# 91         fellow  0.071323
# 96       slightly  0.068440
# 97          terms  0.067580
# 66     whatsoever  0.062389
# 79        neither  0.056441
# 69        matters  0.055976
# 56        generic  0.040630
# 48    generations  0.040332
# 55           park  0.039968
# 83    credentials  0.038666
# 78       possibly  0.038624
# 47      unhelpful  0.037599
# 74       medicate  0.032844
# 77       recieved  0.028791
# 65        weekend  0.026926
# 98       thrilled  0.023046
# 76        replied  0.022836
# 84       addition  0.022543
# 99        dollars  0.022174
# 35           mark  0.020723
# 73        careing  0.018838
# 87        efforts  0.017770
# 67      doctoring  0.017616
# 90         versed  0.013169
# 57     relatively  0.011626
# 101     developed  0.009502
# 53   acknowledged  0.009389
# 43           hold  0.009022
# 95     repeatedly  0.005993
# 75           endo  0.003494
# 71         asking  0.002488
# 45      negligent  0.002113
# 100     processed  0.001636
# 59     empathetic  0.001028
# 25       unturned  0.000682
#
# F>M: Similarity score of female doctors higher then that of male doctors
#
#                  words  abs_diff
# 3                along  0.120382
# 5             analysis  0.112539
# 8                women  0.104004
# 7                 lets  0.102528
# 9               poster  0.102093
# 6          researching  0.096735
# 12         resourceful  0.094358
# 18             dignity  0.083665
# 17                 top  0.082288
# 1                  las  0.082027
# 0                vegas  0.078488
# 11               waits  0.075068
# 24              packed  0.064003
# 4                notch  0.062783
# 26              docter  0.062427
# 23            progress  0.061979
# 30            weekends  0.058511
# 32             passion  0.057247
# 13          phenomenal  0.057092
# 31  gastroenterologist  0.055415
# 36               enemy  0.051797
# 2                  bar  0.051031
# 34         differently  0.043482
# 22       extraordinary  0.040024
# 19              ethics  0.039752
# 10             reviews  0.038500
# 27             opposed  0.037437
# 28        dramatically  0.037346
# 49           solutions  0.036183
# 16           skeptical  0.034770
# ..                 ...       ...
# 42          apologized  0.030533
# 38                   v  0.030278
# 46             whether  0.030196
# 44             operate  0.029549
# 41            talented  0.028250
# 60          intestinal  0.028225
# 61          beneficial  0.026286
# 63            trusting  0.024375
# 15            skillful  0.021366
# 29             fathers  0.020207
# 62             scolded  0.019292
# 54               dosen  0.018831
# 20             capable  0.014677
# 37               tight  0.014525
# 51                okay  0.014523
# 72             summary  0.013970
# 64               added  0.013194
# 58             science  0.013000
# 68             brushed  0.012971
# 40             degrees  0.012267
# 70               state  0.011054
# 14           perfectly  0.009918
# 89           addresses  0.008367
# 88                july  0.006838
# 82                till  0.004842
# 93              pusher  0.004213
# 81           respected  0.004089
# 92               spoke  0.004048
# 33              placed  0.002134
# 21                yell  0.001426
#
# [63 rows x 2 columns]

# %% [markdown]
# ### Sanction

# %%
f0 = d2v_gs_ld_w5.wv.most_similar(positive = [d2v_gs_ld_w5.docvecs['F0']],topn=500)
m0 = d2v_gs_ld_w5.wv.most_similar(positive = [d2v_gs_ld_w5.docvecs['M0']],topn=500)
compare(list1=f0,list2=m0)
# Out:
# In F not in M: Words related with female doctors but didn't appear in male doctor's reviews
#
#                words  similarity_score_f
# 0           expected            0.467540
# 1       questionable            0.462629
# 2           knowlege            0.462604
# 3            readily            0.459064
# 4       relationship            0.458717
# 5             missed            0.457652
# 8           dialysis            0.446763
# 9            setting            0.445190
# 10           private            0.440388
# 11            basics            0.440053
# 12             shore            0.439956
# 13              blue            0.439348
# 14             words            0.439230
# 15          declined            0.437756
# 16      knowledgeble            0.437445
# 17       ineffective            0.436679
# 18             seven            0.436414
# 19              wall            0.436386
# 20             grace            0.435288
# 21       maintaining            0.432179
# 22           expects            0.432071
# 23           outside            0.430283
# 24            covers            0.430215
# 25            enters            0.430120
# 26         recovered            0.429578
# 27         specialty            0.428563
# 28             xrays            0.428062
# 29         consulted            0.428033
# 30             blame            0.427682
# 31   confidentiality            0.426577
# ..               ...                 ...
# 458             four            0.306361
# 459      embarrassed            0.305823
# 460            guess            0.305815
# 461          message            0.305708
# 462            dirty            0.305641
# 463             runs            0.305595
# 464   unknowledgable            0.305574
# 466         speaking            0.305150
# 467             past            0.304829
# 468           endure            0.304807
# 469            threw            0.304776
# 470            leave            0.304447
# 472           agency            0.304247
# 473      proceedures            0.304199
# 474           rather            0.304104
# 475    authorization            0.303879
# 476             post            0.303559
# 477          discuss            0.303503
# 479           thinks            0.303318
# 483              try            0.302716
# 485             plus            0.302239
# 486       addressing            0.302185
# 487             sits            0.301355
# 488          charges            0.301345
# 490           obtain            0.301119
# 492      efficiently            0.300855
# 494       particular            0.300650
# 496     debilitating            0.300037
# 497             area            0.299917
# 498           costly            0.299915
#
# [398 rows x 2 columns]
#
# In M not in F: Words related with male doctors but didn't appear in female doctor's reviews
#
#             words  similarity_score_m
# 102         skill            0.439574
# 103     sincerely            0.429230
# 104      guidance            0.423559
# 105       nodules            0.419925
# 106         began            0.417310
# 107       growing            0.415740
# 108       rapidly            0.414786
# 109   technically            0.414455
# 110    eventually            0.410186
# 111      disaster            0.409038
# 112      followed            0.408871
# 113       journey            0.406240
# 114      suddenly            0.405753
# 115     insulting            0.405403
# 116    management            0.404739
# 117      replaced            0.404314
# 118       closing            0.403528
# 119       anxiety            0.403434
# 120      identify            0.403131
# 121       skilled            0.402309
# 122     reassured            0.402238
# 123        breath            0.401738
# 124      punctual            0.400730
# 125      elevated            0.399720
# 126           lay            0.399518
# 127        minded            0.398304
# 128        larger            0.398254
# 129    challenged            0.397938
# 130        prompt            0.396079
# 131        excuse            0.395381
# ..            ...                 ...
# 470   prescribing            0.297747
# 471       mystery            0.297725
# 472     undivided            0.297703
# 473  unbelievably            0.297586
# 474   possibility            0.297558
# 475     pulmonary            0.297462
# 476       cutting            0.297326
# 477      facility            0.296899
# 478          town            0.296818
# 479            gt            0.296714
# 480       popular            0.296708
# 481          shah            0.296427
# 482           ego            0.296370
# 483            th            0.296319
# 484         smile            0.295863
# 485   considering            0.295845
# 486         reads            0.295767
# 487       sending            0.295721
# 488         stuff            0.295516
# 489         sadly            0.295443
# 490    hesitation            0.295398
# 491   individuals            0.295381
# 492       managed            0.295189
# 493        habits            0.295188
# 494          cell            0.295130
# 495      recently            0.295068
# 496           fix            0.295023
# 497   specialized            0.294937
# 498    researches            0.294783
# 499       consult            0.294608
#
# [398 rows x 2 columns]
#
# M>F: Similarity score of male doctors higher then that of female doctors
#
#             words  abs_diff
# 94        imagine  0.076694
# 86         stress  0.076327
# 85         stupid  0.074262
# 80             ny  0.072844
# 91         fellow  0.071323
# 96       slightly  0.068440
# 97          terms  0.067580
# 66     whatsoever  0.062389
# 79        neither  0.056441
# 69        matters  0.055976
# 56        generic  0.040630
# 48    generations  0.040332
# 55           park  0.039968
# 83    credentials  0.038666
# 78       possibly  0.038624
# 47      unhelpful  0.037599
# 74       medicate  0.032844
# 77       recieved  0.028791
# 65        weekend  0.026926
# 98       thrilled  0.023046
# 76        replied  0.022836
# 84       addition  0.022543
# 99        dollars  0.022174
# 35           mark  0.020723
# 73        careing  0.018838
# 87        efforts  0.017770
# 67      doctoring  0.017616
# 90         versed  0.013169
# 57     relatively  0.011626
# 101     developed  0.009502
# 53   acknowledged  0.009389
# 43           hold  0.009022
# 95     repeatedly  0.005993
# 75           endo  0.003494
# 71         asking  0.002488
# 45      negligent  0.002113
# 100     processed  0.001636
# 59     empathetic  0.001028
# 25       unturned  0.000682
#
# F>M: Similarity score of female doctors higher then that of male doctors
#
#                  words  abs_diff
# 3                along  0.120382
# 5             analysis  0.112539
# 8                women  0.104004
# 7                 lets  0.102528
# 9               poster  0.102093
# 6          researching  0.096735
# 12         resourceful  0.094358
# 18             dignity  0.083665
# 17                 top  0.082288
# 1                  las  0.082027
# 0                vegas  0.078488
# 11               waits  0.075068
# 24              packed  0.064003
# 4                notch  0.062783
# 26              docter  0.062427
# 23            progress  0.061979
# 30            weekends  0.058511
# 32             passion  0.057247
# 13          phenomenal  0.057092
# 31  gastroenterologist  0.055415
# 36               enemy  0.051797
# 2                  bar  0.051031
# 34         differently  0.043482
# 22       extraordinary  0.040024
# 19              ethics  0.039752
# 10             reviews  0.038500
# 27             opposed  0.037437
# 28        dramatically  0.037346
# 49           solutions  0.036183
# 16           skeptical  0.034770
# ..                 ...       ...
# 42          apologized  0.030533
# 38                   v  0.030278
# 46             whether  0.030196
# 44             operate  0.029549
# 41            talented  0.028250
# 60          intestinal  0.028225
# 61          beneficial  0.026286
# 63            trusting  0.024375
# 15            skillful  0.021366
# 29             fathers  0.020207
# 62             scolded  0.019292
# 54               dosen  0.018831
# 20             capable  0.014677
# 37               tight  0.014525
# 51                okay  0.014523
# 72             summary  0.013970
# 64               added  0.013194
# 58             science  0.013000
# 68             brushed  0.012971
# 40             degrees  0.012267
# 70               state  0.011054
# 14           perfectly  0.009918
# 89           addresses  0.008367
# 88                july  0.006838
# 82                till  0.004842
# 93              pusher  0.004213
# 81           respected  0.004089
# 92               spoke  0.004048
# 33              placed  0.002134
# 21                yell  0.001426
#
# [63 rows x 2 columns]

# %% [markdown]
# ### Run Doc2vec for gender & sanction using one label - upsampling

# %%
d2v_gs_lup_w5 = run_dov2vec_sampling(documents = documents,label1=label,sampling=1000,gs=True)
d2v_gs_lup_w5.save('d2v_gs_lup_w5.model')

# %%
from gensim.models.doc2vec import Doc2Vec
d2v_gs_lup_w5= Doc2Vec.load('d2v_gs_lup_w5.model')

# %% [markdown]
# ### Not sanction

# %%
f0 = d2v_gs_lup_w5.wv.most_similar(positive = [d2v_gs_lup_w5.docvecs['F0']],topn=500)
m0 = d2v_gs_lup_w5.wv.most_similar(positive = [d2v_gs_lup_w5.docvecs['M0']],topn=500)
compare(list1=f0,list2=m0)
# Out:
# In F not in M: Words related with female doctors but didn't appear in male doctor's reviews
#
#             words  similarity_score_f
# 0           ahmad            0.343861
# 1         needles            0.339033
# 2            pcos            0.337729
# 3     adjustments            0.336146
# 4            oral            0.335787
# 5           aetna            0.334976
# 6          nausea            0.334969
# 7        surgical            0.333486
# 8        vomiting            0.332419
# 9      continuing            0.332214
# 10       throwing            0.330792
# 12          copay            0.330162
# 13       covering            0.329784
# 14           park            0.328463
# 15          apnea            0.328288
# 16           boot            0.327599
# 17          admin            0.325094
# 19             ny            0.324224
# 21   dramatically            0.323092
# 22           clue            0.322811
# 23         gluten            0.321716
# 24    profesional            0.320329
# 25     assistance            0.317260
# 26      described            0.315525
# 27       referals            0.315066
# 28      reviewers            0.314355
# 29    patronizing            0.313905
# 30     literature            0.313754
# 31         trends            0.312432
# 32     incredibly            0.311819
# ..            ...                 ...
# 465   supplements            0.237759
# 466    reassuring            0.237714
# 467           max            0.237712
# 468     basically            0.237600
# 469          desk            0.237596
# 470            ac            0.237582
# 471        lesson            0.237500
# 472   experiences            0.237380
# 473          blow            0.237345
# 474       resolve            0.237123
# 475        growth            0.237100
# 477    comforting            0.236945
# 478       wasting            0.236908
# 479     undivided            0.236899
# 480         lying            0.236855
# 481      extremly            0.236852
# 482          sore            0.236590
# 483      promptly            0.236552
# 484      finished            0.236529
# 485        sample            0.236446
# 487     listening            0.236355
# 488         broke            0.236209
# 490      provider            0.235824
# 492          golf            0.235671
# 493      remicade            0.235668
# 494  instrumental            0.235516
# 495         heads            0.235433
# 497         stone            0.235303
# 498       setting            0.235288
# 499        remain            0.235182
#
# [406 rows x 2 columns]
#
# In M not in F: Words related with male doctors but didn't appear in female doctor's reviews
#
#              words  similarity_score_m
# 94           valid            0.352383
# 95      speciality            0.352077
# 96        symptons            0.348348
# 97          excess            0.341030
# 98    interrupting            0.335574
# 99              ga            0.333609
# 100          anger            0.332581
# 101      education            0.331807
# 102        massive            0.331329
# 103         polyps            0.326916
# 104       regarded            0.326385
# 105          brush            0.322863
# 106         length            0.320356
# 107      doctoring            0.320101
# 108   successfully            0.318751
# 109     responding            0.318601
# 110   intimidating            0.318067
# 111       existing            0.317240
# 112          krupp            0.316466
# 113           crap            0.316199
# 114         extent            0.316182
# 115         stones            0.315850
# 116          ultra            0.315760
# 117     overweight            0.315170
# 118            hes            0.313095
# 119          girls            0.312925
# 120      reassured            0.312517
# 121            bag            0.312333
# 122        handles            0.311825
# 123          topic            0.311794
# ..             ...                 ...
# 470           heal            0.252900
# 471       horribly            0.252884
# 472         heaven            0.252849
# 473         deadly            0.252722
# 474       trusting            0.252691
# 475          aging            0.252625
# 476       respects            0.252459
# 477        barbara            0.252396
# 478       resulted            0.252166
# 479        healing            0.252097
# 480        conduct            0.251713
# 481          drawn            0.251517
# 482      processed            0.251472
# 483       tendency            0.251416
# 484        figured            0.251374
# 485          value            0.251032
# 486         hardly            0.251027
# 487            hep            0.250987
# 488  encouragement            0.250975
# 489          hyper            0.250883
# 490           scar            0.250875
# 491           bite            0.250688
# 492           sits            0.250660
# 493         common            0.250569
# 494       medicaid            0.250557
# 495        wanting            0.250547
# 496        already            0.250531
# 497        abdomen            0.250429
# 498         jumped            0.250358
# 499      increased            0.250295
#
# [406 rows x 2 columns]
#
# M>F: Similarity score of male doctors higher then that of female doctors
#
#               words  abs_diff
# 93              wit  0.102536
# 65             safe  0.082819
# 88              tom  0.065389
# 90           astute  0.062477
# 27              amy  0.058450
# 52           stinks  0.054380
# 73    exceptionally  0.049770
# 32          likable  0.048836
# 74     knowledgeble  0.047946
# 80        confusing  0.046269
# 29             shes  0.045384
# 82           unkind  0.044711
# 48          mystery  0.038396
# 91         employer  0.038281
# 68          studied  0.038197
# 61       pittsburgh  0.037826
# 79        presented  0.037613
# 92          generic  0.037590
# 76         performs  0.035963
# 28        wednesday  0.034136
# 56      disposition  0.032293
# 81      environment  0.032047
# 87         vitamins  0.031023
# 86              wks  0.030563
# 8    administration  0.028489
# 70        somewhere  0.028361
# 62          avoided  0.027998
# 58         analysis  0.027027
# 77             isnt  0.026901
# 67    disinterested  0.026597
# ..              ...       ...
# 75          abusive  0.018393
# 89            stood  0.017184
# 50       forthright  0.016406
# 16     rheumatology  0.016304
# 63          unheard  0.016102
# 83         pleasent  0.015978
# 71          passion  0.013071
# 85       phenomenal  0.012197
# 59        providers  0.011934
# 60            blunt  0.011671
# 78           ethics  0.011651
# 15          cordial  0.011516
# 39           smooth  0.011124
# 72            route  0.010489
# 44       controlled  0.009941
# 33          studies  0.009933
# 30             food  0.008966
# 51           stupid  0.008893
# 43         politely  0.008797
# 35         examines  0.008769
# 53       pleasantly  0.006613
# 40          matters  0.005720
# 21       definately  0.003570
# 5               lol  0.003569
# 55             xray  0.002334
# 34        interpret  0.002012
# 12  confidentiality  0.001948
# 45           public  0.001543
# 66           crisis  0.000665
# 57       intestinal  0.000655
#
# [66 rows x 2 columns]
#
# F>M: Similarity score of female doctors higher then that of male doctors
#
#             words  abs_diff
# 0       disgusted  0.073757
# 3          formal  0.054750
# 9          graves  0.047571
# 11           flat  0.041232
# 10          stahl  0.040326
# 1    reservations  0.035518
# 6        overlook  0.034173
# 7          writes  0.033182
# 14         copies  0.028570
# 13          grace  0.027374
# 4              ii  0.026133
# 22         secure  0.022560
# 2        unturned  0.021643
# 19      addresses  0.017586
# 31           west  0.014614
# 23           sooo  0.012364
# 41         minded  0.011516
# 18   compasionate  0.010223
# 46         humane  0.006884
# 42            ver  0.005778
# 49         repair  0.005596
# 24       fabulous  0.003593
# 36         typing  0.002456
# 54        laughed  0.001877
# 26      completed  0.001660
# 38    technicians  0.001413
# 37  uncooperative  0.000971
# 47           tons  0.000303

# %% [markdown]
# ### Sanction

# %%
f0 = d2v_gs_lup_w5.wv.most_similar(positive = [d2v_gs_lup_w5.docvecs['F0']],topn=500)
m0 = d2v_gs_lup_w5.wv.most_similar(positive = [d2v_gs_lup_w5.docvecs['M0']],topn=500)
compare(list1=f0,list2=m0)
# Out:
# In F not in M: Words related with female doctors but didn't appear in male doctor's reviews
#
#             words  similarity_score_f
# 0           ahmad            0.343861
# 1         needles            0.339033
# 2            pcos            0.337729
# 3     adjustments            0.336146
# 4            oral            0.335787
# 5           aetna            0.334976
# 6          nausea            0.334969
# 7        surgical            0.333486
# 8        vomiting            0.332419
# 9      continuing            0.332214
# 10       throwing            0.330792
# 12          copay            0.330162
# 13       covering            0.329784
# 14           park            0.328463
# 15          apnea            0.328288
# 16           boot            0.327599
# 17          admin            0.325094
# 19             ny            0.324224
# 21   dramatically            0.323092
# 22           clue            0.322811
# 23         gluten            0.321716
# 24    profesional            0.320329
# 25     assistance            0.317260
# 26      described            0.315525
# 27       referals            0.315066
# 28      reviewers            0.314355
# 29    patronizing            0.313905
# 30     literature            0.313754
# 31         trends            0.312432
# 32     incredibly            0.311819
# ..            ...                 ...
# 465   supplements            0.237759
# 466    reassuring            0.237714
# 467           max            0.237712
# 468     basically            0.237600
# 469          desk            0.237596
# 470            ac            0.237582
# 471        lesson            0.237500
# 472   experiences            0.237380
# 473          blow            0.237345
# 474       resolve            0.237123
# 475        growth            0.237100
# 477    comforting            0.236945
# 478       wasting            0.236908
# 479     undivided            0.236899
# 480         lying            0.236855
# 481      extremly            0.236852
# 482          sore            0.236590
# 483      promptly            0.236552
# 484      finished            0.236529
# 485        sample            0.236446
# 487     listening            0.236355
# 488         broke            0.236209
# 490      provider            0.235824
# 492          golf            0.235671
# 493      remicade            0.235668
# 494  instrumental            0.235516
# 495         heads            0.235433
# 497         stone            0.235303
# 498       setting            0.235288
# 499        remain            0.235182
#
# [406 rows x 2 columns]
#
# In M not in F: Words related with male doctors but didn't appear in female doctor's reviews
#
#              words  similarity_score_m
# 94           valid            0.352383
# 95      speciality            0.352077
# 96        symptons            0.348348
# 97          excess            0.341030
# 98    interrupting            0.335574
# 99              ga            0.333609
# 100          anger            0.332581
# 101      education            0.331807
# 102        massive            0.331329
# 103         polyps            0.326916
# 104       regarded            0.326385
# 105          brush            0.322863
# 106         length            0.320356
# 107      doctoring            0.320101
# 108   successfully            0.318751
# 109     responding            0.318601
# 110   intimidating            0.318067
# 111       existing            0.317240
# 112          krupp            0.316466
# 113           crap            0.316199
# 114         extent            0.316182
# 115         stones            0.315850
# 116          ultra            0.315760
# 117     overweight            0.315170
# 118            hes            0.313095
# 119          girls            0.312925
# 120      reassured            0.312517
# 121            bag            0.312333
# 122        handles            0.311825
# 123          topic            0.311794
# ..             ...                 ...
# 470           heal            0.252900
# 471       horribly            0.252884
# 472         heaven            0.252849
# 473         deadly            0.252722
# 474       trusting            0.252691
# 475          aging            0.252625
# 476       respects            0.252459
# 477        barbara            0.252396
# 478       resulted            0.252166
# 479        healing            0.252097
# 480        conduct            0.251713
# 481          drawn            0.251517
# 482      processed            0.251472
# 483       tendency            0.251416
# 484        figured            0.251374
# 485          value            0.251032
# 486         hardly            0.251027
# 487            hep            0.250987
# 488  encouragement            0.250975
# 489          hyper            0.250883
# 490           scar            0.250875
# 491           bite            0.250688
# 492           sits            0.250660
# 493         common            0.250569
# 494       medicaid            0.250557
# 495        wanting            0.250547
# 496        already            0.250531
# 497        abdomen            0.250429
# 498         jumped            0.250358
# 499      increased            0.250295
#
# [406 rows x 2 columns]
#
# M>F: Similarity score of male doctors higher then that of female doctors
#
#               words  abs_diff
# 93              wit  0.102536
# 65             safe  0.082819
# 88              tom  0.065389
# 90           astute  0.062477
# 27              amy  0.058450
# 52           stinks  0.054380
# 73    exceptionally  0.049770
# 32          likable  0.048836
# 74     knowledgeble  0.047946
# 80        confusing  0.046269
# 29             shes  0.045384
# 82           unkind  0.044711
# 48          mystery  0.038396
# 91         employer  0.038281
# 68          studied  0.038197
# 61       pittsburgh  0.037826
# 79        presented  0.037613
# 92          generic  0.037590
# 76         performs  0.035963
# 28        wednesday  0.034136
# 56      disposition  0.032293
# 81      environment  0.032047
# 87         vitamins  0.031023
# 86              wks  0.030563
# 8    administration  0.028489
# 70        somewhere  0.028361
# 62          avoided  0.027998
# 58         analysis  0.027027
# 77             isnt  0.026901
# 67    disinterested  0.026597
# ..              ...       ...
# 75          abusive  0.018393
# 89            stood  0.017184
# 50       forthright  0.016406
# 16     rheumatology  0.016304
# 63          unheard  0.016102
# 83         pleasent  0.015978
# 71          passion  0.013071
# 85       phenomenal  0.012197
# 59        providers  0.011934
# 60            blunt  0.011671
# 78           ethics  0.011651
# 15          cordial  0.011516
# 39           smooth  0.011124
# 72            route  0.010489
# 44       controlled  0.009941
# 33          studies  0.009933
# 30             food  0.008966
# 51           stupid  0.008893
# 43         politely  0.008797
# 35         examines  0.008769
# 53       pleasantly  0.006613
# 40          matters  0.005720
# 21       definately  0.003570
# 5               lol  0.003569
# 55             xray  0.002334
# 34        interpret  0.002012
# 12  confidentiality  0.001948
# 45           public  0.001543
# 66           crisis  0.000665
# 57       intestinal  0.000655
#
# [66 rows x 2 columns]
#
# F>M: Similarity score of female doctors higher then that of male doctors
#
#             words  abs_diff
# 0       disgusted  0.073757
# 3          formal  0.054750
# 9          graves  0.047571
# 11           flat  0.041232
# 10          stahl  0.040326
# 1    reservations  0.035518
# 6        overlook  0.034173
# 7          writes  0.033182
# 14         copies  0.028570
# 13          grace  0.027374
# 4              ii  0.026133
# 22         secure  0.022560
# 2        unturned  0.021643
# 19      addresses  0.017586
# 31           west  0.014614
# 23           sooo  0.012364
# 41         minded  0.011516
# 18   compasionate  0.010223
# 46         humane  0.006884
# 42            ver  0.005778
# 49         repair  0.005596
# 24       fabulous  0.003593
# 36         typing  0.002456
# 54        laughed  0.001877
# 26      completed  0.001660
# 38    technicians  0.001413
# 37  uncooperative  0.000971
# 47           tons  0.000303

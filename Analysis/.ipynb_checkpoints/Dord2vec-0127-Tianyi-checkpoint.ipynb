# %% [markdown]
# ## Import doctor review dataset and gender dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
path = "/Users/chongchen/Desktop/19Fall RA/data/generated_data/Internal Medicine Review.csv"
review_im = pd.read_csv(path, index_col = 0)

# %%
review_im.head()
# Out:
#                                               Review  hp_id gender  hasorder  \
# 0  satisfactory but would not recommend coldness,...  19713      F         0
# 1   Although Dr. Merlo does not appear to have an...  19713      F         0
# 2   took my daughter for problems, never examined...  19713      F         0
# 3   Yes, Dr. Merlot can be rude and arrogant, but...  19713      F         0
# 4   I called to make and appointment and a woman ...  19713      F         0
#
#                                                lower  \
# 0  satisfactory but would not recommend coldness,...
# 1   although dr. merlo does not appear to have an...
# 2   took my daughter for problems, never examined...
# 3   yes, dr. merlot can be rude and arrogant, but...
# 4   i called to make and appointment and a woman ...
#
#                                            no_digits  \
# 0  satisfactory but would not recommend coldness,...
# 1   although dr. merlo does not appear to have an...
# 2   took my daughter for problems, never examined...
# 3   yes, dr. merlot can be rude and arrogant, but...
# 4   i called to make and appointment and a woman ...
#
#                                       no_punctuation  \
# 0  satisfactory but would not recommend coldness ...
# 1   although dr  merlo does not appear to have an...
# 2   took my daughter for problems  never examined...
# 3   yes  dr  merlot can be rude and arrogant  but...
# 4   i called to make and appointment and a woman ...
#
#                                                words
# 0  ['satisfactory', 'recommend', 'coldness', 'sol...
# 1  ['although', 'dr', 'merlo', 'appear', 'office'...
# 2  ['took', 'daughter', 'problems', 'never', 'exa...
# 3  ['yes', 'dr', 'merlot', 'rude', 'arrogant', 'o...
# 4  ['called', 'make', 'appointment', 'woman', 'ca...

# %%
# drop records without review
review_im.drop(review_im[review_im['Review'] == ' '].index, inplace = True)
review_im.reset_index(inplace = True, drop = True)

# %%
review_im['words'][0]
# Out:
# "['satisfactory', 'recommend', 'coldness', 'solo', 'helpfulness', 'limited', 'office', 'staff', 'isolation', 'diagnosis', 'solo']"

# %%
import ast
review_im['words'] = review_im['words'].map(lambda x: ast.literal_eval(x))

# %%
review_im['words'][0]
# Out:
# ['satisfactory',
#  'recommend',
#  'coldness',
#  'solo',
#  'helpfulness',
#  'limited',
#  'office',
#  'staff',
#  'isolation',
#  'diagnosis',
#  'solo']

# %%
review_im.head()
# Out:
#                                               Review  hp_id gender  hasorder  \
# 0  satisfactory but would not recommend coldness,...  19713      F         0
# 1   Although Dr. Merlo does not appear to have an...  19713      F         0
# 2   took my daughter for problems, never examined...  19713      F         0
# 3   Yes, Dr. Merlot can be rude and arrogant, but...  19713      F         0
# 4   I called to make and appointment and a woman ...  19713      F         0
#
#                                                lower  \
# 0  satisfactory but would not recommend coldness,...
# 1   although dr. merlo does not appear to have an...
# 2   took my daughter for problems, never examined...
# 3   yes, dr. merlot can be rude and arrogant, but...
# 4   i called to make and appointment and a woman ...
#
#                                            no_digits  \
# 0  satisfactory but would not recommend coldness,...
# 1   although dr. merlo does not appear to have an...
# 2   took my daughter for problems, never examined...
# 3   yes, dr. merlot can be rude and arrogant, but...
# 4   i called to make and appointment and a woman ...
#
#                                       no_punctuation  \
# 0  satisfactory but would not recommend coldness ...
# 1   although dr  merlo does not appear to have an...
# 2   took my daughter for problems  never examined...
# 3   yes  dr  merlot can be rude and arrogant  but...
# 4   i called to make and appointment and a woman ...
#
#                                                words
# 0  [satisfactory, recommend, coldness, solo, help...
# 1  [although, dr, merlo, appear, office, staff, m...
# 2  [took, daughter, problems, never, examined, un...
# 3  [yes, dr, merlot, rude, arrogant, one, gastroe...
# 4  [called, make, appointment, woman, calling, ma...

# %% [markdown]
# #### Add lable to the review based on gender & sanction

# %%
review_im['label']=0

# %%
review_im['label'][np.logical_and(review_im['gender']=='F',review_im['hasorder']==0)] = 'F0'
# Out:
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
review_im['label'][np.logical_and(review_im['gender']=='M',review_im['hasorder']==0)] = 'M0'
# Out:
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
review_im['label'][np.logical_and(review_im['gender']=='F',review_im['hasorder']==1)] = 'F1'
# Out:
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
review_im['label'][np.logical_and(review_im['gender']=='M',review_im['hasorder']==1)] = 'M1'
# Out:
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
review_im
# Out:
#                                                   Review    hp_id gender  \
# 0      satisfactory but would not recommend coldness,...    19713      F
# 1       Although Dr. Merlo does not appear to have an...    19713      F
# 2       took my daughter for problems, never examined...    19713      F
# 3       Yes, Dr. Merlot can be rude and arrogant, but...    19713      F
# 4       I called to make and appointment and a woman ...    19713      F
# 5       I, unfortunately,treated with Dr.Merlo severa...    19713      F
# 6       I can't tell you if she's a good or bad docto...    19713      F
# 7       Yesterday my partner had an upper endoscopy d...    19713      F
# 8       Very arrogant and rude. Went in with a previo...    19713      F
# 9       She files insurance for me even though I have...    19713      F
# 10      After scheduling 2 appts. (for a husband and ...    19713      F
# 11     I have been going to Dr. Mittleman for the pas...   587845      M
# 12      Dr. Mittleman is friendly, non-threatening, n...   587845      M
# 13      Dr. Mittleman has been my primary physician f...   587845      M
# 14      I've been Dr. Mittleman for years. He's very ...   587845      M
# 15      This man had the patience of a saint when he ...   587845      M
# 16      Very poor. I took my uncle to him and he was ...   587845      M
# 17      Very caring and helpful! I had a BMI of 41 an...   587845      M
# 18      Dr. Mittleman never makes you feel rushed and...   587845      M
# 19      Dr Mittleman is an excellent MD. He is caring...   587845      M
# 20     What I like most about Dr. Brandies is that sh...  1026482      F
# 21      I've used Dr. Brandies as my doctor for over ...  1026482      F
# 22      I did not find her compassionate at all; in f...  1026482      F
# 23      Excellent doctor with a great 'bedside manner...  1026482      F
# 24      I love Dr. Brandies! She truly is a great doc...  1026482      F
# 25      I can't say enough good things about Dr. Bran...  1026482      F
# 26      Dr. Brandies always takes the time to listen ...  1026482      F
# 27      Dr Brandies is very thoughtful. She listens t...  1026482      F
# 28      Dr. Brandies is a dedicated physician who lis...  1026482      F
# 29      It is ocassionally hard to get an appointment...  1026482      F
# ...                                                  ...      ...    ...
# 87845  My first experience with this doctor was when ...   188148      M
# 87846   This doctor is perpetually in a languid mood....   188148      M
# 87847                                    Very Attentive   1239152      M
# 87848  An excellent physician. A good diagnostician. ...   879980      M
# 87849   always booked and very hard to get an appoint...   879980      M
# 87850   I found him to be very thorough and smart and...   879980      M
# 87866         above average  some room for improvement
# 87867  saw him several times for liver disease    he ...
# 87868   thoughtful and understanding  he is intereste...
# 87869  dr  foster has been excellent  she has hapled ...
# 87870   this doctor is just flaky  dr  foster  just s...
# 87871   do not go to dr  ernia foster  she perforated...
# 87872  dr  davis is a very caring physician  she is n...
# 87873   i found it sad that dr  charlyce davis will n...
# 87874   the times she is running behind you are promp...
#
#                                                    words label
# 0      [satisfactory, recommend, coldness, solo, help...    F0
# 1      [although, dr, merlo, appear, office, staff, m...    F0
# 2      [took, daughter, problems, never, examined, un...    F0
# 3      [yes, dr, merlot, rude, arrogant, one, gastroe...    F0
# 4      [called, make, appointment, woman, calling, ma...    F0
# 5      [unfortunately, treated, dr, merlo, several, y...    F0
# 6      [tell, good, bad, doctor, anything, prove, one...    F0
# 7      [yesterday, partner, upper, endoscopy, done, d...    F0
# 8      [arrogant, rude, went, previously, diagnosed, ...    F0
# 9      [files, insurance, even, though, traditional, ...    F0
# 10     [scheduling, appts, husband, wife, immediate, ...    F0
# 11     [going, dr, mittleman, past, years, caring, at...    M0
# 12     [dr, mittleman, friendly, non, threatening, ne...    M0
# 13     [dr, mittleman, primary, physician, many, year...    M0
# 14     [dr, mittleman, years, attentive, patients, al...    M0
# 15     [man, patience, saint, took, care, wife, amp, ...    M0
# 16     [poor, took, uncle, rude, short, completely, u...    M0
# 17     [caring, helpful, bmi, jump, throat, weight, a...    M0
# 18     [dr, mittleman, never, makes, feel, rushed, tr...    M0
# 19     [dr, mittleman, excellent, md, caring, compass...    M0
# 20     [dr, brandies, jump, treating, every, ache, am...    F0
# 21     [used, dr, brandies, doctor, years, knowledgea...    F0
# 22     [find, compassionate, fact, judgmental, rude, ...    F0
# 23     [excellent, doctor, great, bedside, manner, pa...    F0
# 24     [love, dr, brandies, truly, great, doctor, lis...    F0
# 25     [say, enough, good, things, dr, brandies, comp...    F0
# 26     [dr, brandies, always, takes, time, listen, pr...    F0
# 27     [dr, brandies, thoughtful, listens, everything...    F0
# 28     [dr, brandies, dedicated, physician, listens, ...    F0
# 29     [ocassionally, hard, appointment, doctor, prac...    F0
# ...                                                  ...   ...
# 87845  [first, experience, doctor, arrived, urgent, c...    M0
# 87846  [doctor, perpetually, languid, mood, treats, p...    M0
# 87847                                        [attentive]    M0
# 87848  [excellent, physician, good, diagnostician, ca...    M0
# 87849                [always, booked, hard, appointment]    M0
# 87850  [found, thorough, smart, responsive, diagnosed...    M0
# 87851  [found, thorough, caring, great, following, pa...    M0
# 87852  [excellent, doctor, terms, skill, knowledge, b...    M0
# 87853  [doctor, unable, complete, colonoscopy, amount...    M0
# 87854                                                 []    M0
# 87855  [best, time, dr, takes, care, mother, law, dau...    F0
# 87856  [going, years, one, professional, caring, doct...    F0
# 87857  [whole, family, going, see, years, gotten, bad...    F0
# 87858  [exquisite, diagnostician, dr, myaing, lirst, ...    M0
# 87859  [always, found, dr, myaing, extremely, thoroug...    M0
# 87860  [dr, rickles, helpful, informative, considerat...    M0
# 87861  [dr, rickles, caring, knowledgeable, conversan...    M0
# 87862  [knowledgeable, warm, sympathetic, used, go, a...    M0
# 87863   [kind, caring, doctor, extremely, knowledgeable]    M0
# 87864  [blamed, patient, dambing, difficulty, getting...    M0
# 87865  [disappointed, doctor, seemed, aloof, conversa...    M0
# 87866                       [average, room, improvement]    M0
# 87867  [saw, several, times, liver, disease, affable,...    M0
# 87868  [thoughtful, understanding, interested, proble...    M0
# 87869  [dr, foster, excellent, hapled, diagnosed, alo...    F0
# 87870  [doctor, flaky, dr, foster, seems, care, work,...    F0
# 87871         [go, dr, ernia, foster, perforated, colon]    F0
# 87872  [dr, davis, caring, physician, quick, write, s...    F0
# 87873  [found, sad, dr, charlyce, davis, accept, new,...    F0
# 87874  [times, running, behind, promptly, notified, a...    F0
#
# [87875 rows x 9 columns]

# %% [markdown]
# ### Stemming
# https://www.geeksforgeeks.org/python-stemming-words-with-nltk/

# %% [markdown]
# ### Run Doc2vec, using window size of 5, hold other parameters constant.

# %%
from gensim.models import Word2Vec

# %%
# preparing corpus
documents = list(review_im['words'])

# %%
documents[0][0]
# Out:
# 'satisfactory'

# %%
gender = list(review_im['gender'])
hasorder = list(review_im['hasorder'])
label = list(review_im['label']) # conbine gender & sanction in one label

# %%
len(documents),len(gender),len(hasorder),len(label)
# Out:
# (87875, 87875, 87875)

# %% [markdown]
# ### Write a Doc2vec function

# %%
def run_dov2vec(documents,label1,label2=None):
    # tag document
    import gensim
    docs = [] # each review/row is a tagged document.
    if label2=None:
        for i in range(len(documents)):
            docs.append(gensim.models.doc2vec.TaggedDocument(documents[i], [label1[i]]))
    else:
        for i in range(len(documents)):
            docs.append(gensim.models.doc2vec.TaggedDocument(documents[i], [label1[i],label2[i]]))
    
    # build vocab
    docs_for_vocab = [] 
    for i in docs:
        docs_for_vocab.append(i)
        
    from gensim.models.doc2vec import Doc2Vec, TaggedDocument
    model = Doc2Vec(dm=0, window=5,vector_size=300,min_count=30,epochs=100,workers=4,
               hs=0,negative=7,dbow_words=1,dm_concat=1)
    model.build_vocab(docs_for_vocab)
    model.train(documents = docs,total_examples=model.corpus_count,epochs=100)
    return model

# %% [markdown]
# #### 如果一个label，那就把这个label赋值给label1， 如果两个label， 则分别赋给label1 和label2

# %% [markdown]
# ### boostrap

# %%
#1000 sanction male/female reviews and 1000 not sanction male/female reviews
import random
repeat = {}
indices = []
batch = []
draw = 1000 # 在这里定义boostrap多少sample
sf_candidates = list(review_im[np.logical_and(review_im['hasorder']==1, review_im['gender']=='F')].index)
sm_candidates = list(review_im[np.logical_and(review_im['hasorder']==1, review_im['gender']=='M')].index)
nsf_candidates = list(review_im[np.logical_and(review_im['hasorder']==0, review_im['gender']=='F')].index)
nsm_candidates = list(review_im[np.logical_and(review_im['hasorder']==0, review_im['gender']=='M')].index)
for b in range(draw):
    sf = random.choice(sf_candidates)
    sm = random.choice(sm_candidates)
    indices.append(sf)
    indices.append(sm)
    nsf = random.choice(nsf_candidates)
    nsm = random.choice(nsm_candidates)
    indices.append(nsf)
    indices.append(nsm)
for i in indices:
    try:
        repeat[i]+=1
    except:
        repeat[i]=1
    batch.append(docs_gs[i])
# 最后的batch就是我们要用的变量，相当于之前的docs，里面都是tag 好的list of words

# %% [markdown]
# ### 可以开始run model了

# %%
# assign the model results to a variable
model = run_dov2vec_one_label(documents=xx,label1=xx)
# name the model and save it to local
model.save("xxx.model")

# %%
# reload the model
xxx= Doc2Vec.load("xxx.model")

# %% [markdown]
# ### Run Doc2vec - gender

# %%
# Tag document
import gensim
docs = [] # each review/row is a tagged document.
for i in range(len(documents)):
    docs.append(gensim.models.doc2vec.TaggedDocument(documents[i], [gender[i]]))

# %%
docs[0]
# Out:
# TaggedDocument(words=['satisfactory', 'recommend', 'coldness', 'solo', 'helpfulness', 'limited', 'office', 'staff', 'isolation', 'diagnosis', 'solo'], tags=['F'])

# %%
docs_for_vocab = [] 
for i in docs:
    docs_for_vocab.append(i)

# %%
from gensim.models.doc2vec import Doc2Vec, TaggedDocument
import gensim
import multiprocessing

# %%
model = Doc2Vec(dm=0, window=5,vector_size=300,min_count=30,epochs=100,workers=4,
               hs=0,negative=7,dbow_words=1,dm_concat=1)
model.build_vocab(docs_for_vocab)
model.train(documents = docs,total_examples=model.corpus_count,epochs=100)

# %%
model.save("d2v_g1.model")

# %%
d2v_g1= Doc2Vec.load("d2v_g1.model")

# %%
d2v_g1.wv.most_similar(positive = [d2v_g1.docvecs['F']],topn=15)
# Out:
# [('dr', 0.7431488633155823),
#  ('doctor', 0.7271621227264404),
#  ('caring', 0.6368781328201294),
#  ('staff', 0.6312354803085327),
#  ('office', 0.6301532983779907),
#  ('extremely', 0.629963755607605),
#  ('time', 0.6232239007949829),
#  ('really', 0.6171454787254333),
#  ('knowledgeable', 0.6163986921310425),
#  ('always', 0.6149625778198242),
#  ('patient', 0.6130982637405396),
#  ('never', 0.6121476888656616),
#  ('kind', 0.610569179058075),
#  ('see', 0.6052374839782715),
#  ('friendly', 0.5981082916259766)]

# %%
d2v_g1.wv.most_similar(positive = [d2v_g1.docvecs['M']],topn=15)
# Out:
# [('dr', 0.8281524181365967),
#  ('doctor', 0.8166409134864807),
#  ('kind', 0.7272549271583557),
#  ('patient', 0.7099394202232361),
#  ('caring', 0.7075568437576294),
#  ('extremely', 0.6939889788627625),
#  ('great', 0.6927266120910645),
#  ('well', 0.6783657073974609),
#  ('good', 0.6746696829795837),
#  ('one', 0.6743701696395874),
#  ('time', 0.6675636768341064),
#  ('helpful', 0.6650533676147461),
#  ('knowledgeable', 0.6624915599822998),
#  ('professional', 0.661713719367981),
#  ('excellent', 0.6578822135925293)]

# %% [markdown]
# ### Write a function to output the comparison results

# %%
# for consistency, we assign female words to list1 and male words to list2
def compare(list1,list2):
    ### list1 & list2 are the results from doc2vec.wv.most_similar() ###
    # convert similar words to dataframe
    list1={x:y for (x,y) in list1}
    list1=pd.DataFrame.from_dict(list1,orient='index')
    list1.reset_index(inplace= True)
    list1.rename(columns= {'index':'words',0:'similarity_score_f'},inplace= True)
    
    # convert similar words in list2 to dataframe
    list2={x:y for (x,y) in list2}
    list2=pd.DataFrame.from_dict(list2,orient='index')
    list2.reset_index(inplace= True)
    list2.rename(columns= {'index':'words',0:'similarity_score_m'},inplace= True)
    
    # left join list1 with list2, find words didn't appear in list2 but in list1
    l1 = pd.merge(list1,list2,on = 'words', how = 'left')
    l1_result = l1[['words','similarity_score_f']][l1['similarity_score_m'].isnull()].sort_values(by = 'similarity_score_f', ascending= False)
    print('In F not in M: Words related with female doctors but didn\'t appear in male doctor\'s reviews','\n')
    print(l1_result,'\n')

    # left join male words with female words, find words didn't appear in female but in male
    l2 = pd.merge(list1,list2,on = 'words', how = 'right')
    l2_result = l2[['words','similarity_score_m']][l2['similarity_score_f'].isnull()].sort_values(by = 'similarity_score_m', ascending= False)
    print('In M not in F: Words related with male doctors but didn\'t appear in female doctor\'s reviews','\n')
    print(l2_result,'\n')
    
    
    # related with both
    similar_words = pd.merge(list1,list2,on = 'words', how = 'inner')
    similar_words['diff']=similar_words['similarity_score_m']-similar_words['similarity_score_f']
    similar_words['label'] = similar_words['diff'].map(lambda x: 'F' if x < 0 else 'M')
    similar_words['abs_diff'] = similar_words['diff'].map(lambda x: abs(x))

    # M>F
    m = similar_words[['words','abs_diff']][similar_words['label']=='M'].sort_values(by ='abs_diff', ascending = False)
    # F>M
    f = similar_words[['words','abs_diff']][similar_words['label']=='F'].sort_values(by ='abs_diff', ascending = False)
    
    print('M>F: Similarity score of male doctors higher then that of female doctors','\n')
    print(m,'\n')
    print('F>M: Similarity score of female doctors higher then that of male doctors','\n')
    print(f,'\n')

# %% [markdown]
# ### Similar words comparison results - gender

# %%
f = d2v_g1.wv.most_similar(positive = [d2v_g1.docvecs['F']],topn=500)
m = d2v_g1.wv.most_similar(positive = [d2v_g1.docvecs['M']],topn=500)
compare(list1=f,list2=m)
# Out:
# In F not in M: Words related with female doctors but didn't appear in male doctor's reviews
#
#                words  similarity_score_f
# 168            woman            0.434640
# 186     receptionist            0.424188
# 191        assistant            0.422763
# 193              pcp            0.422260
# 200        listening            0.418194
# 219         physical            0.411748
# 243       supportive            0.406395
# 246  endocrinologist            0.404932
# 274              lab            0.397253
# 276        generally            0.396978
# 278             appt            0.395862
# 287        attention            0.392793
# 297         comments            0.388736
# 298       unfriendly            0.388406
# 299           change            0.388234
# 300               pa            0.387965
# 303          history            0.387647
# 304            moved            0.387520
# 316          rushing            0.385108
# 334             half            0.381241
# 335           asking            0.381069
# 343             cold            0.377985
# 345         schedule            0.377303
# 347      information            0.376813
# 349     practitioner            0.376758
# 352            twice            0.376101
# 354          dealing            0.375948
# 361        referrals            0.374288
# 363             exam            0.373568
# 367             lady            0.373335
# ..               ...                 ...
# 430         provider            0.357588
# 432      appropriate            0.357529
# 435          illness            0.357040
# 437          already            0.356431
# 438      understands            0.356288
# 443           seemed            0.355698
# 447        sensitive            0.355304
# 449           thinks            0.354411
# 452   rheumatologist            0.353917
# 453            tries            0.353832
# 454             runs            0.353724
# 455        surprised            0.353672
# 456      examination            0.353658
# 458   unprofessional            0.353198
# 459           bottom            0.352970
# 461        complaint            0.352802
# 465           plenty            0.352443
# 466          thyroid            0.352390
# 468          reasons            0.352002
# 471            appts            0.351696
# 472             door            0.350969
# 474        addressed            0.350175
# 477             mean            0.349635
# 479    condescending            0.349434
# 483           behind            0.348260
# 484          general            0.347710
# 485             hear            0.347487
# 486      experiences            0.347224
# 490           turned            0.346556
# 499           refers            0.344388
#
# [88 rows x 2 columns]
#
# In M not in F: Words related with male doctors but didn't appear in female doctor's reviews
#
#             words  similarity_score_m
# 412           guy            0.544299
# 413       husband            0.495748
# 414       skilled            0.488942
# 415        gentle            0.469540
# 416      hospital            0.469241
# 417         saved            0.465627
# 418     brilliant            0.462063
# 419       opinion            0.461688
# 420    procedures            0.460899
# 421         humor            0.457579
# 422  cardiologist            0.452302
# 423           put            0.450173
# 424       members            0.445086
# 425          case            0.436556
# 426         heart            0.434904
# 427          wife            0.434825
# 428       sincere            0.434013
# 429        thanks            0.433058
# 430      recomend            0.433003
# 431         thank            0.428348
# 432           bed            0.427666
# 433           god            0.426812
# 434    treatments            0.425598
# 435        worked            0.424034
# 436        superb            0.423297
# 437         extra            0.423165
# 438     performed            0.422141
# 439          knew            0.421640
# 440         world            0.419380
# 441     confident            0.416315
# ..            ...                 ...
# 470         money            0.391761
# 471        advice            0.391621
# 472      educated            0.391467
# 473       regular            0.390577
# 474    conditions            0.389396
# 475         fully            0.389372
# 476    diagnostic            0.388634
# 477       serious            0.387888
# 478          open            0.387839
# 479        mother            0.386606
# 480      internal            0.385993
# 481     reccomend            0.385982
# 482      interest            0.385626
# 483        giving            0.385116
# 484        second            0.384881
# 485          send            0.383328
# 486    reassuring            0.382318
# 487         speak            0.381866
# 488      pleasure            0.381334
# 489         liked            0.380504
# 490          told            0.380226
# 491         words            0.380195
# 492           ten            0.379698
# 493          stay            0.379390
# 494       testing            0.379067
# 495    profession            0.378436
# 496         clear            0.378177
# 497     satisfied            0.376033
# 498          type            0.375519
# 499      returned            0.375366
#
# [88 rows x 2 columns]
#
# M>F: Similarity score of male doctors higher then that of female doctors
#
#            words  abs_diff
# 348          man  0.244173
# 347        earth  0.166934
# 219       family  0.159494
# 50     excellent  0.144171
# 376         used  0.135330
# 27         great  0.135308
# 252  informative  0.134057
# 400       nurses  0.130239
# 380    condition  0.129849
# 357      treated  0.128893
# 210          met  0.126998
# 344         life  0.126873
# 352        sense  0.119595
# 12          kind  0.116686
# 106      bedside  0.111281
# 374        treat  0.109703
# 78        manner  0.108874
# 91          nice  0.108330
# 98   intelligent  0.107571
# 395          use  0.106430
# 341     probably  0.105995
# 377     treating  0.105661
# 21          good  0.105516
# 193  recommended  0.104428
# 390  outstanding  0.104317
# 255      awesome  0.104141
# 222        field  0.103873
# 19          well  0.103701
# 20           one  0.100651
# 326      nothing  0.100281
# ..           ...       ...
# 244        given  0.010650
# 335         late  0.010232
# 270        might  0.010214
# 92        follow  0.010213
# 257        hurry  0.009978
# 135    internist  0.009402
# 328      service  0.009229
# 336          run  0.008909
# 196   personally  0.008677
# 25          seen  0.008116
# 330      instead  0.007537
# 9         always  0.007511
# 144       spends  0.007386
# 143       visits  0.007379
# 231      waiting  0.007307
# 199       making  0.007222
# 96          past  0.007159
# 74         seems  0.007139
# 112       rushed  0.007090
# 288         must  0.006825
# 339     provides  0.006040
# 227       called  0.005101
# 133          new  0.005005
# 160        phone  0.001972
# 129     practice  0.001653
# 56          love  0.001474
# 151      overall  0.001198
# 70         makes  0.001107
# 212   especially  0.000784
# 108         gone  0.000518
#
# [350 rows x 2 columns]
#
# F>M: Similarity score of female doctors higher then that of male doctors
#
#             words  abs_diff
# 159        waited  0.062586
# 85    appointment  0.055717
# 109  appointments  0.055183
# 128       feeling  0.052753
# 148         spend  0.048588
# 40           work  0.044331
# 68         issues  0.039814
# 66      important  0.036686
# 29       concerns  0.033105
# 177       current  0.031440
# 169         often  0.030795
# 132       usually  0.029700
# 221          hour  0.029115
# 184        rushes  0.028936
# 168       results  0.027350
# 87           last  0.027138
# 64         health  0.026051
# 174       follows  0.025000
# 93      sometimes  0.024831
# 30         seeing  0.024608
# 186      personal  0.023242
# 145    responsive  0.023124
# 235          left  0.022446
# 260      previous  0.021609
# 192        return  0.021439
# 62           wait  0.019948
# 211    incredibly  0.019669
# 134    empathetic  0.019369
# 97        looking  0.018648
# 54          nurse  0.018369
# ..            ...       ...
# 101         gives  0.017383
# 197       changed  0.016778
# 60           rush  0.016265
# 63           long  0.015606
# 131       someone  0.015584
# 194         front  0.014180
# 164          hard  0.013074
# 183       finally  0.012758
# 4          office  0.011838
# 205          seem  0.011006
# 157     something  0.010418
# 188       minutes  0.009412
# 161          rude  0.009210
# 123       primary  0.008583
# 249           etc  0.008247
# 295        trying  0.006413
# 28      attentive  0.005877
# 218         leave  0.004552
# 248     difficult  0.004503
# 139         visit  0.004149
# 120          wish  0.003933
# 34       actually  0.003555
# 305      detailed  0.002342
# 175         thing  0.002131
# 266          less  0.001863
# 254        longer  0.001666
# 217       pleased  0.001447
# 269     insurance  0.000899
# 13            see  0.000214
# 16       thorough  0.000061
#
# [62 rows x 2 columns]

# %% [markdown]
# ### Run Doc2vec - gender & sanction

# %%
# Tag document
import gensim
docs_gs = [] # each review/row is a tagged document.
for i in range(len(documents)):
    docs_gs.append(gensim.models.doc2vec.TaggedDocument(documents[i],  [hasorder[i],gender[i]]))

# %%
docs_gs[0]
# Out:
# TaggedDocument(words=['satisfactory', 'recommend', 'coldness', 'solo', 'helpfulness', 'limited', 'office', 'staff', 'isolation', 'diagnosis', 'solo'], tags=[0, 'F'])

# %%
docs_for_vocab_gs = [] 
for i in docs_gs:
    docs_for_vocab_gs.append(i)

# %%
model_gs = Doc2Vec(dm=0, window=30,vector_size=300,min_count=30,epochs=100,workers=4,
               hs=0,negative=7,dbow_words=1,dm_concat=1)
model_gs.build_vocab(docs_for_vocab_gs)
model_gs.train(documents = docs_gs,total_examples=model_gs.corpus_count,epochs=100)

# %%
model_gs.save("d2v_gs1.model")

# %%
d2v_gs1= Doc2Vec.load("d2v_gs1.model")

# %%
d2v_gs1.wv.most_similar(positive = [d2v_gs1.docvecs[0],d2v_gs1.docvecs['F']],topn=15)
# Out:
# [('dr', 0.8382483124732971),
#  ('doctor', 0.8094700574874878),
#  ('caring', 0.7179374694824219),
#  ('patient', 0.7118537425994873),
#  ('kind', 0.7015848159790039),
#  ('extremely', 0.6905013918876648),
#  ('time', 0.6878834366798401),
#  ('staff', 0.6851698756217957),
#  ('knowledgeable', 0.6844163537025452),
#  ('always', 0.6755608320236206),
#  ('never', 0.6683287620544434),
#  ('really', 0.6661325097084045),
#  ('office', 0.6633327007293701),
#  ('helpful', 0.6618456840515137),
#  ('great', 0.6505095362663269)]

# %%
d2v_gs1.wv.most_similar(positive = [d2v_gs1.docvecs[0],d2v_gs1.docvecs['M']],topn=15)
# Out:
# [('dr', 0.8472877740859985),
#  ('doctor', 0.8312726020812988),
#  ('patient', 0.7375615835189819),
#  ('caring', 0.7362607717514038),
#  ('kind', 0.7360689640045166),
#  ('great', 0.7048937082290649),
#  ('extremely', 0.70399010181427),
#  ('knowledgeable', 0.6948617100715637),
#  ('good', 0.6827594041824341),
#  ('time', 0.6805500984191895),
#  ('professional', 0.679201066493988),
#  ('one', 0.6737104654312134),
#  ('staff', 0.6704651713371277),
#  ('excellent', 0.6696045398712158),
#  ('always', 0.6638321876525879)]

# %%
d2v_gs1.wv.most_similar(positive = [d2v_gs1.docvecs[1],d2v_gs1.docvecs['F']],topn=15)
# Out:
# [('doctor', 0.5625770092010498),
#  ('dr', 0.5559017658233643),
#  ('always', 0.5051372647285461),
#  ('staff', 0.4993571639060974),
#  ('office', 0.48801589012145996),
#  ('caring', 0.48241108655929565),
#  ('never', 0.47603607177734375),
#  ('time', 0.4671357274055481),
#  ('kind', 0.4612017869949341),
#  ('patient', 0.46081849932670593),
#  ('one', 0.46024295687675476),
#  ('see', 0.4597282111644745),
#  ('well', 0.45818468928337097),
#  ('patients', 0.45670783519744873),
#  ('helpful', 0.4463525414466858)]

# %%
d2v_gs1.wv.most_similar(positive = [d2v_gs1.docvecs[1],d2v_gs1.docvecs['M']],topn=15)
# Out:
# [('doctor', 0.5769614577293396),
#  ('dr', 0.5612245202064514),
#  ('always', 0.49770617485046387),
#  ('caring', 0.49418675899505615),
#  ('staff', 0.489698588848114),
#  ('kind', 0.483650267124176),
#  ('well', 0.4821067154407501),
#  ('patient', 0.4772361218929291),
#  ('one', 0.4758063554763794),
#  ('office', 0.4652448296546936),
#  ('patients', 0.4650103449821472),
#  ('never', 0.4641687870025635),
#  ('time', 0.461802214384079),
#  ('care', 0.45553481578826904),
#  ('great', 0.44906601309776306)]

# %% [markdown]
# ### Similar words comparison results -gender & not sanctioned

# %%
nsf = d2v_gs1.wv.most_similar(positive = [d2v_gs1.docvecs[0],d2v_gs1.docvecs['F']],topn=500)
nsm = d2v_gs1.wv.most_similar(positive = [d2v_gs1.docvecs[0],d2v_gs1.docvecs['M']],topn=500)
compare(list1=nsf,list2=nsm)
# Out:
# In F not in M: Words related with female doctors but didn't appear in male doctor's reviews
#
# ..             ...       ...
# 82           cares  0.005354
# 420         advice  0.005197
# 378        working  0.004646
# 129      efficient  0.004599
# 367           rare  0.004467
# 350           plus  0.004457
# 142       although  0.004209
# 50   understanding  0.004089
# 386    specialists  0.004002
# 218       referred  0.003993
# 301           gets  0.003790
# 125         little  0.003711
# 377          keeps  0.003230
# 264          wrong  0.003059
# 141           give  0.003044
# 353         rather  0.002960
# 105            far  0.002722
# 177         detail  0.002470
# 52            talk  0.002217
# 145            got  0.002065
# 172      fantastic  0.001980
# 391           sees  0.001851
# 277          comes  0.001814
# 120          right  0.001597
# 238           deal  0.001416
# 13         helpful  0.001343
# 41         doctors  0.001338
# 134     definitely  0.000945
# 419           type  0.000105
# 69           first  0.000004
#
# [254 rows x 2 columns]
#
# F>M: Similarity score of female doctors higher then that of male doctors
#
#             words  abs_diff
# 126   appointment  0.054731
# 261        waited  0.052904
# 187       feeling  0.044869
# 40       concerns  0.042448
# 79         issues  0.041409
# 235    supportive  0.040582
# 182       usually  0.039700
# 210       current  0.039349
# 189      personal  0.036736
# 72           work  0.036703
# 160  appointments  0.035668
# 191         spend  0.035384
# 84          nurse  0.035283
# 167    empathetic  0.035114
# 37         seeing  0.034947
# 18            see  0.034739
# 12         office  0.034355
# 206         often  0.033824
# 118     sometimes  0.033596
# 68           rush  0.033313
# 316          hour  0.033300
# 107          wait  0.032147
# 297          left  0.031451
# 116          last  0.030940
# 181       someone  0.030268
# 236       results  0.030257
# 223          seem  0.029717
# 140       primary  0.029606
# 96      important  0.028655
# 67         health  0.028372
# ..            ...       ...
# 76          makes  0.003393
# 433      informed  0.003390
# 166        though  0.003368
# 343         shows  0.003242
# 149     genuinely  0.003231
# 371           yes  0.003223
# 304      continue  0.003056
# 345      question  0.002443
# 66        answers  0.002319
# 224           bad  0.002208
# 234    interested  0.002120
# 232    completely  0.002101
# 214       thought  0.002011
# 422        plenty  0.001915
# 158      explains  0.001746
# 161           yet  0.001676
# 104       medical  0.001665
# 248         least  0.001526
# 61      questions  0.001524
# 213         calls  0.001340
# 117      anything  0.001124
# 64            say  0.001029
# 226           amp  0.000762
# 108        almost  0.000688
# 342          look  0.000686
# 197          come  0.000526
# 388      provides  0.000501
# 165        people  0.000412
# 73       punctual  0.000292
# 302           try  0.000092
#
# [196 rows x 2 columns]

# %% [markdown]
# ### Similar words comparison results -gender & sanctioned

# %%
sf = d2v_gs1.wv.most_similar(positive = [d2v_gs1.docvecs[1],d2v_gs1.docvecs['F']],topn=500)
sm = d2v_gs1.wv.most_similar(positive = [d2v_gs1.docvecs[1],d2v_gs1.docvecs['M']],topn=500)
compare(list1=sf,list2=sm)
# Out:
# In F not in M: Words related with female doctors but didn't appear in male doctor's reviews
#
#               words  similarity_score_f
# 277       listening            0.299232
# 294           woman            0.295252
# 295              pa            0.294961
# 310            lady            0.292004
# 311      unfriendly            0.291435
# 316       remembers            0.290402
# 326        physical            0.288599
# 327           waits            0.288242
# 346    receptionist            0.283865
# 353    practitioner            0.281889
# 354         feeling            0.281830
# 363         despite            0.279828
# 365         manager            0.279398
# 367        switched            0.279149
# 371        comments            0.278655
# 398        changing            0.275905
# 399         current            0.275671
# 429          money  0.028808
# 345          treat  0.027495
# 436    outstanding  0.027390
# ..             ...       ...
# 330        working  0.003082
# 339           plus  0.002814
# 197          keeps  0.002748
# 160      efficient  0.002701
# 40   understanding  0.002683
# 171          cares  0.002657
# 279           gets  0.002442
# 184           sees  0.001963
# 288           thru  0.001923
# 136           give  0.001908
# 218         little  0.001762
# 421       referred  0.001696
# 347    incompetent  0.001665
# 384       although  0.001499
# 125            far  0.001391
# 387        support  0.001319
# 188         saying  0.001245
# 149            got  0.001159
# 216      fantastic  0.000962
# 84            talk  0.000819
# 249           deal  0.000778
# 201          helps  0.000726
# 14         helpful  0.000449
# 192            try  0.000259
# 85          people  0.000216
# 37          almost  0.000214
# 235       provides  0.000144
# 80         doctors  0.000044
# 270          right  0.000041
# 46        campbell  0.000007
#
# [248 rows x 2 columns]
#
# F>M: Similarity score of female doctors higher then that of male doctors
#
#             words  abs_diff
# 223     assistant  0.041973
# 135   appointment  0.036986
# 248        waited  0.035573
# 251     generally  0.034595
# 152     referrals  0.030461
# 76       concerns  0.029323
# 263  consistently  0.028125
# 90         issues  0.028100
# 242        behind  0.026159
# 89        usually  0.026076
# 28           dube  0.025312
# 99           work  0.025101
# 128      personal  0.024434
# 290         spend  0.024352
# 164  appointments  0.024114
# 61          nurse  0.023598
# 138    empathetic  0.023517
# 30         seeing  0.023502
# 11            see  0.023317
# 97           rush  0.022874
# 4          office  0.022771
# 105     sometimes  0.022605
# 224          hour  0.022132
# 60         rarely  0.022072
# 51          often  0.021508
# 202          left  0.020851
# 29           wait  0.020667
# 74           last  0.020521
# 182       someone  0.020468
# 173       primary  0.020274
# ..            ...       ...
# 237         agree  0.002301
# 377           yet  0.002262
# 140        though  0.002219
# 326      explains  0.002149
# 307           yes  0.002108
# 274         shows  0.002103
# 296      anything  0.001914
# 119       quality  0.001704
# 256       thought  0.001661
# 227           bad  0.001589
# 261          dont  0.001577
# 52        answers  0.001520
# 230    completely  0.001499
# 306    healthcare  0.001497
# 393      favorite  0.001493
# 392         touch  0.001305
# 82            say  0.001184
# 413          ways  0.001078
# 426          look  0.001013
# 273          come  0.000860
# 176         least  0.000825
# 266           amp  0.000817
# 100      punctual  0.000657
# 42        medical  0.000558
# 394          lots  0.000404
# 109         calls  0.000389
# 425          sits  0.000240
# 403         reach  0.000228
# 71          first  0.000219
# 342        amount  0.000061
#
# [196 rows x 2 columns]

# %% [markdown]
# ### Run Doc2vec - gender & sanction (downsampling)

# %%
#1000 sanction male/female reviews and 1000 not sanction male/female reviews
import random
repeat = {}
indices = []
batch = []
draw = 1000
sf_candidates = list(review_im[np.logical_and(review_im['hasorder']==1, review_im['gender']=='F')].index)
sm_candidates = list(review_im[np.logical_and(review_im['hasorder']==1, review_im['gender']=='M')].index)
nsf_candidates = list(review_im[np.logical_and(review_im['hasorder']==0, review_im['gender']=='F')].index)
nsm_candidates = list(review_im[np.logical_and(review_im['hasorder']==0, review_im['gender']=='M')].index)
for b in range(draw):
    sf = random.choice(sf_candidates)
    sm = random.choice(sm_candidates)
    indices.append(sf)
    indices.append(sm)
    nsf = random.choice(nsf_candidates)
    nsm = random.choice(nsm_candidates)
    indices.append(nsf)
    indices.append(nsm)
for i in indices:
    try:
        repeat[i]+=1
    except:
        repeat[i]=1
    batch.append(docs_gs[i])

# %%
batch[1]
# Out:
# TaggedDocument(words=['year', 'old', 'mother', 'doctor', 'handled', 'medical', 'problems', 'efficiently', 'quickly'], tags=[1, 'M'])

# %%
model_gs2 = Doc2Vec(dm=0, window=30,vector_size=300,min_count=30,epochs=100,workers=4,
               hs=0,negative=7,dbow_words=1,dm_concat=1)
model_gs2.build_vocab(docs_for_vocab_gs)
model_gs2.train(documents = batch,total_examples=model_gs2.corpus_count,epochs=100)

# %%
model_gs2.save("d2v_gs2.model")

# %%
d2v_gs2= Doc2Vec.load("d2v_gs2.model")

# %%
d2v_gs2.wv.most_similar(positive = [d2v_gs2.docvecs[0],d2v_gs2.docvecs['F']],topn=15)
# Out:
# [('dr', 0.6020839810371399),
#  ('awsome', 0.47494271397590637),
#  ('doctor', 0.47274988889694214),
#  ('impolite', 0.46135926246643066),
#  ('pompous', 0.45513975620269775),
#  ('inexperienced', 0.449698269367218),
#  ('energetic', 0.445687860250473),
#  ('appropriately', 0.43323108553886414),
#  ('barbara', 0.4282136559486389),
#  ('stick', 0.42703840136528015),
#  ('tom', 0.4258250892162323),
#  ('aetna', 0.4186226725578308),
#  ('north', 0.4080013036727905),
#  ('america', 0.40761807560920715),
#  ('reassured', 0.400024950504303)]

# %%
d2v_gs2.wv.most_similar(positive = [d2v_gs2.docvecs[0],d2v_gs2.docvecs['M']],topn=15)
# Out:
# [('dr', 0.5665391087532043),
#  ('doctor', 0.47637856006622314),
#  ('pompous', 0.4653067886829376),
#  ('energetic', 0.4551064074039459),
#  ('tom', 0.4449748992919922),
#  ('apply', 0.43487924337387085),
#  ('awsome', 0.43423449993133545),
#  ('angioplasty', 0.43408894538879395),
#  ('barbara', 0.4332249164581299),
#  ('aid', 0.42949095368385315),
#  ('aetna', 0.42615213990211487),
#  ('inserted', 0.4257005453109741),
#  ('developed', 0.4147881269454956),
#  ('astute', 0.4129182994365692),
#  ('picking', 0.40869128704071045)]

# %%
d2v_gs2.wv.most_similar(positive = [d2v_gs2.docvecs[1],d2v_gs2.docvecs['F']],topn=15)
# Out:
# [('dr', 0.5927680730819702),
#  ('aetna', 0.4869834780693054),
#  ('awsome', 0.48465782403945923),
#  ('pompous', 0.4734799265861511),
#  ('inexperienced', 0.4649198055267334),
#  ('impolite', 0.45495229959487915),
#  ('doctor', 0.4374799132347107),
#  ('energetic', 0.42345237731933594),
#  ('time', 0.4170688986778259),
#  ('reassured', 0.4074348211288452),
#  ('paul', 0.40258002281188965),
#  ('stick', 0.40172356367111206),
#  ('likeable', 0.399562805891037),
#  ('staff', 0.3992134928703308),
#  ('relates', 0.3986293077468872)]

# %%
d2v_gs2.wv.most_similar(positive = [d2v_gs2.docvecs[1],d2v_gs2.docvecs['M']],topn=15)
# Out:
# [('dr', 0.5355526208877563),
#  ('aetna', 0.47160065174102783),
#  ('pompous', 0.45995497703552246),
#  ('awsome', 0.4286330044269562),
#  ('doctor', 0.41925978660583496),
#  ('complication', 0.41800248622894287),
#  ('time', 0.41488999128341675),
#  ('energetic', 0.41089513897895813),
#  ('alternate', 0.3918306231498718),
#  ('lol', 0.38481441140174866),
#  ('likeable', 0.3833930492401123),
#  ('relates', 0.3789610266685486),
#  ('robert', 0.37827861309051514),
#  ('reassured', 0.3720431327819824),
#  ('extremly', 0.37180835008621216)]

# %% [markdown]
# ### Similar words comparison results - gender & not sanctioned (downsampling)

# %%
nf1 = d2v_gs2.wv.most_similar(positive = [d2v_gs2.docvecs[0],d2v_gs2.docvecs['F']],topn=500)
nm1 = d2v_gs2.wv.most_similar(positive = [d2v_gs2.docvecs[0],d2v_gs2.docvecs['M']],topn=500)
compare(list1=nf1,list2=nm1)
# Out:
# In F not in M: Words related with female doctors but didn't appear in male doctor's reviews
#
#              words  similarity_score_f
# 28          relies            0.361435
# 44         approve            0.348098
# 57         cancels            0.339005
# 62         develop            0.333981
# 72          duties            0.326829
# 76       primarily            0.325781
# 78           ideas            0.324189
# 98          joking            0.317783
# 104         regret            0.315557
# 108        deliver            0.314397
# 110       ignorant            0.314161
# 114        bizarre            0.313313
# 118         sample            0.312910
# 119     unreliable            0.312875
# 122      indicates            0.311597
# 128  argumentative            0.307396
# 131            boy            0.306350
# 133        privacy            0.305446
# 137    challenging            0.304381
# 138    inefficient            0.304134
# 153         behalf            0.301243
# 154       precious            0.301243
# 155      neglected            0.301096
# 158        chances            0.300453
# 160     assistance            0.300090
# 161         proved            0.300030
# 164            hey            0.299427
# 166      attitudes            0.299359
# 168        reduced            0.298626
# 170           onto            0.298263
# ..             ...                 ...
# 437           grow            0.265236
# 439       protocol            0.265027
# 440       homework            0.265012
# 441   debilitating            0.264897
# 442          blows            0.264766
# 443  communicating            0.264756
# 445          sinai            0.264562
# 448       symptons            0.264220
# 452        wearing            0.263750
# 453       charging            0.263431
# 456    unconcerned            0.263100
# 457          noone            0.263063
# 460         recall            0.262800
# 461            bat            0.262733
# 462          grown            0.262470
# 464        proceed            0.262336
# 467             fl            0.261900
# 468        atlanta            0.261829
# 469     suggestion            0.261603
# 471        renewed            0.261554
# 472         candid            0.261455
# 478  documentation            0.260786
# 479          nancy            0.260728
# 482           well            0.260443
# 484            pro            0.260094
# 490        useless            0.259721
# 492          brand            0.259579
# 495          brain            0.259201
# 496     permission            0.259013
# 498           scam            0.258834
#
# [196 rows x 2 columns]
#
# In M not in F: Words related with male doctors but didn't appear in female doctor's reviews
#
#              words  similarity_score_m
# 304            egd            0.360621
# 305           sooo            0.352774
# 306         headed            0.348554
# 307     prevention            0.343284
# 308        dosages            0.343122
# 309        teacher            0.341211
# 310          ankle            0.336066
# 311          jokes            0.335597
# 312       national            0.332673
# 313           ross            0.330229
# 314      character            0.329633
# 315       watching            0.327958
# 316       infected            0.327153
# 317     recommends            0.326303
# 318           mask            0.325068
# 319          saint            0.325016
# 320          ortho            0.320854
# 321        entered            0.317093
# 322           clot            0.315975
# 323       terribly            0.315453
# 324         solved            0.313454
# 325     borderline            0.312487
# 326            fed            0.312316
# 327          march            0.312235
# 328      prevented            0.311846
# 329         anemia            0.311520
# 330      privilege            0.310992
# 331           pass            0.310300
# 332          xanax            0.309791
# 333      insisting            0.309748
# ..             ...                 ...
# 470         sudden            0.268873
# 471        turning            0.268411
# 472  interpersonal            0.268224
# 473          chair            0.268145
# 474           soul            0.267968
# 475           pray            0.267556
# 476        reminds            0.267549
# 477       bleeding            0.267481
# 478         argued            0.267230
# 479    possibility            0.267176
# 480     insurances            0.266917
# 481       jennifer            0.266606
# 482      dismisses            0.266308
# 483      monitored            0.265988
# 484         misses            0.265866
# 485          takes            0.265329
# 486            mos            0.265060
# 487      affecting            0.264924
# 488           ring            0.264823
# 489          hills            0.264781
# 490       welcomed            0.264736
# 491         public            0.264638
# 492        chaotic            0.264431
# 493           jobs            0.264269
# 494         austin            0.264262
# 495      reference            0.264113
# 496             ga            0.264109
# 497          south            0.263713
# 498       advocate            0.263685
# 499        mothers            0.263470
#
# [196 rows x 2 columns]
#
# M>F: Similarity score of male doctors higher then that of female doctors
#
#             words  abs_diff
# 205         xrays  0.115161
# 118     developed  0.110207
# 100        astute  0.098786
# 176          ages  0.096310
# 52    angioplasty  0.094479
# 61       inserted  0.093173
# 89        picking  0.089066
# 161     alternate  0.087830
# 224       miracle  0.078113
# 300       melamed  0.072454
# 167          unit  0.070191
# 285      patients  0.069896
# 262     interpret  0.069740
# 292       compare  0.061908
# 191   unimportant  0.059629
# 239        sooner  0.059259
# 298         moves  0.059100
# 106  complication  0.058503
# 275         seven  0.056494
# 129           one  0.056083
# 248    insightful  0.055743
# 108       undergo  0.054129
# 270      directed  0.054025
# 293  pancreatitis  0.053379
# 253      shoulder  0.052750
# 209   forthcoming  0.052195
# 207     competant  0.052180
# 21            aid  0.051758
# 277           fib  0.051269
# 255          wide  0.050799
# ..            ...       ...
# 245            pc  0.007765
# 11          aetna  0.007529
# 192           toe  0.006636
# 299       screwed  0.006448
# 232      interact  0.006192
# 74     perscribed  0.005288
# 265        miller  0.005285
# 189       cursory  0.005025
# 8         barbara  0.005011
# 31          fresh  0.004572
# 297   attentively  0.004469
# 54        arizona  0.004153
# 163          lies  0.004043
# 2          doctor  0.003629
# 53          chang  0.003400
# 258          mark  0.003296
# 290        loudly  0.002919
# 16       likeable  0.002877
# 286         steps  0.002777
# 251         deals  0.002663
# 193  hematologist  0.001944
# 84        tricare  0.001917
# 62           ercp  0.001502
# 92          colds  0.001336
# 281     endocrine  0.001251
# 180        judged  0.001163
# 272   undiagnosed  0.001135
# 221           psa  0.000966
# 225             z  0.000813
# 124      biopsies  0.000450
#
# [188 rows x 2 columns]
#
# F>M: Similarity score of female doctors higher then that of male doctors
#
#               words  abs_diff
# 3          impolite  0.156874
# 5     inexperienced  0.121103
# 12            north  0.100716
# 13          america  0.097578
# 32            speed  0.080469
# 35       suggesting  0.070973
# 20             boot  0.067422
# 19            bully  0.066820
# 45           insane  0.065595
# 22             firm  0.065261
# 15       recommened  0.061288
# 46      responsible  0.058786
# 57          rapidly  0.058232
# 71          explore  0.057086
# 51         paitents  0.056500
# 83       remembered  0.055639
# 65             shut  0.055502
# 33         increase  0.054581
# 98              mix  0.050912
# 77         bringing  0.050712
# 38            smear  0.050465
# 60           google  0.048812
# 7     appropriately  0.046004
# 28             care  0.041253
# 1            awsome  0.040708
# 112           cheap  0.040457
# 23            staff  0.038525
# 76            ulcer  0.037143
# 103         stellar  0.037134
# 26            piece  0.036808
# ..              ...       ...
# 159          dumped  0.011180
# 203       pertinent  0.011154
# 185         clinics  0.010948
# 41      progressive  0.010916
# 217            near  0.010576
# 227     disregarded  0.008586
# 202        relevant  0.008538
# 113           dream  0.008281
# 155  pharmaceutical  0.007800
# 107         zubaidi  0.007181
# 236         teaches  0.007024
# 168     specialties  0.006024
# 73             ohio  0.005838
# 99     continuously  0.005520
# 56          carring  0.005262
# 206         distant  0.005084
# 126       resources  0.004920
# 147            food  0.004532
# 220       disagreed  0.004307
# 48           earned  0.004037
# 184        horribly  0.003389
# 235           eager  0.003388
# 179      accurately  0.003366
# 79          relates  0.002919
# 146      requesting  0.002334
# 37          shooter  0.001624
# 153              mr  0.001320
# 171   disinterested  0.001011
# 102         suffers  0.000582
# 242           enter  0.000122
#
# [116 rows x 2 columns]

# %% [markdown]
# ### Similar words comparison results - gender & sanctioned (downsampling)

# %%
sf1 = d2v_gs2.wv.most_similar(positive = [d2v_gs2.docvecs[1],d2v_gs2.docvecs['F']],topn=500)
sm1 = d2v_gs2.wv.most_similar(positive = [d2v_gs2.docvecs[1],d2v_gs2.docvecs['M']],topn=500)
compare(list1=sf1,list2=sm1)
# Out:
# In F not in M: Words related with female doctors but didn't appear in male doctor's reviews
#
#               words  similarity_score_f
# 37             dube            0.353419
# 55          approve            0.330949
# 59              hey            0.326947
# 61            peers            0.324745
# 78           duties            0.318524
# 88            ideas            0.316339
# 95      challenging            0.313021
# 100      suggesting            0.311897
# 117          behalf            0.308679
# 119    communicator            0.308363
# 127          proved            0.303718
# 133           valid            0.301097
# 154       intensive            0.296650
# 158        ignorant            0.295476
# 173             mix            0.291265
# 175             boy            0.290904
# 187          relies            0.287942
# 188      contracted            0.287924
# 192           copay            0.287079
# 193        campbell            0.286070
# 200        assisted            0.285516
# 202      wonderfull            0.284815
# 211      colleagues            0.282272
# 213         develop            0.281970
# 215         handles            0.281895
# 221          kramer            0.280760
# 223         chances            0.280149
# 231     inefficient            0.277873
# 235   approximately            0.277091
# 237            risk            0.276096
# ..              ...                 ...
# 449          wished            0.248427
# 450         squeeze            0.248182
# 452          insist            0.247914
# 453          peters            0.247866
# 454        bringing            0.247778
# 455    continuously            0.247741
# 457            gerd            0.247616
# 458          unkind            0.247529
# 460         pressed            0.247377
# 461          lesson            0.247334
# 462    subsequently            0.247183
# 468          caught            0.246679
# 469     malpractice            0.246449
# 470         bizarre            0.246337
# 471          chairs            0.246327
# 475       perfectly            0.245212
# 476            mild            0.245180
# 478         deliver            0.244965
# 479            vast            0.244784
# 485      threatened            0.244283
# 486   knowledgeable            0.244188
# 488          extent            0.244131
# 489            near            0.243946
# 491         screwed            0.243721
# 492         concept            0.243662
# 493  unprofessional            0.243520
# 494          adults            0.243177
# 497     responsible            0.242923
# 498        constant            0.242878
# 499          lovely            0.242867
#
# [153 rows x 2 columns]
#
# In M not in F: Words related with male doctors but didn't appear in female doctor's reviews
#
rows x 2 columns]
#
# F>M: Similarity score of female doctors higher then that of male doctors
#
#                words  abs_diff
# 5           impolite  0.150406
# 4      inexperienced  0.121068
# 25         primarily  0.110452
# 32            regret  0.108561
# 17             north  0.101410
# 23           america  0.098571
# 20           cancels  0.082518
# 15        unreliable  0.082159
# 53              boot  0.071860
# 63             bully  0.071142
# 49              firm  0.070190
# 94            insane  0.069183
# 66            pursue  0.068981
# 87        recommened  0.066676
# 48            poster  0.065383
# 81            snotty  0.063830
# 44           rapidly  0.063790
# 105        violation  0.062929
# 33         attitudes  0.062767
# 64          paitents  0.061906
# 103           joking  0.061878
# 95           explore  0.061798
# 117        neglected  0.061739
# 45        remembered  0.061374
# 92          increase  0.060340
# 130          reduced  0.058781
# 134            allen  0.057433
# 0                 dr  0.057215
# 16     appropriately  0.057002
# 2             awsome  0.056025
# ..               ...       ...
# 272           wisdom  0.007089
# 310         replaced  0.006585
# 109          partial  0.006545
# 162              jan  0.006530
# 128             guys  0.006405
# 282            apnea  0.006301
# 26     pulmonologist  0.006005
# 327               pc  0.005671
# 74             falls  0.005562
# 193            shore  0.005477
# 257         intently  0.004608
# 285           deeply  0.004453
# 223             harm  0.004327
# 298         occurred  0.003916
# 236              pet  0.002678
# 129          caution  0.002649
# 77        adequately  0.002513
# 240           facing  0.002226
# 242       congestive  0.002184
# 8               time  0.002179
# 252       beneficial  0.001245
# 346            panel  0.001196
# 245             jobs  0.001086
# 216            lewis  0.000981
# 122  straightforward  0.000914
# 299            sturn  0.000893
# 267       registered  0.000556
# 75            stands  0.000435
# 333         invasive  0.000360
# 146           cookie  0.000340
#
# [191 rows x 2 columns]

# %% [markdown]
# ### Run Doc2vec - gender & sanction (upsampling)

# %%
#1000 sanction male/female reviews and 1000 not sanction male/female reviews
import random
repeat = {}
indices = []
batch2 = []
draw = 10000
sf_candidates = list(review_im[np.logical_and(review_im['hasorder']==1, review_im['gender']=='F')].index)
sm_candidates = list(review_im[np.logical_and(review_im['hasorder']==1, review_im['gender']=='M')].index)
nsf_candidates = list(review_im[np.logical_and(review_im['hasorder']==0, review_im['gender']=='F')].index)
nsm_candidates = list(review_im[np.logical_and(review_im['hasorder']==0, review_im['gender']=='M')].index)
for b in range(draw):
    sf = random.choice(sf_candidates)
    sm = random.choice(sm_candidates)
    indices.append(sf)
    indices.append(sm)
    nsf = random.choice(nsf_candidates)
    nsm = random.choice(nsm_candidates)
    indices.append(nsf)
    indices.append(nsm)
for i in indices:
    try:
        repeat[i]+=1
    except:
        repeat[i]=1
    batch2.append(docs_gs[i])

# %%
len(batch2)
# Out:
# 40000

# %%
model_gs3 = Doc2Vec(dm=0, window=30,vector_size=300,min_count=30,epochs=100,workers=4,
               hs=0,negative=7,dbow_words=1,dm_concat=1)
model_gs3.build_vocab(docs_for_vocab_gs)
model_gs3.train(documents = batch2,total_examples=model_gs2.corpus_count,epochs=100)

# %%
model_gs3.save("d2v_gs3.model")

# %%
d2v_gs3= Doc2Vec.load("d2v_gs3.model")

# %%
d2v_gs3.wv.most_similar(positive = [d2v_gs3.docvecs[0],d2v_gs3.docvecs['F']],topn=15)
# Out:
# [('dr', 0.5724689364433289),
#  ('doctor', 0.49950820207595825),
#  ('time', 0.43546438217163086),
#  ('staff', 0.4080578684806824),
#  ('office', 0.3696812391281128),
#  ('patient', 0.36583051085472107),
#  ('care', 0.36055541038513184),
#  ('one', 0.3587050437927246),
#  ('see', 0.35299962759017944),
#  ('never', 0.35087186098098755),
#  ('questions', 0.3377339243888855),
#  ('years', 0.3343408405780792),
#  ('found', 0.33351242542266846),
#  ('manner', 0.32705754041671753),
#  ('bedside', 0.32702577114105225)]

# %%
d2v_gs3.wv.most_similar(positive = [d2v_gs3.docvecs[0],d2v_gs3.docvecs['M']],topn=15)
# Out:
# [('dr', 0.4985211491584778),
#  ('doctor', 0.4801616370677948),
#  ('one', 0.40479540824890137),
#  ('time', 0.3816603422164917),
#  ('highly', 0.37834638357162476),
#  ('top', 0.3756328821182251),
#  ('well', 0.3724502623081207),
#  ('compassionate', 0.36480942368507385),
#  ('really', 0.35604971647262573),
#  ('years', 0.35145482420921326),
#  ('bad', 0.3506760001182556),
#  ('patients', 0.3496653139591217),
#  ('caring', 0.3473668098449707),
#  ('excellent', 0.34657877683639526),
#  ('never', 0.34541070461273193)]

# %%
d2v_gs3.wv.most_similar(positive = [d2v_gs3.docvecs[1],d2v_gs3.docvecs['F']],topn=15)
# Out:
# [('dr', 0.5598286390304565),
#  ('doctor', 0.42158520221710205),
#  ('time', 0.3732236325740814),
#  ('staff', 0.3562275171279907),
#  ('care', 0.35531941056251526),
#  ('office', 0.32850828766822815),
#  ('dube', 0.2996673583984375),
#  ('years', 0.29861557483673096),
#  ('patient', 0.29857200384140015),
#  ('one', 0.2943735122680664),
#  ('see', 0.2917926609516144),
#  ('never', 0.2857934832572937),
#  ('even', 0.27929872274398804),
#  ('rude', 0.2738555669784546),
#  ('medical', 0.2731856107711792)]

# %%
d2v_gs3.wv.most_similar(positive = [d2v_gs3.docvecs[1],d2v_gs3.docvecs['M']],topn=15)
# Out:
# [('dr', 0.5190690755844116),
#  ('doctor', 0.41704756021499634),
#  ('time', 0.3429281711578369),
#  ('one', 0.33390501141548157),
#  ('care', 0.32987773418426514),
#  ('years', 0.3174331784248352),
#  ('staff', 0.31650128960609436),
#  ('well', 0.3153061270713806),
#  ('office', 0.3011116683483124),
#  ('good', 0.28827792406082153),
#  ('never', 0.2882222533226013),
#  ('patients', 0.2870241105556488),
#  ('patient', 0.28100883960723877),
#  ('caring', 0.27199840545654297),
#  ('always', 0.26913994550704956)]

# %% [markdown]
# ### Similar words comparison results - gender & not sanctioned (upsampling)

# %%
nf2 = d2v_gs3.wv.most_similar(positive = [d2v_gs3.docvecs[0],d2v_gs3.docvecs['F']],topn=500)
nm2 = d2v_gs3.wv.most_similar(positive = [d2v_gs3.docvecs[0],d2v_gs3.docvecs['M']],topn=500)
compare(list1=nf2,list2=nm2)
# Out:
# In F not in M: Words related with female doctors but didn't appear in male doctor's reviews
#
#              words  similarity_score_f
# 43      responsive            0.293909
# 54            felt            0.290385
# 61          decade            0.288083
# 64           fever            0.286880
# 77            dube            0.282448
# 82          issues            0.280580
# 87    subsequently            0.279354
# 100          nurse            0.276921
# 101            mix            0.276708
# 108             sp            0.275589
# 111        removal            0.275175
# 117      defensive            0.274421
# 126       practice            0.272357
# 130    transferred            0.271254
# 131        answers            0.271235
# 136       negative            0.270184
# 138         lovely            0.269893
# 139       demeanor            0.269754
# 143         marrow            0.268777
# 144          lymph            0.268651
# 147           lump            0.267561
# 148            ups            0.267146
# 149      bothering            0.266896
# 151           list            0.266504
# 154        another            0.266021
# 155           hour            0.265926
# 156           test            0.265830
# 160    unsatisfied            0.264961
# 161           told            0.264690
# 162           sold            0.264066
# ..             ...                 ...
# 460      voicemail            0.230692
# 461      insurance            0.230684
# 462        dropped            0.230646
# 467   disorganized            0.230340
# 468            pas            0.230325
# 469             nd            0.230309
# 470          reads            0.230235
# 471       reflects            0.230156
# 473      regarding            0.229861
# 474  diagnostician            0.229785
# 475            box            0.229660
# 478         topics            0.229553
# 480      certified            0.229302
# 481       followed            0.229259
# 482        extreme            0.229044
# 483            end            0.228938
# 484         series            0.228870
# 485     congestive            0.228756
# 486         waited            0.228735
# 487          enemy            0.228725
# 489        calling            0.228574
# 490       remember            0.228521
# 491      physicals            0.228511
# 492         nurses            0.228477
# 494          davis            0.228383
# 495         letter            0.228332
# 496      discharge            0.228192
# 497        explore            0.228070
# 498        scripts            0.228045
# 499           last            0.227907
#
# [203 rows x 2 columns]
#
# In M not in F: Words related with male doctors but didn't appear in female doctor's reviews
#
#               words  similarity_score_m
# 297           needs            0.337003
# 298          family            0.317126
# 299            kind            0.316699
# 300             man            0.315545
# 301            help            0.309318
# 302        accurate            0.305144
# 303           treat            0.301793
# 304            hard            0.295178
# 305            life            0.294867
# 306             guy            0.294333
# 307       procedure            0.290909
# 308           drugs            0.290002
# 309          skills            0.288346
# 310        hospital            0.286339
# 311         treated            0.284204
# 312          within            0.283220
# 313        diagnose            0.283038
# 314          little            0.282520
# 315            sure            0.280069
# 316            came            0.278047
# 317          person            0.277181
# 318           clear            0.276467
# 319    cardiologist            0.275843
# 320           extra            0.273572
# 321            long            0.271799
# 322             try            0.271338
# 323              us            0.269906
# 324       brilliant            0.269031
# 325      procedures            0.267600
# 326          worked            0.267373
# ..              ...                 ...
# 470        husbands            0.234942
# 471        honestly            0.234856
# 472           loved            0.234694
# 473     informative            0.234679
# 474       amazingly            0.234567
# 475      medication            0.234479
# 476            plus            0.233771
# 477         surgeon            0.233734
# 478        regarded            0.233693
# 479           arise            0.233362
# 480           score            0.233296
# 481           thank            0.233180
# 482          walked            0.233161
# 483            sent            0.232905
# 484        multiple            0.232672
# 485     specializes            0.232519
# 486          bright            0.232455
# 487          looked            0.232259
# 488           cause            0.232176
# 489   authorization            0.232118
# 490         looking            0.231952
# 491           blood            0.231842
# 492           least            0.231730
# 493    pediatrician            0.231693
# 494            room            0.231375
# 495  unknowledgable            0.231356
# 496             let            0.231234
# 497            rash            0.231216
# 498            make            0.231066
# 499            says            0.230985
#
# [203 rows x 2 columns]
#
# M>F: Similarity score of male doctors higher then that of female doctors
#
#              words  abs_diff
# 221  compassionate  0.119823
# 213            bad  0.104187
# 159      excellent  0.089169
# 241          cares  0.083992
# 152          takes  0.078042
# 127         polite  0.076942
# 82          really  0.076725
# 126     definitely  0.075490
# 194         helped  0.073510
# 40            well  0.073095
# 34             top  0.073048
# 285            put  0.070250
# 144           nice  0.069921
# 80          caring  0.067926
# 85     intelligent  0.066911
# 19          highly  0.065643
# 97        listened  0.064814
# 239         change  0.063070
# 105      something  0.058182
# 189    recommended  0.057147
# 207           rush  0.055921
# 247       problems  0.053685
# 68      completely  0.052672
# 230      condition  0.052602
# 209   knowledgable  0.052298
# 101          field  0.052058
# 242        willing  0.050372
# 199       switched  0.049708
# 56            area  0.048880
# 66            good  0.047030
# ..             ...       ...
# 282     treatments  0.006887
# 25            best  0.006809
# 280      medicines  0.006698
# 149  communicating  0.006106
# 173         almost  0.005564
# 73          rather  0.005227
# 277       friendly  0.005135
# 185           sees  0.004875
# 240    experiences  0.004728
# 293            far  0.004532
# 112            say  0.004401
# 205          cruel  0.004367
# 258           gave  0.004365
# 44           think  0.004142
# 287          solid  0.003820
# 273           pain  0.003628
# 193           rock  0.003600
# 179           take  0.003580
# 46        listener  0.003545
# 296         warmth  0.003466
# 115         shares  0.003082
# 263        waiting  0.002951
# 254            doc  0.002825
# 227      intuitive  0.002800
# 186           used  0.002689
# 251          quick  0.002559
# 99            know  0.001454
# 27       competent  0.001340
# 276          given  0.001024
# 55         clearly  0.000088
#
# [173 rows x 2 columns]
#
# F>M: Similarity score of female doctors higher then that of male doctors
#
#              words  abs_diff
# 10       questions  0.081825
# 0               dr  0.073948
# 39       treatment  0.066739
# 3            staff  0.066429
# 8              see  0.065673
# 47            rude  0.058178
# 2             time  0.053804
# 69         primary  0.051764
# 4           office  0.048342
# 6             care  0.046329
# 84        survived  0.045256
# 57           sadly  0.045151
# 48            need  0.043812
# 45            mono  0.043376
# 54           manor  0.042341
# 78            back  0.041978
# 32         medical  0.041852
# 102         method  0.041564
# 93         results  0.040190
# 42             esp  0.038815
# 96    misdiagnosed  0.038157
# 60          direct  0.037835
# 103        managed  0.035486
# 94        bringing  0.035228
# 5          patient  0.033772
# 107          women  0.032227
# 53       literally  0.031465
# 58         degrees  0.030090
# 29   knowledgeable  0.029114
# 18             lot  0.027710
# ..             ...       ...
# 234          order  0.008499
# 206          nodes  0.008448
# 74         outside  0.008426
# 151        thyroid  0.008205
# 216         health  0.007781
# 158         listen  0.007362
# 135         needed  0.006557
# 130       diabetes  0.006103
# 9            never  0.005461
# 245          ulcer  0.005267
# 155          susan  0.005138
# 166         prompt  0.004859
# 108             md  0.004306
# 87         concern  0.003945
# 210   expectations  0.003093
# 218         twenty  0.002954
# 268         lesson  0.002946
# 261     university  0.002918
# 147          major  0.002721
# 117     thoroughly  0.002721
# 81    professional  0.002447
# 267       medicine  0.002296
# 176          spend  0.002239
# 211      unhelpful  0.001983
# 208         latest  0.001785
# 270           dead  0.001672
# 118           made  0.001455
# 228          times  0.001185
# 253         smiled  0.001172
# 145         spinal  0.000097
#
# [124 rows x 2 columns]

# %% [markdown]
# ### Similar words comparison results - gender & sanctioned (upsampling)

# %%
sf2 = d2v_gs3.wv.most_similar(positive = [d2v_gs3.docvecs[1],d2v_gs3.docvecs['F']],topn=500)
sm2 = d2v_gs3.wv.most_similar(positive = [d2v_gs3.docvecs[1],d2v_gs3.docvecs['M']],topn=500)
compare(list1=sf2,list2=sm2)
# Out:
# In F not in M: Words related with female doctors but didn't appear in male doctor's reviews
#
#             words  similarity_score_f
# 89    transferred            0.205109
# 90             sp            0.204859
# 91           mail            0.204621
# 98       selected            0.203490
# 101          lump            0.201917
# 107        marrow            0.200108
# 121     defensive            0.196381
# 123      oncology            0.195212
# 128           new            0.194483
# 130         goals            0.193690
# 133    responsive            0.193088
# 150       extreme            0.190991
# 151          back            0.190881
# 156  subsequently            0.189805
# 163        insure            0.188943
# 179       judging            0.186008
# 183         seems            0.185348
# 186          hang            0.184902
# 188          list            0.184736
# 191        mainly            0.184239
# 194        answer            0.184134
# 196      comments            0.183764
# 199         voice            0.183468
# 208       primary            0.182858
# 209    geriatrics            0.182759
# 215          sold            0.181139
# 216         notes            0.181088
# 217       barbara            0.181081
# 222         sadly            0.180745
# 227     prescribe            0.180099
# ..            ...                 ...
# 449          done            0.161986
# 450         vague            0.161961
# 454         xanax            0.161819
# 455   encountered            0.161792
# 456        system            0.161743
# 457     voicemail            0.161649
# 458        became            0.161623
# 459           etc            0.161574
# 460       clearly            0.161509
# 461        begged            0.161470
# 463           bar            0.161333
# 464     urologist            0.161309
# 465          hour            0.161252
# 468       history            0.161046
# 469          away            0.161027
# 470        astute            0.160984
# 471  receptionist            0.160981
# 472      addicted            0.160945
# 473  expectations            0.160675
# 475           ass            0.160432
# 476           fib            0.160410
# 479       offered            0.160318
# 485     improving            0.160096
# 488    introduced            0.160047
# 491         using            0.159966
# 495         meant            0.159768
# 496         susan            0.159768
# 497      grateful            0.159670
# 498          seem            0.159543
# 499            md            0.159524
#
# [175 rows x 2 columns]
#
# In M not in F: Words related with male doctors but didn't appear in female doctor's reviews
#
#               words  similarity_score_m
# 325   compassionate            0.246715
# 326           drugs            0.229082
# 327            help            0.227446
# 328             man            0.226206
# 329           treat            0.218446
# 330         disease            0.217946
# 331           cares            0.216320
# 332            kind            0.215937
# 333          really            0.215050
# 334  administration            0.212837
# 335             guy            0.209177
# 336       procedure            0.208181
# 337        handling            0.205252
# 338         believe            0.204496
# 339       brilliant            0.202373
# 340         treated            0.201710
# 341        physcian            0.201491
# 342            drug            0.200295
# 343        listened            0.200116
# 344            came            0.199857
# 345         willing            0.198076
# 346             led            0.197769
# 347        probably            0.197237
# 348          skills            0.196283
# 349      medication            0.195847
# 350            hero            0.194681
# 351           field            0.194199
# 352           veins            0.194108
# 353           south            0.193711
# 354            nice            0.193139
# ..              ...                 ...
# 470           young            0.169436
# 471   approximately            0.169418
# 472          thomas            0.169338
# 473            mike            0.169186
# 474           knows            0.169149
# 475         listens            0.169140
# 476          spouse            0.168719
# 477          snippy            0.168578
# 478           loved            0.168109
# 479         listner            0.168090
# 480           child            0.168084
# 481        narcotic            0.168038
# 482       technical            0.168032
# 483           david            0.167946
# 484        accurate            0.167918
# 485      practioner            0.167894
# 486        business            0.167886
# 487            cath            0.167852
# 488     knowledable            0.167748
# 489            rate            0.167728
# 490            lyme            0.167699
# 491        shopping            0.167545
# 492          sharon            0.167448
# 493        answered            0.167267
# 494       basically            0.167256
# 495     credentials            0.167213
# 496        disabled            0.167089
# 497       standards            0.166835
# 498   communicating            0.166791
# 499         samples            0.166667
#
# [175 rows x 2 columns]
#
# M>F: Similarity score of male doctors higher then that of female doctors
#
#             words  abs_diff
# 248         needs  0.087314
# 222         heart  0.080018
# 286           bad  0.078335
# 185        family  0.077387
# 147      hospital  0.074018
# 178          life  0.069953
# 121     excellent  0.068187
# 269         takes  0.059687
# 18           well  0.058021
# 249           top  0.056248
# 141           put  0.054525
# 52         caring  0.053512
# 244   intelligent  0.051831
# 227        highly  0.051064
# 241    meticulous  0.048117
# 79            ver  0.045730
# 263     something  0.045503
# 154       stomach  0.045348
# 318        called  0.045042
# 123      episodes  0.044497
# 143         ellis  0.043575
# 271      problems  0.042200
# 180     condition  0.041769
# 225        person  0.040177
# 9             one  0.039531
# 136          area  0.039352
# 21           good  0.039165
# 138      brooklyn  0.038243
# 231      approach  0.037143
# 171          long  0.036022
# ..            ...       ...
# 245          pain  0.006417
# 259          rock  0.006381
# 291        trauma  0.006348
# 221        shares  0.006210
# 195       waiting  0.006144
# 54           know  0.005887
# 255           doc  0.005818
# 293     intuitive  0.005708
# 307        delays  0.005532
# 298         quick  0.005516
# 122     competent  0.005385
# 133        awsome  0.005361
# 292         right  0.005285
# 173         death  0.005271
# 242      informed  0.005121
# 135         given  0.004973
# 181        spinal  0.004064
# 49           made  0.003823
# 268         chemo  0.003298
# 63       medicine  0.003028
# 165        latest  0.002882
# 199          dead  0.002813
# 137  professional  0.002575
# 190        aspect  0.002473
# 209           ali  0.002449
# 11          never  0.002429
# 198          week  0.001987
# 272         aware  0.001352
# 197        facing  0.000867
# 251       arrival  0.000089
#
# [201 rows x 2 columns]
#
# F>M: Similarity score of female doctors higher then that of male doctors
#
#            words  abs_diff
# 15      campbell  0.083420
# 6           dube  0.067543
# 22     questions  0.053106
# 32        decade  0.048688
# 64          test  0.044926
# 16     treatment  0.042013
# 60          felt  0.041419
# 0             dr  0.040760
# 10           see  0.040568
# 26        issues  0.040275
# 84       removal  0.039877
# 3          staff  0.039726
# 56           mix  0.039703
# 86         phone  0.039614
# 25          told  0.039590
# 73         fever  0.038162
# 13          rude  0.035672
# 75     discussed  0.035228
# 98      negative  0.033082
# 35         nurse  0.032374
# 68           non  0.031830
# 109      ability  0.030907
# 2           time  0.030295
# 50         lymph  0.030021
# 72     impressed  0.028534
# 111      answers  0.028509
# 27      practice  0.028357
# 69      survived  0.027690
# 5         office  0.027397
# 71          mono  0.026325
# ..           ...       ...
# 119        allow  0.005872
# 129  judgemental  0.005657
# 24            go  0.004595
# 1         doctor  0.004538
# 240       assist  0.004198
# 88        choose  0.004135
# 152   antibiotic  0.004039
# 162         lake  0.003903
# 223  furthermore  0.003634
# 177       seeing  0.003627
# 156  colonoscopy  0.003546
# 205      testing  0.003512
# 92     primarily  0.003124
# 243         talk  0.003034
# 102    operation  0.002649
# 238      getting  0.002314
# 193  incompetent  0.002220
# 100         line  0.001966
# 106      outside  0.001538
# 74         nodes  0.001407
# 57           toe  0.001329
# 246           st  0.001098
# 139        going  0.000965
# 128       listen  0.000957
# 235      removed  0.000870
# 44        health  0.000728
# 232           nt  0.000670
# 206         high  0.000607
# 159       needed  0.000474
# 250         tone  0.000093
#
# [124 rows x 2 columns]

# %% [markdown]
# ### Run Doc2vec - sanction

# %%
# Tag document
import gensim
docs_s = [] # each review/row is a tagged document.
for i in range(len(documents)):
    docs_s.append(gensim.models.doc2vec.TaggedDocument(documents[i],  [hasorder[i]]))

# %%
docs_s[0]
# Out:
# TaggedDocument(words=['satisfactory', 'recommend', 'coldness', 'solo', 'helpfulness', 'limited', 'office', 'staff', 'isolation', 'diagnosis', 'solo'], tags=[0])

# %%
docs_for_vocab_s = [] 
for i in docs_s:
    docs_for_vocab_s.append(i)

# %%
model_s = Doc2Vec(dm=0, window=30,vector_size=300,min_count=30,epochs=100,workers=4,
               hs=0,negative=7,dbow_words=1,dm_concat=1)
model_s.build_vocab(docs_for_vocab_s)
model_s.train(documents = docs_s,total_examples=model_s.corpus_count,epochs=100)

# %%
model_s.save("d2v_s1.model")

# %%
d2v_s1= Doc2Vec.load("d2v_s1.model")

# %%
d2v_s1.wv.most_similar(positive = [d2v_s1.docvecs[0]],topn=15)
# Out:
# [('dr', 0.8645907640457153),
#  ('doctor', 0.8477318286895752),
#  ('patient', 0.7336011528968811),
#  ('kind', 0.73296719789505),
#  ('caring', 0.7244918346405029),
#  ('extremely', 0.717980682849884),
#  ('time', 0.7027345895767212),
#  ('great', 0.7014315128326416),
#  ('knowledgeable', 0.697580099105835),
#  ('staff', 0.692682147026062),
#  ('one', 0.6919885873794556),
#  ('helpful', 0.6891661882400513),
#  ('good', 0.6879582405090332),
#  ('never', 0.6785876750946045),
#  ('professional', 0.6783258318901062)]

# %%
d2v_s1.wv.most_similar(positive = [d2v_s1.docvecs[1]],topn=15)
# Out:
# [('dube', 0.40781348943710327),
#  ('campbell', 0.3616836667060852),
#  ('always', 0.35032209753990173),
#  ('doctor', 0.34824657440185547),
#  ('patients', 0.3298832178115845),
#  ('dr', 0.3278457820415497),
#  ('well', 0.3236086368560791),
#  ('never', 0.32163792848587036),
#  ('caring', 0.318787544965744),
#  ('ill', 0.31691277027130127),
#  ('staff', 0.3160620331764221),
#  ('see', 0.3144984841346741),
#  ('patient', 0.31109490990638733),
#  ('care', 0.3053843080997467),
#  ('kind', 0.30244529247283936)]

# %% [markdown]
# ### Similar words comparison results - sanction
# #### In this results, please replace 'F' with 'sanction', and replace 'M' with 'not sanction"

# %%
s = d2v_s1.wv.most_similar(positive = [d2v_s1.docvecs[1]],topn=500)
ns = d2v_s1.wv.most_similar(positive = [d2v_s1.docvecs[0]],topn=500)
compare(list1=s, list2=ns)
# Out:
# In F not in M: Words related with female doctors but didn't appear in male doctor's reviews
#
rows x 2 columns]
#
# M>F: Similarity score of male doctors higher then that of female doctors
#
#              words  abs_diff
# 3               dr  0.536745
# 1           doctor  0.499485
# 182  knowledgeable  0.494484
# 189   professional  0.477154
# 69       extremely  0.469931
# 46           great  0.440375
# 204     personable  0.438660
# 239       thorough  0.438102
# 11            kind  0.430522
# 9          patient  0.422506
# 166      recommend  0.420515
# 32         helpful  0.418058
# 18            time  0.415176
# 29            good  0.411775
# 59   compassionate  0.411663
# 192   knowledgable  0.409534
# 62       excellent  0.407553
# 6           caring  0.405704
# 252         manner  0.405649
# 254           nice  0.403812
# 147         highly  0.403524
# 117      physician  0.401031
# 241           best  0.398983
# 37          really  0.397938
# 13             one  0.397585
# 265         anyone  0.395897
# 78           found  0.394395
# 66        friendly  0.394184
# 53       wonderful  0.387881
# 270      concerned  0.385466
# ..             ...       ...
# 90            full  0.199096
# 118          keeps  0.198579
# 201         mother  0.197062
# 217            ten  0.195283
# 102        changed  0.195212
# 168      assistant  0.195045
# 74          return  0.195037
# 77         waiting  0.193880
# 207     confidence  0.191756
# 17       available  0.191120
# 71            true  0.190889
# 185        running  0.188857
# 113           room  0.186395
# 88          either  0.182512
# 130           asks  0.178038
# 120       provides  0.176941
# 128           alot  0.176311
# 31           short  0.175734
# 135           exam  0.174940
# 50         usually  0.174611
# 48           quick  0.173490
# 45           often  0.171114
# 39          longer  0.163852
# 99       attention  0.161591
# 27            keep  0.160345
# 63     specialists  0.158538
# 26          reason  0.153281
# 54          change  0.141054
# 55            sick  0.135563
# 24           today  0.119448
#
# [276 rows x 2 columns]
#
# F>M: Similarity score of female doctors higher then that of male doctors
#
# Empty DataFrame
# Columns: [words, abs_diff]
# Index: []

# %% [markdown]
# ### Run Doc2vec for gender & sanction using one label

# %%
label = list(review_im['label'])

# %%
len(label),len(documents)
# Out:
# (87875, 87875)

# %%
# Tag document
import gensim
docs_l = [] # each review/row is a tagged document.
for i in range(len(documents)):
    docs_l.append(gensim.models.doc2vec.TaggedDocument(documents[i],  [label[i]]))

# %%
docs_l[0]
# Out:
# TaggedDocument(words=['satisfactory', 'recommend', 'coldness', 'solo', 'helpfulness', 'limited', 'office', 'staff', 'isolation', 'diagnosis', 'solo'], tags=['F0'])

# %%
docs_for_vocab_l = [] 
for i in docs_l:
    docs_for_vocab_l.append(i)

# %%
model_l = Doc2Vec(dm=0, window=30,vector_size=300,min_count=30,epochs=100,workers=4,
               hs=0,negative=7,dbow_words=1,dm_concat=1)
model_l.build_vocab(docs_for_vocab_l)
model_l.train(documents = docs_l,total_examples=model_l.corpus_count,epochs=100)

# %%
model_l.save("d2v_l1.model")

# %%
d2v_l1= Doc2Vec.load("d2v_l1.model")

# %%
d2v_l1.wv.most_similar(positive = [d2v_l1.docvecs['F0']],topn=15)
# Out:
# [('dr', 0.748054563999176),
#  ('doctor', 0.716896653175354),
#  ('extremely', 0.6405178308486938),
#  ('staff', 0.6297218799591064),
#  ('caring', 0.6291263103485107),
#  ('office', 0.6269620656967163),
#  ('see', 0.6180649995803833),
#  ('never', 0.6140685081481934),
#  ('patient', 0.6139594912528992),
#  ('time', 0.6099159717559814),
#  ('really', 0.6055251955986023),
#  ('kind', 0.6051135063171387),
#  ('always', 0.6043594479560852),
#  ('helpful', 0.6029866933822632),
#  ('thorough', 0.596150279045105)]

# %%
d2v_l1.wv.most_similar(positive = [d2v_l1.docvecs['M0']],topn=15)
# Out:
# [('dr', 0.8275669813156128),
#  ('doctor', 0.8142729997634888),
#  ('kind', 0.7264524698257446),
#  ('caring', 0.7145541906356812),
#  ('patient', 0.7142596244812012),
#  ('extremely', 0.7005687952041626),
#  ('great', 0.6884934902191162),
#  ('good', 0.6759421825408936),
#  ('one', 0.6703273057937622),
#  ('professional', 0.6676058173179626),
#  ('well', 0.6670365333557129),
#  ('knowledgeable', 0.6643065214157104),
#  ('helpful', 0.6641438007354736),
#  ('time', 0.6632285118103027),
#  ('excellent', 0.6587772369384766)]

# %% [markdown]
# ### Similar words comparison results - gender & not sanction (using one label)

# %%
f0 = d2v_l1.wv.most_similar(positive = [d2v_l1.docvecs['F0']],topn=500)
m0 = d2v_l1.wv.most_similar(positive = [d2v_l1.docvecs['M0']],topn=500)
compare(list1=f0,list2=m0)
# Out:
# In F not in M: Words related with female doctors but didn't appear in male doctor's reviews
#
#                words  similarity_score_f
# 169        assistant            0.430557
# 174     receptionist            0.428215
# 184            woman            0.425550
# 188              pcp            0.422320
# 196         physical            0.418129
# 199              lab            0.416652
# 229             hour            0.408544
# 244       supportive            0.404466
# 251        generally            0.403162
# 261        listening            0.400194
# 269             appt            0.395902
# 283       unfriendly            0.392232
# 289             asks            0.389612
# 292          history            0.388730
# 298  endocrinologist            0.386706
# 299               pa            0.386540
# 301           change            0.386107
# 315           trying            0.382094
# 321            moved            0.380178
# 329             cold            0.378721
# 331         comments            0.378200
# 334             exam            0.377668
# 337          discuss            0.377203
# 339           wanted            0.376923
# 341          dealing            0.376677
# 344    prescriptions            0.375446
# 347         schedule            0.375129
# 351             half            0.374113
# 354           rarely            0.373288
# 355             desk            0.373013
# ..               ...                 ...
# 439         diabetes            0.354932
# 444          running            0.353522
# 445           bottom            0.353462
# 446             lady            0.353271
# 447        sensitive            0.353183
# 449      understands            0.353023
# 450          address            0.352976
# 452          illness            0.352103
# 453           behind            0.352011
# 454         informed            0.351978
# 458           turned            0.351401
# 462          reasons            0.350480
# 463        addressed            0.350198
# 467   unprofessional            0.349389
# 470             runs            0.349006
# 474          details            0.348534
# 476             read            0.347986
# 477             mean            0.347851
# 478          thyroid            0.347800
# 481     consistently            0.347482
# 482    condescending            0.347228
# 485            looks            0.346567
# 486             part            0.346306
# 488         provider            0.345310
# 491             five            0.344541
# 492          reviews            0.344278
# 493        surprised            0.344053
# 495      experiences            0.343868
# 496            maybe            0.343833
# 498             lots            0.343245
#
# [89 rows x 2 columns]
#
# In M not in F: Words related with male doctors but didn't appear in female doctor's reviews
#
#             words  similarity_score_m
# 411       husband            0.494846
# 412       skilled            0.480454
# 413        gentle            0.463466
# 414           use            0.462236
# 415   outstanding            0.460819
# 416     brilliant            0.460515
# 417         saved            0.458601
# 418      hospital            0.457260
# 419    procedures            0.455210
# 420  cardiologist            0.452962
# 421           put            0.451454
# 422         humor            0.450104
# 423        thanks            0.447704
# 424         heart            0.444978
# 425          wife            0.442623
# 426      recomend            0.438762
# 427       members            0.438492
# 428        superb            0.437907
# 429          case            0.435809
# 430   knowlegable            0.435124
# 431         along            0.432744
# 432         thank            0.431895
# 433           bed            0.424896
# 434          said            0.424451
# 435          knew            0.423811
# 436        worked            0.421457
# 437           god            0.421349
# 438         extra            0.419051
# 439          ease            0.417738
# 440      arrogant            0.417585
# ..            ...                 ...
# 470    diagnostic            0.388992
# 471         clear            0.388127
# 472    reassuring            0.387280
# 473         later            0.387075
# 474         speak            0.386788
# 475          high            0.385815
# 476       careful            0.385489
# 477          hope            0.385105
# 478      educated            0.384599
# 479          open            0.384561
# 480     reccomend            0.384206
# 481         money            0.384012
# 482       testing            0.384011
# 483     obviously            0.383653
# 484         words            0.383500
# 485          send            0.383351
# 486        mother            0.382586
# 487      consider            0.382180
# 488     explained            0.381636
# 489      internal            0.380304
# 490          meet            0.379979
# 491      interest            0.379739
# 492      accurate            0.379732
# 493    confidence            0.379699
# 494         fully            0.379534
# 495    profession            0.378870
# 496            ok            0.378556
# 497          stay            0.378285
# 498        direct            0.378075
# 499        latest            0.377850
#
# [89 rows x 2 columns]
#
# M>F: Similarity score of male doctors higher then that of female doctors
#
#              words  abs_diff
# 358            man  0.239304
# 393            guy  0.209754
# 348          earth  0.157500
# 229         family  0.146273
# 287    informative  0.145939
# 388           used  0.144601
# 44       excellent  0.137062
# 24           great  0.134437
# 386      condition  0.133410
# 381        treated  0.127467
# 409         nurses  0.126809
# 235            met  0.125819
# 346           life  0.122960
# 84          manner  0.121650
# 11            kind  0.121339
# 223    recommended  0.121174
# 398          treat  0.121016
# 81            nice  0.116871
# 26            well  0.116220
# 372          sense  0.114496
# 119        bedside  0.112712
# 361            ago  0.112075
# 40       wonderful  0.110029
# 355       possible  0.109748
# 109    intelligent  0.109110
# 264        awesome  0.108957
# 20            good  0.107556
# 337      available  0.106084
# 410        opinion  0.104553
# 34   compassionate  0.100699
# ..             ...       ...
# 29            even  0.013377
# 39            feel  0.013288
# 261          hurry  0.012947
# 172     completely  0.012490
# 241      different  0.012045
# 102           make  0.011909
# 255           felt  0.011868
# 124           wish  0.011286
# 350       horrible  0.011272
# 288           plan  0.011056
# 199          least  0.010871
# 74           makes  0.010776
# 303            yes  0.009262
# 176        overall  0.009224
# 138           gone  0.008939
# 88             lot  0.007483
# 222          short  0.007068
# 249        pleased  0.006334
# 191     personally  0.005786
# 77          follow  0.005415
# 151         visits  0.004979
# 65            love  0.004824
# 32        actually  0.004370
# 301          twice  0.003550
# 253            etc  0.002806
# 202       attitude  0.002753
# 95             ask  0.001620
# 246           less  0.001126
# 120        primary  0.000724
# 162        totally  0.000299
#
# [348 rows x 2 columns]
#
# F>M: Similarity score of female doctors higher then that of male doctors
#
#             words  abs_diff
# 73    appointment  0.061635
# 153        waited  0.055521
# 137       feeling  0.052256
# 116  appointments  0.046920
# 142       usually  0.038711
# 161         spend  0.036657
# 70         issues  0.033832
# 31       concerns  0.031777
# 156       results  0.027924
# 211          left  0.027816
# 164          seem  0.026619
# 33         seeing  0.026604
# 178         often  0.026265
# 53         health  0.025733
# 187       current  0.025720
# 105     sometimes  0.025630
# 56           long  0.025038
# 68           wait  0.023063
# 63           rush  0.018673
# 165      personal  0.017973
# 14       thorough  0.017713
# 213        rushes  0.017517
# 48           work  0.017108
# 143       someone  0.015684
# 208         front  0.015440
# 129    empathetic  0.014818
# 195         issue  0.013624
# 146         visit  0.013423
# 167        taking  0.013362
# 126      practice  0.012891
# ..            ...       ...
# 28      attentive  0.011264
# 106       looking  0.010402
# 5          office  0.009852
# 238         might  0.009823
# 276      detailed  0.009110
# 6             see  0.008925
# 278         shows  0.008782
# 93      important  0.008673
# 215       changed  0.007646
# 149          rude  0.007293
# 237     difficult  0.006744
# 184       concern  0.006673
# 103         gives  0.006660
# 228         leave  0.006181
# 59          nurse  0.005850
# 100        rushed  0.005179
# 177          hard  0.005135
# 251     insurance  0.004990
# 204       follows  0.004265
# 89           last  0.003598
# 97       listener  0.003515
# 76           past  0.003171
# 23           seen  0.002814
# 141         phone  0.002481
# 219       waiting  0.002340
# 182            md  0.002045
# 263    incredibly  0.001019
# 262      previous  0.000900
# 198       minutes  0.000629
# 158    responsive  0.000379
#
# [63 rows x 2 columns]

# %% [markdown]
# ### Similar words comparison results - gender & sanction (using one label)

# %%
f1 = d2v_l1.wv.most_similar(positive = [d2v_l1.docvecs['F1']],topn=500)
m1 = d2v_l1.wv.most_similar(positive = [d2v_l1.docvecs['M1']],topn=500)
compare(list1=f1,list2=m1)
# Out:
# In F not in M: Words related with female doctors but didn't appear in male doctor's reviews
#
#              words  similarity_score_f
# 0             dube            0.579761
# 1         campbell            0.433309
# 3           issues            0.241955
# 4          quality            0.239301
# 7            karen            0.236477
# 8            reads            0.236305
# 10    organization            0.233808
# 13         ability            0.225343
# 15       defensive            0.224558
# 16        superior            0.222778
# 18         clients            0.217946
# 19        centered            0.215806
# 20         finding            0.215272
# 21           files            0.213212
# 22             non            0.212817
# 24          modern            0.211575
# 25       concierge            0.211145
# 30          errors            0.206021
# 31          answer            0.205752
# 32       impatient            0.205283
# 34    availability            0.203782
# 35        pleasent            0.203536
# 36        referals            0.203355
# 38   authorization            0.202509
# 41           alway            0.200618
# 42         deserve            0.200607
# 45        material            0.199561
# 47           every            0.199152
# 48             new            0.198957
# 49           stays            0.198343
# ..             ...                 ...
# 464       uncaring            0.143437
# 465         letter            0.143326
# 466       internal            0.143315
# 468        closing            0.143259
# 469         memory            0.143118
# 470          vegas            0.143011
# 471            ins            0.142992
# 472     experience            0.142944
# 473         spends            0.142665
# 474          tries            0.142613
# 475      assisting            0.142479
# 476      associate            0.142427
# 477          sadly            0.142342
# 478          cohen            0.142309
# 479        consent            0.142287
# 480            hot            0.142217
# 481        develop            0.142123
# 483          hands            0.141943
# 484         wanted            0.141838
# 485        history            0.141833
# 486         beware            0.141810
# 487           kane            0.141754
# 488            law            0.141721
# 489        failure            0.141689
# 490            cut            0.141676
# 491          touch            0.141663
# 492         fiance            0.141641
# 494        partner            0.141496
# 496           exam            0.141480
# 497           stop            0.141455
#
# [382 rows x 2 columns]
#
# In M not in F: Words related with male doctors but didn't appear in female doctor's reviews
#
#              words  similarity_score_m
# 118      attentive            0.302316
# 119      wonderful            0.297922
# 120           take            0.294176
# 121           much            0.292171
# 122           good            0.291687
# 123    considerate            0.281655
# 124        doctors            0.278326
# 125           keep            0.278252
# 126           make            0.276437
# 127         nurses            0.270844
# 128            man            0.270766
# 129          great            0.266831
# 130           true            0.264649
# 131         really            0.263043
# 132   hospitalized            0.256821
# 133      excellent            0.256356
# 134       believes            0.256204
# 135       helpfull            0.256047
# 136          makes            0.255839
# 137        helpful            0.255756
# 138         charge            0.255134
# 139         change            0.254709
# 140         beyond            0.252126
# 141          visit            0.250506
# 142         rating            0.247725
# 143           find            0.247149
# 144            due            0.245477
# 145       punctual            0.244489
# 146       hospital            0.243684
# 147       recently            0.243613
# ..             ...                 ...
# 470            iam            0.182948
# 471      surprised            0.182892
# 472          right            0.182764
# 473             da            0.182758
# 474      physicals            0.182562
# 475          finds            0.182533
# 476       original            0.182514
# 477         delays            0.182415
# 478           plus            0.182408
# 479          night            0.182340
# 480       services            0.182294
# 481           jobs            0.182262
# 482     eventually            0.182198
# 483  extraordinary            0.182089
# 484      concerned            0.182005
# 485           went            0.181990
# 486          check            0.181851
# 487           died            0.181848
# 488        neither            0.181377
# 489            ive            0.181352
# 490          crazy            0.181274
# 491         timely            0.181250
# 492           hear            0.181185
# 493       improved            0.181034
# 494        injured            0.180811
# 495        feldman            0.180735
# 496           wise            0.180691
# 497          tells            0.180627
# 498     empathetic            0.180335
# 499       internet            0.180307
#
# [382 rows x 2 columns]
#
# M>F: Similarity score of male doctors higher then that of female doctors
#
#              words  abs_diff
# 109         doctor  0.239545
# 105          taken  0.158268
# 66        patients  0.144496
# 107           even  0.126426
# 43          caring  0.123197
# 71          family  0.120035
# 36            well  0.117114
# 86          taking  0.116623
# 91           takes  0.115450
# 12              dr  0.113237
# 76         treated  0.108778
# 15           never  0.108127
# 93          around  0.103620
# 65           today  0.102307
# 17            time  0.102226
# 111          think  0.101486
# 112         return  0.101071
# 55             ill  0.099733
# 62            help  0.097152
# 30          health  0.097121
# 28             one  0.095827
# 53            wait  0.095720
# 8            staff  0.094601
# 26            many  0.094199
# 79          person  0.093654
# 117           wish  0.092389
# 74          polite  0.091706
# 116           long  0.088688
# 80   compassionate  0.083800
# 41          visits  0.082659
# ..             ...       ...
# 106          still  0.038171
# 57      absolutely  0.038153
# 19             via  0.037036
# 34         without  0.036519
# 39         medical  0.034901
# 16             way  0.034769
# 75        consider  0.034488
# 100            bad  0.033910
# 101          nasty  0.033663
# 85            high  0.032796
# 1            often  0.029833
# 88       assistant  0.029442
# 69            full  0.027911
# 50           issue  0.027198
# 60            feel  0.026697
# 78       goldsmith  0.026433
# 29             far  0.024817
# 37            seen  0.023436
# 21       available  0.021696
# 59         willing  0.016282
# 42          carter  0.014779
# 45       including  0.014491
# 22         answers  0.014047
# 4             care  0.013995
# 7           reason  0.013508
# 31        curtious  0.011244
# 46            talk  0.008805
# 38            vist  0.006179
# 11        practice  0.002141
# 27       primarily  0.001321
#
# [112 rows x 2 columns]
#
# F>M: Similarity score of female doctors higher then that of male doctors
#
#             words  abs_diff
# 0          almost  0.043766
# 3           short  0.030827
# 14  inappropriate  0.014638
# 10        several  0.010115
# 9             sad  0.005519
# 5           nurse  0.005361

# %% [markdown]
# 1. Try window size: 5
# 1. Try stemming
# 2. First down sampling sanction results. 574, then up sampling and double.
# 3. Try outer join
